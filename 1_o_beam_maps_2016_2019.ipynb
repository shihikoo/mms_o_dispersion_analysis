# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"
hemi_sort_map_path = "hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20191231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kowduYNTUWGqxf4TvaLqRj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kowduYNTUWGqxf4TvaLqRj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kowduYNTUWGqxf4TvaLqRj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kowduYNTUWGqxf4TvaLqRj:checked ~ #ipyplot-html-viewer-textarea-kowduYNTUWGqxf4TvaLqRj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kowduYNTUWGqxf4TvaLqRj:checked + #ipyplot-html-viewer-label-kowduYNTUWGqxf4TvaLqRj:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20191231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-emkSoHG4PW8FFV9RA6BETy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-emkSoHG4PW8FFV9RA6BETy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-emkSoHG4PW8FFV9RA6BETy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-emkSoHG4PW8FFV9RA6BETy:checked ~ #ipyplot-html-viewer-textarea-emkSoHG4PW8FFV9RA6BETy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-emkSoHG4PW8FFV9RA6BETy:checked + #ipyplot-html-viewer-label-emkSoHG4PW8FFV9RA6BETy:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20191231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iqMvKHCHt88zgoiTxzR4fm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iqMvKHCHt88zgoiTxzR4fm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iqMvKHCHt88zgoiTxzR4fm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iqMvKHCHt88zgoiTxzR4fm:checked ~ #ipyplot-html-viewer-textarea-iqMvKHCHt88zgoiTxzR4fm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iqMvKHCHt88zgoiTxzR4fm:checked + #ipyplot-html-viewer-label-iqMvKHCHt88zgoiTxzR4fm:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20191231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZEeqnWE2NzMMT6n28FScRH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZEeqnWE2NzMMT6n28FScRH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZEeqnWE2NzMMT6n28FScRH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZEeqnWE2NzMMT6n28FScRH:checked ~ #ipyplot-html-viewer-textarea-ZEeqnWE2NzMMT6n28FScRH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZEeqnWE2NzMMT6n28FScRH:checked + #ipyplot-html-viewer-label-ZEeqnWE2NzMMT6n28FScRH:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20191231_X_GSM_vs_Beta.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20191231_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZpgXKYp54xyaHqLPYSAs3a {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZpgXKYp54xyaHqLPYSAs3a {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZpgXKYp54xyaHqLPYSAs3a {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZpgXKYp54xyaHqLPYSAs3a:checked ~ #ipyplot-html-viewer-textarea-ZpgXKYp54xyaHqLPYSAs3a {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZpgXKYp54xyaHqLPYSAs3a:checked + #ipyplot-html-viewer-label-ZpgXKYp54xyaHqLPYSAs3a:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-VUvnPvH5SHzJuD93CD6bB5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VUvnPvH5SHzJuD93CD6bB5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VUvnPvH5SHzJuD93CD6bB5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VUvnPvH5SHzJuD93CD6bB5:checked ~ #ipyplot-html-viewer-textarea-VUvnPvH5SHzJuD93CD6bB5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VUvnPvH5SHzJuD93CD6bB5:checked + #ipyplot-html-viewer-label-VUvnPvH5SHzJuD93CD6bB5:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XGUiJTBf9xYYXnrWYr9VyK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XGUiJTBf9xYYXnrWYr9VyK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XGUiJTBf9xYYXnrWYr9VyK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XGUiJTBf9xYYXnrWYr9VyK:checked ~ #ipyplot-html-viewer-textarea-XGUiJTBf9xYYXnrWYr9VyK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XGUiJTBf9xYYXnrWYr9VyK:checked + #ipyplot-html-viewer-label-XGUiJTBf9xYYXnrWYr9VyK:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RuYFXUBBW27zjvFYQGzsdP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RuYFXUBBW27zjvFYQGzsdP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RuYFXUBBW27zjvFYQGzsdP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RuYFXUBBW27zjvFYQGzsdP:checked ~ #ipyplot-html-viewer-textarea-RuYFXUBBW27zjvFYQGzsdP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RuYFXUBBW27zjvFYQGzsdP:checked + #ipyplot-html-viewer-label-RuYFXUBBW27zjvFYQGzsdP:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
         "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RZFeYs5hXUcyGwvno73vi7 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RZFeYs5hXUcyGwvno73vi7 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RZFeYs5hXUcyGwvno73vi7 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RZFeYs5hXUcyGwvno73vi7:checked ~ #ipyplot-html-viewer-textarea-RZFeYs5hXUcyGwvno73vi7 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RZFeYs5hXUcyGwvno73vi7:checked + #ipyplot-html-viewer-label-RZFeYs5hXUcyGwvno73vi7:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3mhXGiMxBrkkXNdsZ9LcLy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3mhXGiMxBrkkXNdsZ9LcLy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3mhXGiMxBrkkXNdsZ9LcLy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3mhXGiMxBrkkXNdsZ9LcLy:checked ~ #ipyplot-html-viewer-textarea-3mhXGiMxBrkkXNdsZ9LcLy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3mhXGiMxBrkkXNdsZ9LcLy:checked + #ipyplot-html-viewer-label-3mhXGiMxBrkkXNdsZ9LcLy:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-F48y285vUYzRTPHGmveCtq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-F48y285vUYzRTPHGmveCtq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-F48y285vUYzRTPHGmveCtq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-F48y285vUYzRTPHGmveCtq:checked ~ #ipyplot-html-viewer-textarea-F48y285vUYzRTPHGmveCtq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-F48y285vUYzRTPHGmveCtq:checked + #ipyplot-html-viewer-label-F48y285vUYzRTPHGmveCtq:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NzEoeEAb5gFHtt2kbMzwtf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NzEoeEAb5gFHtt2kbMzwtf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NzEoeEAb5gFHtt2kbMzwtf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NzEoeEAb5gFHtt2kbMzwtf:checked ~ #ipyplot-html-viewer-textarea-NzEoeEAb5gFHtt2kbMzwtf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NzEoeEAb5gFHtt2kbMzwtf:checked + #ipyplot-html-viewer-label-NzEoeEAb5gFHtt2kbMzwtf:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ma2ZumU5ZTCf9FLinxARsA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ma2ZumU5ZTCf9FLinxARsA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ma2ZumU5ZTCf9FLinxARsA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ma2ZumU5ZTCf9FLinxARsA:checked ~ #ipyplot-html-viewer-textarea-Ma2ZumU5ZTCf9FLinxARsA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ma2ZumU5ZTCf9FLinxARsA:checked + #ipyplot-html-viewer-label-Ma2ZumU5ZTCf9FLinxARsA:after {
# ...

# %% [markdown]
# # Check how south/north defination compared with position cut south/north

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/slice/slice_zgrid_20/south_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/slice/slice_zgrid_20/north_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/slice/slice_zgrid_20/south_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/slice/slice_zgrid_20/north_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png" 
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/slice/slice_zgrid_20/south_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/slice/slice_zgrid_20/north_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MWfW9yhCEwARiDb6bGQyMC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MWfW9yhCEwARiDb6bGQyMC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MWfW9yhCEwARiDb6bGQyMC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MWfW9yhCEwARiDb6bGQyMC:checked ~ #ipyplot-html-viewer-textarea-MWfW9yhCEwARiDb6bGQyMC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MWfW9yhCEwARiDb6bGQyMC:checked + #ipyplot-html-viewer-label-MWfW9yhCEwARiDb6bGQyMC:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XYgsm plan for north and south in different regions 2016-2017 vs 2018-2019

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_20/Lobe_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_20/Lobe_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_20/Lobe_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_20/Lobe_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_20/BL_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_20/BL_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_20/BL_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_20/BL_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_20/PS_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_20/PS_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_20/PS_any__ratio_20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_20/PS_any__ratio_20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HtkM9E6YwXjUToxx8w7nf4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HtkM9E6YwXjUToxx8w7nf4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HtkM9E6YwXjUToxx8w7nf4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HtkM9E6YwXjUToxx8w7nf4:checked ~ #ipyplot-html-viewer-textarea-HtkM9E6YwXjUToxx8w7nf4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HtkM9E6YwXjUToxx8w7nf4:checked + #ipyplot-html-viewer-label-HtkM9E6YwXjUToxx8w7nf4:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hdTwzkmLNyH6jzdMHY4Wgh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hdTwzkmLNyH6jzdMHY4Wgh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hdTwzkmLNyH6jzdMHY4Wgh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hdTwzkmLNyH6jzdMHY4Wgh:checked ~ #ipyplot-html-viewer-textarea-hdTwzkmLNyH6jzdMHY4Wgh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hdTwzkmLNyH6jzdMHY4Wgh:checked + #ipyplot-html-viewer-label-hdTwzkmLNyH6jzdMHY4Wgh:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CePYCvVPeXiP77E3XMCQfB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CePYCvVPeXiP77E3XMCQfB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CePYCvVPeXiP77E3XMCQfB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CePYCvVPeXiP77E3XMCQfB:checked ~ #ipyplot-html-viewer-textarea-CePYCvVPeXiP77E3XMCQfB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CePYCvVPeXiP77E3XMCQfB:checked + #ipyplot-html-viewer-label-CePYCvVPeXiP77E3XMCQfB:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
       ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
 ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ba9SdcUoDSwrudMVMrxYri {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ba9SdcUoDSwrudMVMrxYri {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ba9SdcUoDSwrudMVMrxYri {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ba9SdcUoDSwrudMVMrxYri:checked ~ #ipyplot-html-viewer-textarea-ba9SdcUoDSwrudMVMrxYri {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ba9SdcUoDSwrudMVMrxYri:checked + #ipyplot-html-viewer-label-ba9SdcUoDSwrudMVMrxYri:after {
# ...
