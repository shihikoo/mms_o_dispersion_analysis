# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"
with_reduced_kp_sort_map_path = main_plot_path+'plots_with_reduced/kp_sort_map'
with_reduced_bx_sort_map_path = main_plot_path+'plots_with_reduced/bx_sort_map'

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"
kp_sort_map_path = main_plot_path+'plots_original/kp_sort_map'
bx_sort_map_path = main_plot_path+'plots_original/bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
        , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JDnQWad9Z2hPCLc6HDnT7S {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JDnQWad9Z2hPCLc6HDnT7S {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JDnQWad9Z2hPCLc6HDnT7S {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JDnQWad9Z2hPCLc6HDnT7S:checked ~ #ipyplot-html-viewer-textarea-JDnQWad9Z2hPCLc6HDnT7S {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JDnQWad9Z2hPCLc6HDnT7S:checked + #ipyplot-html-viewer-label-JDnQWad9Z2hPCLc6HDnT7S:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jdQ3YvZ5EkDJND9xrT6Avr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jdQ3YvZ5EkDJND9xrT6Avr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jdQ3YvZ5EkDJND9xrT6Avr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jdQ3YvZ5EkDJND9xrT6Avr:checked ~ #ipyplot-html-viewer-textarea-jdQ3YvZ5EkDJND9xrT6Avr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jdQ3YvZ5EkDJND9xrT6Avr:checked + #ipyplot-html-viewer-label-jdQ3YvZ5EkDJND9xrT6Avr:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png",with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
,with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cqUbouKFJ9VuVyhyxkDqd4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cqUbouKFJ9VuVyhyxkDqd4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cqUbouKFJ9VuVyhyxkDqd4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cqUbouKFJ9VuVyhyxkDqd4:checked ~ #ipyplot-html-viewer-textarea-cqUbouKFJ9VuVyhyxkDqd4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cqUbouKFJ9VuVyhyxkDqd4:checked + #ipyplot-html-viewer-label-cqUbouKFJ9VuVyhyxkDqd4:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    ,
    with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
       , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"       , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SCMQww4rdQ2p9KisnzSGfM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SCMQww4rdQ2p9KisnzSGfM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SCMQww4rdQ2p9KisnzSGfM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SCMQww4rdQ2p9KisnzSGfM:checked ~ #ipyplot-html-viewer-textarea-SCMQww4rdQ2p9KisnzSGfM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SCMQww4rdQ2p9KisnzSGfM:checked + #ipyplot-html-viewer-label-SCMQww4rdQ2p9KisnzSGfM:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png" ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"    
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"   
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
  , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hw2m3UJzLxbgAqnKSDBC2S {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hw2m3UJzLxbgAqnKSDBC2S {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hw2m3UJzLxbgAqnKSDBC2S {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hw2m3UJzLxbgAqnKSDBC2S:checked ~ #ipyplot-html-viewer-textarea-hw2m3UJzLxbgAqnKSDBC2S {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hw2m3UJzLxbgAqnKSDBC2S:checked + #ipyplot-html-viewer-label-hw2m3UJzLxbgAqnKSDBC2S:after {
# ...

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
        , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
       , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"   , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6vZRTYExa5rqrngyvudywP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6vZRTYExa5rqrngyvudywP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6vZRTYExa5rqrngyvudywP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6vZRTYExa5rqrngyvudywP:checked ~ #ipyplot-html-viewer-textarea-6vZRTYExa5rqrngyvudywP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6vZRTYExa5rqrngyvudywP:checked + #ipyplot-html-viewer-label-6vZRTYExa5rqrngyvudywP:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hSyQQyJF4zSoV8uGWBvszv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hSyQQyJF4zSoV8uGWBvszv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hSyQQyJF4zSoV8uGWBvszv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hSyQQyJF4zSoV8uGWBvszv:checked ~ #ipyplot-html-viewer-textarea-hSyQQyJF4zSoV8uGWBvszv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hSyQQyJF4zSoV8uGWBvszv:checked + #ipyplot-html-viewer-label-hSyQQyJF4zSoV8uGWBvszv:after {
# ...
