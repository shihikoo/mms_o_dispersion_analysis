# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "plots_only_reduced/non_sort_map"
hemi_sort_map_path = "plots_only_reduced/hemi_sort_map"

kp_sort_map_path = 'plots_avoid_compression/kp_sort_map'
bx_sort_map_path = 'plots_avoid_compression/bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ANFyLyx4SSnfJAS8MZd6KW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ANFyLyx4SSnfJAS8MZd6KW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ANFyLyx4SSnfJAS8MZd6KW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ANFyLyx4SSnfJAS8MZd6KW:checked ~ #ipyplot-html-viewer-textarea-ANFyLyx4SSnfJAS8MZd6KW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ANFyLyx4SSnfJAS8MZd6KW:checked + #ipyplot-html-viewer-label-ANFyLyx4SSnfJAS8MZd6KW:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dvHg5U4JCpabJ2WvU5BLgd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dvHg5U4JCpabJ2WvU5BLgd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dvHg5U4JCpabJ2WvU5BLgd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dvHg5U4JCpabJ2WvU5BLgd:checked ~ #ipyplot-html-viewer-textarea-dvHg5U4JCpabJ2WvU5BLgd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dvHg5U4JCpabJ2WvU5BLgd:checked + #ipyplot-html-viewer-label-dvHg5U4JCpabJ2WvU5BLgd:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fKCEArwoBPTSAUgBTWoRwc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fKCEArwoBPTSAUgBTWoRwc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fKCEArwoBPTSAUgBTWoRwc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fKCEArwoBPTSAUgBTWoRwc:checked ~ #ipyplot-html-viewer-textarea-fKCEArwoBPTSAUgBTWoRwc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fKCEArwoBPTSAUgBTWoRwc:checked + #ipyplot-html-viewer-label-fKCEArwoBPTSAUgBTWoRwc:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
       , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7RWEvjr77iGPv74B8nen72 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7RWEvjr77iGPv74B8nen72 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7RWEvjr77iGPv74B8nen72 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7RWEvjr77iGPv74B8nen72:checked ~ #ipyplot-html-viewer-textarea-7RWEvjr77iGPv74B8nen72 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7RWEvjr77iGPv74B8nen72:checked + #ipyplot-html-viewer-label-7RWEvjr77iGPv74B8nen72:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3w7zd5d5HwTYGAJWEmyvHV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3w7zd5d5HwTYGAJWEmyvHV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3w7zd5d5HwTYGAJWEmyvHV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3w7zd5d5HwTYGAJWEmyvHV:checked ~ #ipyplot-html-viewer-textarea-3w7zd5d5HwTYGAJWEmyvHV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3w7zd5d5HwTYGAJWEmyvHV:checked + #ipyplot-html-viewer-label-3w7zd5d5HwTYGAJWEmyvHV:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-G3TEWMeW5FYmjipgE2U8QT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-G3TEWMeW5FYmjipgE2U8QT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-G3TEWMeW5FYmjipgE2U8QT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-G3TEWMeW5FYmjipgE2U8QT:checked ~ #ipyplot-html-viewer-textarea-G3TEWMeW5FYmjipgE2U8QT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-G3TEWMeW5FYmjipgE2U8QT:checked + #ipyplot-html-viewer-label-G3TEWMeW5FYmjipgE2U8QT:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ULTRGbSXcCxsdHbmnPkPJr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ULTRGbSXcCxsdHbmnPkPJr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ULTRGbSXcCxsdHbmnPkPJr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ULTRGbSXcCxsdHbmnPkPJr:checked ~ #ipyplot-html-viewer-textarea-ULTRGbSXcCxsdHbmnPkPJr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ULTRGbSXcCxsdHbmnPkPJr:checked + #ipyplot-html-viewer-label-ULTRGbSXcCxsdHbmnPkPJr:after {
# ...

# %% [markdown]
# ## kp impacts on the convection maps

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DjzXKZHYLTpu3K8a8jM4ry {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DjzXKZHYLTpu3K8a8jM4ry {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DjzXKZHYLTpu3K8a8jM4ry {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DjzXKZHYLTpu3K8a8jM4ry:checked ~ #ipyplot-html-viewer-textarea-DjzXKZHYLTpu3K8a8jM4ry {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DjzXKZHYLTpu3K8a8jM4ry:checked + #ipyplot-html-viewer-label-DjzXKZHYLTpu3K8a8jM4ry:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZU3hmLqUx5FbdHREeo9ypQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZU3hmLqUx5FbdHREeo9ypQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZU3hmLqUx5FbdHREeo9ypQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZU3hmLqUx5FbdHREeo9ypQ:checked ~ #ipyplot-html-viewer-textarea-ZU3hmLqUx5FbdHREeo9ypQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZU3hmLqUx5FbdHREeo9ypQ:checked + #ipyplot-html-viewer-label-ZU3hmLqUx5FbdHREeo9ypQ:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fZSxLi6W4waJjMs6R8yHhr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fZSxLi6W4waJjMs6R8yHhr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fZSxLi6W4waJjMs6R8yHhr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fZSxLi6W4waJjMs6R8yHhr:checked ~ #ipyplot-html-viewer-textarea-fZSxLi6W4waJjMs6R8yHhr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fZSxLi6W4waJjMs6R8yHhr:checked + #ipyplot-html-viewer-label-fZSxLi6W4waJjMs6R8yHhr:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JhBaU8h9pZABp4u6zXPY29 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JhBaU8h9pZABp4u6zXPY29 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JhBaU8h9pZABp4u6zXPY29 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JhBaU8h9pZABp4u6zXPY29:checked ~ #ipyplot-html-viewer-textarea-JhBaU8h9pZABp4u6zXPY29 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JhBaU8h9pZABp4u6zXPY29:checked + #ipyplot-html-viewer-label-JhBaU8h9pZABp4u6zXPY29:after {
# ...

# %% [markdown]
# ## Storm impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-He5JCxg7Qj7iQJTxUzhUwY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-He5JCxg7Qj7iQJTxUzhUwY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-He5JCxg7Qj7iQJTxUzhUwY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-He5JCxg7Qj7iQJTxUzhUwY:checked ~ #ipyplot-html-viewer-textarea-He5JCxg7Qj7iQJTxUzhUwY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-He5JCxg7Qj7iQJTxUzhUwY:checked + #ipyplot-html-viewer-label-He5JCxg7Qj7iQJTxUzhUwY:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5GMkn8D6BTrA2avFAqorN4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5GMkn8D6BTrA2avFAqorN4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5GMkn8D6BTrA2avFAqorN4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5GMkn8D6BTrA2avFAqorN4:checked ~ #ipyplot-html-viewer-textarea-5GMkn8D6BTrA2avFAqorN4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5GMkn8D6BTrA2avFAqorN4:checked + #ipyplot-html-viewer-label-5GMkn8D6BTrA2avFAqorN4:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_0_450_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_450_900_median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BqbJwLPmA6CWE6gfQSt3zm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BqbJwLPmA6CWE6gfQSt3zm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BqbJwLPmA6CWE6gfQSt3zm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BqbJwLPmA6CWE6gfQSt3zm:checked ~ #ipyplot-html-viewer-textarea-BqbJwLPmA6CWE6gfQSt3zm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BqbJwLPmA6CWE6gfQSt3zm:checked + #ipyplot-html-viewer-label-BqbJwLPmA6CWE6gfQSt3zm:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2whLsWe3dSmNnkGnPsxJQJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2whLsWe3dSmNnkGnPsxJQJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2whLsWe3dSmNnkGnPsxJQJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2whLsWe3dSmNnkGnPsxJQJ:checked ~ #ipyplot-html-viewer-textarea-2whLsWe3dSmNnkGnPsxJQJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2whLsWe3dSmNnkGnPsxJQJ:checked + #ipyplot-html-viewer-label-2whLsWe3dSmNnkGnPsxJQJ:after {
# ...
