# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
# main_plot_path_1 = "idl_plots/before IUGG/output_5min_multi_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1_oldregion/plots_ss27/"

# non_sort_map_path_1 = main_plot_path_1+"non_sort_map"
# hemi_sort_map_path_1 = main_plot_path_1+"hemi_sort_map"
# kp_sort_map_path_1 = main_plot_path_1+'kp_sort_map'
# bx_sort_map_path_1 = main_plot_path_1+'bx_sort_map'

# start_time_1 = '20170101'
# end_time_1 = '20201231'

# grid_str_1 = "grid_02"
# direction_str_1 = "outflow"

# main_plot_path_2 = "idl_plots/before IUGG/output_5min_multi_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots_ss27/"

# non_sort_map_path_2 = main_plot_path_2+"non_sort_map"
# hemi_sort_map_path_2 = main_plot_path_2+"hemi_sort_map"
# kp_sort_map_path_2 = main_plot_path_2+'kp_sort_map'
# bx_sort_map_path_2 = main_plot_path_2+'bx_sort_map'

# start_time_2 = '20170101'
# end_time_2 = '20201231'

# grid_str_2 = "grid_02"
# direction_str_2 = "outflow"

# %%
main_plot_path_1 = "idl_plots/output_sc1_sp3_300sec_multi_pa2_en2_subtraction_removebi_flux0.500.751.00_pap3.02.01.1/plots/plots_only_no_compression_ss27/"

non_sort_map_path_1 = main_plot_path_1+"non_sort_map"
hemi_sort_map_path_1 = main_plot_path_1+"hemi_sort_map"
kp_sort_map_path_1 = main_plot_path_1+'kp_sort_map'
bx_sort_map_path_1 = main_plot_path_1+'bx_sort_map'

start_time_1 = '20180101'
end_time_1 = '20191231'

grid_str_1 = "grid_02"
direction_str_1 = "outflow"


main_plot_path_2 = "idl_plots/output_sc1_sp3_300sec_multi_pa2_en2_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots/plots_only_no_compression_ss27/"

non_sort_map_path_2 = main_plot_path_2+"non_sort_map"
hemi_sort_map_path_2 = main_plot_path_2+"hemi_sort_map"
kp_sort_map_path_2 = main_plot_path_2+'kp_sort_map'
bx_sort_map_path_2 = main_plot_path_2+'bx_sort_map'

start_time_2 = '20180101'
end_time_2 = '20191231'

grid_str_2 = "grid_02"
direction_str_2 = "outflow"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [ non_sort_map_path_1+"/"+grid_str_1+"/"+direction_str_1+"/events/2d/"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/"+direction_str_1+"/events/2d/"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/"+direction_str_1+"/events/2d/"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/"+direction_str_2+"/events/2d/"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/"+direction_str_2+"/events/2d/"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/"+direction_str_2+"/events/2d/"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5nvYDDHV5iQjNiydWuMdyw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5nvYDDHV5iQjNiydWuMdyw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5nvYDDHV5iQjNiydWuMdyw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5nvYDDHV5iQjNiydWuMdyw:checked ~ #ipyplot-html-viewer-textarea-5nvYDDHV5iQjNiydWuMdyw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5nvYDDHV5iQjNiydWuMdyw:checked + #ipyplot-html-viewer-label-5nvYDDHV5iQjNiydWuMdyw:after {
# ...

# %%
images_array = [
    non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/2d/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/2d/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/2d/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-eUwtQRDDKi8joDJ8DLsQ5Y {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eUwtQRDDKi8joDJ8DLsQ5Y {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eUwtQRDDKi8joDJ8DLsQ5Y {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eUwtQRDDKi8joDJ8DLsQ5Y:checked ~ #ipyplot-html-viewer-textarea-eUwtQRDDKi8joDJ8DLsQ5Y {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eUwtQRDDKi8joDJ8DLsQ5Y:checked + #ipyplot-html-viewer-label-eUwtQRDDKi8joDJ8DLsQ5Y:after {
# ...

# %%
images_array = [
    non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/2d/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/2d/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/2d/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-FiZiFAuWPdP4nuhani7FuC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-FiZiFAuWPdP4nuhani7FuC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-FiZiFAuWPdP4nuhani7FuC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-FiZiFAuWPdP4nuhani7FuC:checked ~ #ipyplot-html-viewer-textarea-FiZiFAuWPdP4nuhani7FuC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-FiZiFAuWPdP4nuhani7FuC:checked + #ipyplot-html-viewer-label-FiZiFAuWPdP4nuhani7FuC:after {
# ...

# %%
images_array = [
    non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ReMvGZLEZq5LiqtdVRCKsu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ReMvGZLEZq5LiqtdVRCKsu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ReMvGZLEZq5LiqtdVRCKsu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ReMvGZLEZq5LiqtdVRCKsu:checked ~ #ipyplot-html-viewer-textarea-ReMvGZLEZq5LiqtdVRCKsu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ReMvGZLEZq5LiqtdVRCKsu:checked + #ipyplot-html-viewer-label-ReMvGZLEZq5LiqtdVRCKsu:after {
# ...

# %%
images_array = [
    non_sort_map_path_1+"/"+grid_str_1+"/Tail_"+direction_str_1+"/events/2d/Tail_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Beta.png"
    , non_sort_map_path_1+"/"+grid_str_1+"/Tail_"+direction_str_1+"/events/2d/Tail_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_DIST_vs_Beta.png"
    ,    non_sort_map_path_2+"/"+grid_str_2+"/Tail_"+direction_str_2+"/events/2d/Tail_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Beta.png"
    , non_sort_map_path_2+"/"+grid_str_2+"/Tail_"+direction_str_2+"/events/2d/Tail_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ae6ZXmzttJ5L7pLjpgN5ff {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ae6ZXmzttJ5L7pLjpgN5ff {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ae6ZXmzttJ5L7pLjpgN5ff {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ae6ZXmzttJ5L7pLjpgN5ff:checked ~ #ipyplot-html-viewer-textarea-ae6ZXmzttJ5L7pLjpgN5ff {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ae6ZXmzttJ5L7pLjpgN5ff:checked + #ipyplot-html-viewer-label-ae6ZXmzttJ5L7pLjpgN5ff:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"   ,non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"   ,non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    ,  
    non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    , 
    non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_15/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_10/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_15/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"     ,  
    non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"   
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_15/PS_"+direction_str_2+"__ratio_"+start_time_1+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_10/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_15/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KZD44ED3eMdhBNTXDkcF8n {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KZD44ED3eMdhBNTXDkcF8n {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KZD44ED3eMdhBNTXDkcF8n {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KZD44ED3eMdhBNTXDkcF8n:checked ~ #ipyplot-html-viewer-textarea-KZD44ED3eMdhBNTXDkcF8n {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KZD44ED3eMdhBNTXDkcF8n:checked + #ipyplot-html-viewer-label-KZD44ED3eMdhBNTXDkcF8n:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,
     non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,  
    non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"     ,  
    non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_15/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_10/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/BL_"+direction_str_2+"/events/slice/slice_zgrid_10/BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"     ,   
    non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"        ,   
    non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_15/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_10/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/slice/slice_zgrid_10/PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-m6pNMyYZ6EbE6zeJ2WZi2v {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-m6pNMyYZ6EbE6zeJ2WZi2v {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-m6pNMyYZ6EbE6zeJ2WZi2v {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-m6pNMyYZ6EbE6zeJ2WZi2v:checked ~ #ipyplot-html-viewer-textarea-m6pNMyYZ6EbE6zeJ2WZi2v {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-m6pNMyYZ6EbE6zeJ2WZi2v:checked + #ipyplot-html-viewer-label-m6pNMyYZ6EbE6zeJ2WZi2v:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
    hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_Lobe_"+direction_str_1+"/events/2d/south_Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_Lobe_"+direction_str_1+"/events/2d/north_Lobe_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png" ,   
     hemi_sort_map_path_2+"/hemi_south/"+grid_str_2+"/south_Lobe_"+direction_str_2+"/events/2d/south_Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_2+"/hemi_north/"+grid_str_2+"/north_Lobe_"+direction_str_2+"/events/2d/north_Lobe_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_BL_"+direction_str_1+"/events/2d/south_BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_BL_"+direction_str_1+"/events/2d/north_BL_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_2+"/hemi_south/"+grid_str_2+"/south_BL_"+direction_str_2+"/events/2d/south_BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_2+"/hemi_north/"+grid_str_2+"/north_BL_"+direction_str_2+"/events/2d/north_BL_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_PS_"+direction_str_1+"/events/2d/south_PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_PS_"+direction_str_1+"/events/2d/north_PS_"+direction_str_1+"__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
        ,   hemi_sort_map_path_2+"/hemi_south/"+grid_str_2+"/south_PS_"+direction_str_2+"/events/2d/south_PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_2+"/hemi_north/"+grid_str_2+"/north_PS_"+direction_str_2+"/events/2d/north_PS_"+direction_str_2+"__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QLqqeYV5hBG3pqfxBFzx4P {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QLqqeYV5hBG3pqfxBFzx4P {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QLqqeYV5hBG3pqfxBFzx4P {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QLqqeYV5hBG3pqfxBFzx4P:checked ~ #ipyplot-html-viewer-textarea-QLqqeYV5hBG3pqfxBFzx4P {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QLqqeYV5hBG3pqfxBFzx4P:checked + #ipyplot-html-viewer-label-QLqqeYV5hBG3pqfxBFzx4P:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
    non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png",  non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png",
     non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/2d/Lobe_"+direction_str_2+"_imfBy_0_25__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png",  non_sort_map_path_2+"/"+grid_str_2+"/Lobe_"+direction_str_2+"/events/2d/Lobe_"+direction_str_2+"_imfBy_-25_0__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png",
    
non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
  ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
        , 
   
non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_2+"/events/2d/BL_"+direction_str_2+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
  ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_2+"/events/2d/BL_"+direction_str_2+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
     , 
    non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,      non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"  

     , non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"

    ,      non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aZuBUHQEq6XQbFPzm6EB5N {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aZuBUHQEq6XQbFPzm6EB5N {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aZuBUHQEq6XQbFPzm6EB5N {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aZuBUHQEq6XQbFPzm6EB5N:checked ~ #ipyplot-html-viewer-textarea-aZuBUHQEq6XQbFPzm6EB5N {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aZuBUHQEq6XQbFPzm6EB5N:checked + #ipyplot-html-viewer-label-aZuBUHQEq6XQbFPzm6EB5N:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"    , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_2+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_2+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_2+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_2+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_2+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_2+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_2+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_2+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_2+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_2+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_2+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_2+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8yjJcWZPmYPLJDaEVccw5z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8yjJcWZPmYPLJDaEVccw5z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8yjJcWZPmYPLJDaEVccw5z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8yjJcWZPmYPLJDaEVccw5z:checked ~ #ipyplot-html-viewer-textarea-8yjJcWZPmYPLJDaEVccw5z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8yjJcWZPmYPLJDaEVccw5z:checked + #ipyplot-html-viewer-label-8yjJcWZPmYPLJDaEVccw5z:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
        , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
        ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dPAeZ2wn8ySmvudEzjzti4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dPAeZ2wn8ySmvudEzjzti4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dPAeZ2wn8ySmvudEzjzti4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dPAeZ2wn8ySmvudEzjzti4:checked ~ #ipyplot-html-viewer-textarea-dPAeZ2wn8ySmvudEzjzti4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dPAeZ2wn8ySmvudEzjzti4:checked + #ipyplot-html-viewer-label-dPAeZ2wn8ySmvudEzjzti4:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"       , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_15/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/slice/slice_zgrid_10/Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
            ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 

    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_15/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/slice/slice_zgrid_10/BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_15/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/slice/slice_zgrid_10/PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iLWLNTFmqEKhejpd7sCXzJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iLWLNTFmqEKhejpd7sCXzJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iLWLNTFmqEKhejpd7sCXzJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iLWLNTFmqEKhejpd7sCXzJ:checked ~ #ipyplot-html-viewer-textarea-iLWLNTFmqEKhejpd7sCXzJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iLWLNTFmqEKhejpd7sCXzJ:checked + #ipyplot-html-viewer-label-iLWLNTFmqEKhejpd7sCXzJ:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_Lobe_"+direction_str_1+"/events/2d/north_Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_Lobe_"+direction_str_1+"/events/2d/north_Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_Lobe_"+direction_str_1+"/events/2d/south_Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_Lobe_"+direction_str_1+"/events/2d/south_Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,     hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_Lobe_"+direction_str_1+"/events/2d/north_Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_Lobe_"+direction_str_1+"/events/2d/north_Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_Lobe_"+direction_str_1+"/events/2d/south_Lobe_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_Lobe_"+direction_str_1+"/events/2d/south_Lobe_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_BL_"+direction_str_1+"/events/2d/north_BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_BL_"+direction_str_1+"/events/2d/north_BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_BL_"+direction_str_1+"/events/2d/south_BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_BL_"+direction_str_1+"/events/2d/south_BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_BL_"+direction_str_1+"/events/2d/north_BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_BL_"+direction_str_1+"/events/2d/north_BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_BL_"+direction_str_1+"/events/2d/south_BL_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_BL_"+direction_str_1+"/events/2d/south_BL_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_PS_"+direction_str_1+"/events/2d/north_PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_north/"+grid_str_1+"/north_PS_"+direction_str_1+"/events/2d/north_PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_PS_"+direction_str_1+"/events/2d/south_PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_1+"/hemi_south/"+grid_str_1+"/south_PS_"+direction_str_1+"/events/2d/south_PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_PS_"+direction_str_1+"/events/2d/north_PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_north/"+grid_str_1+"/north_PS_"+direction_str_1+"/events/2d/north_PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_PS_"+direction_str_1+"/events/2d/south_PS_"+direction_str_1+"_imfBy_-25_0__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path_2+"/hemi_south/"+grid_str_1+"/south_PS_"+direction_str_1+"/events/2d/south_PS_"+direction_str_1+"_imfBy_0_25__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
  ]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-g6XRjs59xtcZFyup8QvsaV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-g6XRjs59xtcZFyup8QvsaV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-g6XRjs59xtcZFyup8QvsaV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-g6XRjs59xtcZFyup8QvsaV:checked ~ #ipyplot-html-viewer-textarea-g6XRjs59xtcZFyup8QvsaV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-g6XRjs59xtcZFyup8QvsaV:checked + #ipyplot-html-viewer-label-g6XRjs59xtcZFyup8QvsaV:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
         , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
      ,   
    

non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1_100__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7TZzVQC8GpLnigzAAWRg9W {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7TZzVQC8GpLnigzAAWRg9W {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7TZzVQC8GpLnigzAAWRg9W {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7TZzVQC8GpLnigzAAWRg9W:checked ~ #ipyplot-html-viewer-textarea-7TZzVQC8GpLnigzAAWRg9W {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7TZzVQC8GpLnigzAAWRg9W:checked + #ipyplot-html-viewer-label-7TZzVQC8GpLnigzAAWRg9W:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
        non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
         , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
      ,   
    

non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_100_1000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BmYviHmjE48rLVPFTo3TEC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BmYviHmjE48rLVPFTo3TEC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BmYviHmjE48rLVPFTo3TEC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BmYviHmjE48rLVPFTo3TEC:checked ~ #ipyplot-html-viewer-textarea-BmYviHmjE48rLVPFTo3TEC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BmYviHmjE48rLVPFTo3TEC:checked + #ipyplot-html-viewer-label-BmYviHmjE48rLVPFTo3TEC:after {
# ...

# %% [markdown]
# ### 1000 - 3000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
         , non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/Lobe_"+direction_str_1+"/events/2d/Lobe_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_1+"/BL_"+direction_str_1+"/events/2d/BL_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_1+"/"+grid_str_1+"/PS_"+direction_str_1+"/events/2d/PS_"+direction_str_1+"_en_1000_3000__ratio_"+start_time_1+"_to_"+end_time_1+"_Y_GSM_vs_Z_GSM.png"
      ,   
    

non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"_en_1000_3000__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"_en_1000_3000__ratio_"+start_time_2+"_to_"+end_time_2+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path_2+"/"+grid_str_2+"/PS_"+direction_str_2+"/events/2d/PS_"+direction_str_2+"_en_1000_3000__ratio_"+start_time_2+"_to_"+end_time_2+"_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-378CR59BARkAorPFoWAjiX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-378CR59BARkAorPFoWAjiX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-378CR59BARkAorPFoWAjiX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-378CR59BARkAorPFoWAjiX:checked ~ #ipyplot-html-viewer-textarea-378CR59BARkAorPFoWAjiX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-378CR59BARkAorPFoWAjiX:checked + #ipyplot-html-viewer-label-378CR59BARkAorPFoWAjiX:after {
# ...
