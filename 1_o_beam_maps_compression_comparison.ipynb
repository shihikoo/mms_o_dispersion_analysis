# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aiuJH8yPRibZxo8xzBSQa4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aiuJH8yPRibZxo8xzBSQa4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aiuJH8yPRibZxo8xzBSQa4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aiuJH8yPRibZxo8xzBSQa4:checked ~ #ipyplot-html-viewer-textarea-aiuJH8yPRibZxo8xzBSQa4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aiuJH8yPRibZxo8xzBSQa4:checked + #ipyplot-html-viewer-label-aiuJH8yPRibZxo8xzBSQa4:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LT6RJ48Y4EZTLzgr5ZsH9U {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LT6RJ48Y4EZTLzgr5ZsH9U {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LT6RJ48Y4EZTLzgr5ZsH9U {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LT6RJ48Y4EZTLzgr5ZsH9U:checked ~ #ipyplot-html-viewer-textarea-LT6RJ48Y4EZTLzgr5ZsH9U {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LT6RJ48Y4EZTLzgr5ZsH9U:checked + #ipyplot-html-viewer-label-LT6RJ48Y4EZTLzgr5ZsH9U:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-bzrXbp4NvY5MY3nF6rx7dx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bzrXbp4NvY5MY3nF6rx7dx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bzrXbp4NvY5MY3nF6rx7dx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bzrXbp4NvY5MY3nF6rx7dx:checked ~ #ipyplot-html-viewer-textarea-bzrXbp4NvY5MY3nF6rx7dx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bzrXbp4NvY5MY3nF6rx7dx:checked + #ipyplot-html-viewer-label-bzrXbp4NvY5MY3nF6rx7dx:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-24jaL5xgoN8aXTKQutdZ9F {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-24jaL5xgoN8aXTKQutdZ9F {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-24jaL5xgoN8aXTKQutdZ9F {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-24jaL5xgoN8aXTKQutdZ9F:checked ~ #ipyplot-html-viewer-textarea-24jaL5xgoN8aXTKQutdZ9F {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-24jaL5xgoN8aXTKQutdZ9F:checked + #ipyplot-html-viewer-label-24jaL5xgoN8aXTKQutdZ9F:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190417_to_20190817_DIST_vs_Beta.png"
    ,    with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
    , with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190417_to_20190817_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aU4t6xgQpYBfqpYLuEz7bj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aU4t6xgQpYBfqpYLuEz7bj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aU4t6xgQpYBfqpYLuEz7bj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aU4t6xgQpYBfqpYLuEz7bj:checked ~ #ipyplot-html-viewer-textarea-aU4t6xgQpYBfqpYLuEz7bj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aU4t6xgQpYBfqpYLuEz7bj:checked + #ipyplot-html-viewer-label-aU4t6xgQpYBfqpYLuEz7bj:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" ,with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"     
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"   
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hXnPBTAjQk9itG2yDLYqEw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hXnPBTAjQk9itG2yDLYqEw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hXnPBTAjQk9itG2yDLYqEw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hXnPBTAjQk9itG2yDLYqEw:checked ~ #ipyplot-html-viewer-textarea-hXnPBTAjQk9itG2yDLYqEw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hXnPBTAjQk9itG2yDLYqEw:checked + #ipyplot-html-viewer-label-hXnPBTAjQk9itG2yDLYqEw:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"     ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MYUFPvmDPcHuhEgBfFVToj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MYUFPvmDPcHuhEgBfFVToj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MYUFPvmDPcHuhEgBfFVToj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MYUFPvmDPcHuhEgBfFVToj:checked ~ #ipyplot-html-viewer-textarea-MYUFPvmDPcHuhEgBfFVToj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MYUFPvmDPcHuhEgBfFVToj:checked + #ipyplot-html-viewer-label-MYUFPvmDPcHuhEgBfFVToj:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
    hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png" ,    with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
        ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-78NQxZZTyTtud4ZGRA5yGC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-78NQxZZTyTtud4ZGRA5yGC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-78NQxZZTyTtud4ZGRA5yGC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-78NQxZZTyTtud4ZGRA5yGC:checked ~ #ipyplot-html-viewer-textarea-78NQxZZTyTtud4ZGRA5yGC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-78NQxZZTyTtud4ZGRA5yGC:checked + #ipyplot-html-viewer-label-78NQxZZTyTtud4ZGRA5yGC:after {
# ...

# %%
with_reduced_non_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
# Out:
# 'idl_plots/plots_with_reduced/non_sort_map/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png'

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png",  non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png",
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png",  with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png",
    
non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
        , 
   
with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
     , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,      non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"  

     , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"

    ,      with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7HEcN9fuoxQLKMriFkzXvm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7HEcN9fuoxQLKMriFkzXvm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7HEcN9fuoxQLKMriFkzXvm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7HEcN9fuoxQLKMriFkzXvm:checked ~ #ipyplot-html-viewer-textarea-7HEcN9fuoxQLKMriFkzXvm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7HEcN9fuoxQLKMriFkzXvm:checked + #ipyplot-html-viewer-label-7HEcN9fuoxQLKMriFkzXvm:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-k2wesPxnACQ3MzjPUQcCv2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-k2wesPxnACQ3MzjPUQcCv2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-k2wesPxnACQ3MzjPUQcCv2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-k2wesPxnACQ3MzjPUQcCv2:checked ~ #ipyplot-html-viewer-textarea-k2wesPxnACQ3MzjPUQcCv2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-k2wesPxnACQ3MzjPUQcCv2:checked + #ipyplot-html-viewer-label-k2wesPxnACQ3MzjPUQcCv2:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
        , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RJSYzkyWw7NQrVrzCCtjUm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RJSYzkyWw7NQrVrzCCtjUm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RJSYzkyWw7NQrVrzCCtjUm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RJSYzkyWw7NQrVrzCCtjUm:checked ~ #ipyplot-html-viewer-textarea-RJSYzkyWw7NQrVrzCCtjUm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RJSYzkyWw7NQrVrzCCtjUm:checked + #ipyplot-html-viewer-label-RJSYzkyWw7NQrVrzCCtjUm:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"       , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
            ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 

    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-VGgjjCddFvmdTiJ8ScgKAa {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VGgjjCddFvmdTiJ8ScgKAa {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VGgjjCddFvmdTiJ8ScgKAa {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VGgjjCddFvmdTiJ8ScgKAa:checked ~ #ipyplot-html-viewer-textarea-VGgjjCddFvmdTiJ8ScgKAa {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VGgjjCddFvmdTiJ8ScgKAa:checked + #ipyplot-html-viewer-label-VGgjjCddFvmdTiJ8ScgKAa:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,     with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
  ]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Btk65wYhvEC7Uj4GndGCic {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Btk65wYhvEC7Uj4GndGCic {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Btk65wYhvEC7Uj4GndGCic {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Btk65wYhvEC7Uj4GndGCic:checked ~ #ipyplot-html-viewer-textarea-Btk65wYhvEC7Uj4GndGCic {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Btk65wYhvEC7Uj4GndGCic:checked + #ipyplot-html-viewer-label-Btk65wYhvEC7Uj4GndGCic:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KJwMgVRG3JeZFn2wJNiQy5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KJwMgVRG3JeZFn2wJNiQy5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KJwMgVRG3JeZFn2wJNiQy5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KJwMgVRG3JeZFn2wJNiQy5:checked ~ #ipyplot-html-viewer-textarea-KJwMgVRG3JeZFn2wJNiQy5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KJwMgVRG3JeZFn2wJNiQy5:checked + #ipyplot-html-viewer-label-KJwMgVRG3JeZFn2wJNiQy5:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cYcE4raJ7bffP65aFrbhpK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cYcE4raJ7bffP65aFrbhpK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cYcE4raJ7bffP65aFrbhpK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cYcE4raJ7bffP65aFrbhpK:checked ~ #ipyplot-html-viewer-textarea-cYcE4raJ7bffP65aFrbhpK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cYcE4raJ7bffP65aFrbhpK:checked + #ipyplot-html-viewer-label-cYcE4raJ7bffP65aFrbhpK:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7zTFue34ZoLd8Zww5aub4V {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7zTFue34ZoLd8Zww5aub4V {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7zTFue34ZoLd8Zww5aub4V {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7zTFue34ZoLd8Zww5aub4V:checked ~ #ipyplot-html-viewer-textarea-7zTFue34ZoLd8Zww5aub4V {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7zTFue34ZoLd8Zww5aub4V:checked + #ipyplot-html-viewer-label-7zTFue34ZoLd8Zww5aub4V:after {
# ...
