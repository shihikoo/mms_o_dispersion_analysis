# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"
with_reduced_kp_sort_map_path = main_plot_path+'plots_with_reduced/kp_sort_map'
with_reduced_bx_sort_map_path = main_plot_path+'plots_with_reduced/bx_sort_map'

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"
kp_sort_map_path = main_plot_path+'plots_original/kp_sort_map'
bx_sort_map_path = main_plot_path+'plots_original/bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
        , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KDZBUq6cb2EQKc3SnrmG74 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KDZBUq6cb2EQKc3SnrmG74 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KDZBUq6cb2EQKc3SnrmG74 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KDZBUq6cb2EQKc3SnrmG74:checked ~ #ipyplot-html-viewer-textarea-KDZBUq6cb2EQKc3SnrmG74 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KDZBUq6cb2EQKc3SnrmG74:checked + #ipyplot-html-viewer-label-KDZBUq6cb2EQKc3SnrmG74:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nBgVGxszWYxaRsms4pxXBc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nBgVGxszWYxaRsms4pxXBc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nBgVGxszWYxaRsms4pxXBc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nBgVGxszWYxaRsms4pxXBc:checked ~ #ipyplot-html-viewer-textarea-nBgVGxszWYxaRsms4pxXBc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nBgVGxszWYxaRsms4pxXBc:checked + #ipyplot-html-viewer-label-nBgVGxszWYxaRsms4pxXBc:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png",with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
,with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gGKvtcSDK8bCvuDj3pUQNi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gGKvtcSDK8bCvuDj3pUQNi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gGKvtcSDK8bCvuDj3pUQNi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gGKvtcSDK8bCvuDj3pUQNi:checked ~ #ipyplot-html-viewer-textarea-gGKvtcSDK8bCvuDj3pUQNi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gGKvtcSDK8bCvuDj3pUQNi:checked + #ipyplot-html-viewer-label-gGKvtcSDK8bCvuDj3pUQNi:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    ,
    with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
       , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"       , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7jpyiCcuFRP8yJ955LgFrE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7jpyiCcuFRP8yJ955LgFrE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7jpyiCcuFRP8yJ955LgFrE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7jpyiCcuFRP8yJ955LgFrE:checked ~ #ipyplot-html-viewer-textarea-7jpyiCcuFRP8yJ955LgFrE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7jpyiCcuFRP8yJ955LgFrE:checked + #ipyplot-html-viewer-label-7jpyiCcuFRP8yJ955LgFrE:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png" ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"    
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"   
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
  , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6FDjma5aCP3vRaE6ovtxYP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6FDjma5aCP3vRaE6ovtxYP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6FDjma5aCP3vRaE6ovtxYP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6FDjma5aCP3vRaE6ovtxYP:checked ~ #ipyplot-html-viewer-textarea-6FDjma5aCP3vRaE6ovtxYP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6FDjma5aCP3vRaE6ovtxYP:checked + #ipyplot-html-viewer-label-6FDjma5aCP3vRaE6ovtxYP:after {
# ...

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
        , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
       , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"   , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2d3VB2k8P6fZZwfvVdQRNj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2d3VB2k8P6fZZwfvVdQRNj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2d3VB2k8P6fZZwfvVdQRNj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2d3VB2k8P6fZZwfvVdQRNj:checked ~ #ipyplot-html-viewer-textarea-2d3VB2k8P6fZZwfvVdQRNj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2d3VB2k8P6fZZwfvVdQRNj:checked + #ipyplot-html-viewer-label-2d3VB2k8P6fZZwfvVdQRNj:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2tMmwgKbb7mXXdsGQs8UUf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2tMmwgKbb7mXXdsGQs8UUf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2tMmwgKbb7mXXdsGQs8UUf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2tMmwgKbb7mXXdsGQs8UUf:checked ~ #ipyplot-html-viewer-textarea-2tMmwgKbb7mXXdsGQs8UUf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2tMmwgKbb7mXXdsGQs8UUf:checked + #ipyplot-html-viewer-label-2tMmwgKbb7mXXdsGQs8UUf:after {
# ...
