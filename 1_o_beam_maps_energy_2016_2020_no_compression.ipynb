# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "plots_avoid_compression/non_sort_map"
hemi_sort_map_path = "plots_avoid_compression/hemi_sort_map"

kp_sort_map_path = 'plots_avoid_compression/kp_sort_map'
bx_sort_map_path = 'plots_avoid_compression/bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-96KDyiex3PGHcurJsWLBTV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-96KDyiex3PGHcurJsWLBTV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-96KDyiex3PGHcurJsWLBTV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-96KDyiex3PGHcurJsWLBTV:checked ~ #ipyplot-html-viewer-textarea-96KDyiex3PGHcurJsWLBTV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-96KDyiex3PGHcurJsWLBTV:checked + #ipyplot-html-viewer-label-96KDyiex3PGHcurJsWLBTV:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UNHCW45GUwWCqGPLTxD9SH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UNHCW45GUwWCqGPLTxD9SH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UNHCW45GUwWCqGPLTxD9SH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UNHCW45GUwWCqGPLTxD9SH:checked ~ #ipyplot-html-viewer-textarea-UNHCW45GUwWCqGPLTxD9SH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UNHCW45GUwWCqGPLTxD9SH:checked + #ipyplot-html-viewer-label-UNHCW45GUwWCqGPLTxD9SH:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3frmUeuAsPnGTGp6S4ycAK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3frmUeuAsPnGTGp6S4ycAK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3frmUeuAsPnGTGp6S4ycAK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3frmUeuAsPnGTGp6S4ycAK:checked ~ #ipyplot-html-viewer-textarea-3frmUeuAsPnGTGp6S4ycAK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3frmUeuAsPnGTGp6S4ycAK:checked + #ipyplot-html-viewer-label-3frmUeuAsPnGTGp6S4ycAK:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
       , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nd3yqZXCkSxKmuPdwTJKyF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nd3yqZXCkSxKmuPdwTJKyF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nd3yqZXCkSxKmuPdwTJKyF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nd3yqZXCkSxKmuPdwTJKyF:checked ~ #ipyplot-html-viewer-textarea-nd3yqZXCkSxKmuPdwTJKyF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nd3yqZXCkSxKmuPdwTJKyF:checked + #ipyplot-html-viewer-label-nd3yqZXCkSxKmuPdwTJKyF:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Vc7f8GnfXHyZbbytxSJaii {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Vc7f8GnfXHyZbbytxSJaii {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Vc7f8GnfXHyZbbytxSJaii {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Vc7f8GnfXHyZbbytxSJaii:checked ~ #ipyplot-html-viewer-textarea-Vc7f8GnfXHyZbbytxSJaii {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Vc7f8GnfXHyZbbytxSJaii:checked + #ipyplot-html-viewer-label-Vc7f8GnfXHyZbbytxSJaii:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nqtd6SPPb2vSH6jYhvJfAA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nqtd6SPPb2vSH6jYhvJfAA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nqtd6SPPb2vSH6jYhvJfAA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nqtd6SPPb2vSH6jYhvJfAA:checked ~ #ipyplot-html-viewer-textarea-nqtd6SPPb2vSH6jYhvJfAA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nqtd6SPPb2vSH6jYhvJfAA:checked + #ipyplot-html-viewer-label-nqtd6SPPb2vSH6jYhvJfAA:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hpNoB5AwCL7MGFBc4YyKGf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hpNoB5AwCL7MGFBc4YyKGf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hpNoB5AwCL7MGFBc4YyKGf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hpNoB5AwCL7MGFBc4YyKGf:checked ~ #ipyplot-html-viewer-textarea-hpNoB5AwCL7MGFBc4YyKGf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hpNoB5AwCL7MGFBc4YyKGf:checked + #ipyplot-html-viewer-label-hpNoB5AwCL7MGFBc4YyKGf:after {
# ...

# %% [markdown]
# ## kp impacts on the convection maps

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZPKuWZ4q9iZJzXna8YELiv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZPKuWZ4q9iZJzXna8YELiv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZPKuWZ4q9iZJzXna8YELiv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZPKuWZ4q9iZJzXna8YELiv:checked ~ #ipyplot-html-viewer-textarea-ZPKuWZ4q9iZJzXna8YELiv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZPKuWZ4q9iZJzXna8YELiv:checked + #ipyplot-html-viewer-label-ZPKuWZ4q9iZJzXna8YELiv:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dwS8bovE5PY5yeokHDeyxf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dwS8bovE5PY5yeokHDeyxf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dwS8bovE5PY5yeokHDeyxf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dwS8bovE5PY5yeokHDeyxf:checked ~ #ipyplot-html-viewer-textarea-dwS8bovE5PY5yeokHDeyxf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dwS8bovE5PY5yeokHDeyxf:checked + #ipyplot-html-viewer-label-dwS8bovE5PY5yeokHDeyxf:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HTFaD5nUivVHeZv3wA9SUG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HTFaD5nUivVHeZv3wA9SUG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HTFaD5nUivVHeZv3wA9SUG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HTFaD5nUivVHeZv3wA9SUG:checked ~ #ipyplot-html-viewer-textarea-HTFaD5nUivVHeZv3wA9SUG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HTFaD5nUivVHeZv3wA9SUG:checked + #ipyplot-html-viewer-label-HTFaD5nUivVHeZv3wA9SUG:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NqGfveK7tTrivaL2ZhkXky {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NqGfveK7tTrivaL2ZhkXky {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NqGfveK7tTrivaL2ZhkXky {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NqGfveK7tTrivaL2ZhkXky:checked ~ #ipyplot-html-viewer-textarea-NqGfveK7tTrivaL2ZhkXky {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NqGfveK7tTrivaL2ZhkXky:checked + #ipyplot-html-viewer-label-NqGfveK7tTrivaL2ZhkXky:after {
# ...

# %% [markdown]
# ## Storm impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nudX322ZBtAaapy5DeWRvB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nudX322ZBtAaapy5DeWRvB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nudX322ZBtAaapy5DeWRvB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nudX322ZBtAaapy5DeWRvB:checked ~ #ipyplot-html-viewer-textarea-nudX322ZBtAaapy5DeWRvB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nudX322ZBtAaapy5DeWRvB:checked + #ipyplot-html-viewer-label-nudX322ZBtAaapy5DeWRvB:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JPKXd2jHdoXjHvbRQnH6n4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JPKXd2jHdoXjHvbRQnH6n4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JPKXd2jHdoXjHvbRQnH6n4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JPKXd2jHdoXjHvbRQnH6n4:checked ~ #ipyplot-html-viewer-textarea-JPKXd2jHdoXjHvbRQnH6n4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JPKXd2jHdoXjHvbRQnH6n4:checked + #ipyplot-html-viewer-label-JPKXd2jHdoXjHvbRQnH6n4:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_0_450_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_450_900_median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dpKLVvGoNEeXcP3CgwaPsF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dpKLVvGoNEeXcP3CgwaPsF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dpKLVvGoNEeXcP3CgwaPsF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dpKLVvGoNEeXcP3CgwaPsF:checked ~ #ipyplot-html-viewer-textarea-dpKLVvGoNEeXcP3CgwaPsF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dpKLVvGoNEeXcP3CgwaPsF:checked + #ipyplot-html-viewer-label-dpKLVvGoNEeXcP3CgwaPsF:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20160101_to_20201231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-U3aLLJmAimpQbQUvKj3ZBH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-U3aLLJmAimpQbQUvKj3ZBH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-U3aLLJmAimpQbQUvKj3ZBH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-U3aLLJmAimpQbQUvKj3ZBH:checked ~ #ipyplot-html-viewer-textarea-U3aLLJmAimpQbQUvKj3ZBH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-U3aLLJmAimpQbQUvKj3ZBH:checked + #ipyplot-html-viewer-label-U3aLLJmAimpQbQUvKj3ZBH:after {
# ...
