# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"
with_reduced_kp_sort_map_path = main_plot_path+'plots_with_reduced/kp_sort_map'
with_reduced_bx_sort_map_path = main_plot_path+'plots_with_reduced/bx_sort_map'

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"
kp_sort_map_path = main_plot_path+'plots_original/kp_sort_map'
bx_sort_map_path = main_plot_path+'plots_original/bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
        , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Y6sJxdcvcLHsTedB7FxXm3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Y6sJxdcvcLHsTedB7FxXm3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Y6sJxdcvcLHsTedB7FxXm3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Y6sJxdcvcLHsTedB7FxXm3:checked ~ #ipyplot-html-viewer-textarea-Y6sJxdcvcLHsTedB7FxXm3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Y6sJxdcvcLHsTedB7FxXm3:checked + #ipyplot-html-viewer-label-Y6sJxdcvcLHsTedB7FxXm3:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UgBZbCix6XqGeAzE7hgryg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UgBZbCix6XqGeAzE7hgryg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UgBZbCix6XqGeAzE7hgryg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UgBZbCix6XqGeAzE7hgryg:checked ~ #ipyplot-html-viewer-textarea-UgBZbCix6XqGeAzE7hgryg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UgBZbCix6XqGeAzE7hgryg:checked + #ipyplot-html-viewer-label-UgBZbCix6XqGeAzE7hgryg:after {
# ...

# %%
       with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
# Out:
# 'idl_plots/plots_with_reduced/non_sort_map/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png'

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png",with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
,with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PYxovRLVQCT4rLSfxWKewZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PYxovRLVQCT4rLSfxWKewZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PYxovRLVQCT4rLSfxWKewZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PYxovRLVQCT4rLSfxWKewZ:checked ~ #ipyplot-html-viewer-textarea-PYxovRLVQCT4rLSfxWKewZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PYxovRLVQCT4rLSfxWKewZ:checked + #ipyplot-html-viewer-label-PYxovRLVQCT4rLSfxWKewZ:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"    ,
    with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
       , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"       , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HPYWmNp9qt3UuxpTTzo5mp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HPYWmNp9qt3UuxpTTzo5mp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HPYWmNp9qt3UuxpTTzo5mp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HPYWmNp9qt3UuxpTTzo5mp:checked ~ #ipyplot-html-viewer-textarea-HPYWmNp9qt3UuxpTTzo5mp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HPYWmNp9qt3UuxpTTzo5mp:checked + #ipyplot-html-viewer-label-HPYWmNp9qt3UuxpTTzo5mp:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png" ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"    
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"   
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
, hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
, with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
  , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZvpioB583FfwhZhMJb4bT3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZvpioB583FfwhZhMJb4bT3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZvpioB583FfwhZhMJb4bT3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZvpioB583FfwhZhMJb4bT3:checked ~ #ipyplot-html-viewer-textarea-ZvpioB583FfwhZhMJb4bT3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZvpioB583FfwhZhMJb4bT3:checked + #ipyplot-html-viewer-label-ZvpioB583FfwhZhMJb4bT3:after {
# ...

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
        , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
       , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"   , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jrNHeGQ3XB4VcAbgprxDAs {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jrNHeGQ3XB4VcAbgprxDAs {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jrNHeGQ3XB4VcAbgprxDAs {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jrNHeGQ3XB4VcAbgprxDAs:checked ~ #ipyplot-html-viewer-textarea-jrNHeGQ3XB4VcAbgprxDAs {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jrNHeGQ3XB4VcAbgprxDAs:checked + #ipyplot-html-viewer-label-jrNHeGQ3XB4VcAbgprxDAs:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
   ,with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20190417_to_20190817_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nrdwCf3RVpdPVXXo63oQWw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nrdwCf3RVpdPVXXo63oQWw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nrdwCf3RVpdPVXXo63oQWw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nrdwCf3RVpdPVXXo63oQWw:checked ~ #ipyplot-html-viewer-textarea-nrdwCf3RVpdPVXXo63oQWw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nrdwCf3RVpdPVXXo63oQWw:checked + #ipyplot-html-viewer-label-nrdwCf3RVpdPVXXo63oQWw:after {
# ...
