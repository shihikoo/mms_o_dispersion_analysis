# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dHYLo6x3U6GpNooxzdwiMX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dHYLo6x3U6GpNooxzdwiMX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dHYLo6x3U6GpNooxzdwiMX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dHYLo6x3U6GpNooxzdwiMX:checked ~ #ipyplot-html-viewer-textarea-dHYLo6x3U6GpNooxzdwiMX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dHYLo6x3U6GpNooxzdwiMX:checked + #ipyplot-html-viewer-label-dHYLo6x3U6GpNooxzdwiMX:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-idFBaLZiWcq8aRQtmyXMgm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-idFBaLZiWcq8aRQtmyXMgm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-idFBaLZiWcq8aRQtmyXMgm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-idFBaLZiWcq8aRQtmyXMgm:checked ~ #ipyplot-html-viewer-textarea-idFBaLZiWcq8aRQtmyXMgm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-idFBaLZiWcq8aRQtmyXMgm:checked + #ipyplot-html-viewer-label-idFBaLZiWcq8aRQtmyXMgm:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iwWxprX3pEceciYuAbpy2j {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iwWxprX3pEceciYuAbpy2j {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iwWxprX3pEceciYuAbpy2j {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iwWxprX3pEceciYuAbpy2j:checked ~ #ipyplot-html-viewer-textarea-iwWxprX3pEceciYuAbpy2j {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iwWxprX3pEceciYuAbpy2j:checked + #ipyplot-html-viewer-label-iwWxprX3pEceciYuAbpy2j:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XSdJ6acdWmtth29s2Y4own {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XSdJ6acdWmtth29s2Y4own {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XSdJ6acdWmtth29s2Y4own {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XSdJ6acdWmtth29s2Y4own:checked ~ #ipyplot-html-viewer-textarea-XSdJ6acdWmtth29s2Y4own {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XSdJ6acdWmtth29s2Y4own:checked + #ipyplot-html-viewer-label-XSdJ6acdWmtth29s2Y4own:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_DIST_vs_Beta.png"
    ,    with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_X_GSM_vs_Beta.png"
    , with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-B3gxKggw3sM3aBtHDpwZ9g {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-B3gxKggw3sM3aBtHDpwZ9g {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-B3gxKggw3sM3aBtHDpwZ9g {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-B3gxKggw3sM3aBtHDpwZ9g:checked ~ #ipyplot-html-viewer-textarea-B3gxKggw3sM3aBtHDpwZ9g {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-B3gxKggw3sM3aBtHDpwZ9g:checked + #ipyplot-html-viewer-label-B3gxKggw3sM3aBtHDpwZ9g:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XZgsm for dawn, center and dusk in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" ,with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"     
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"   
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LxmRYVZXQjt2UXm4FrN24f {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LxmRYVZXQjt2UXm4FrN24f {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LxmRYVZXQjt2UXm4FrN24f {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LxmRYVZXQjt2UXm4FrN24f:checked ~ #ipyplot-html-viewer-textarea-LxmRYVZXQjt2UXm4FrN24f {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LxmRYVZXQjt2UXm4FrN24f:checked + #ipyplot-html-viewer-label-LxmRYVZXQjt2UXm4FrN24f:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"     ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3na79LWN5TfhwQP32NPSGk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3na79LWN5TfhwQP32NPSGk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3na79LWN5TfhwQP32NPSGk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3na79LWN5TfhwQP32NPSGk:checked ~ #ipyplot-html-viewer-textarea-3na79LWN5TfhwQP32NPSGk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3na79LWN5TfhwQP32NPSGk:checked + #ipyplot-html-viewer-label-3na79LWN5TfhwQP32NPSGk:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
    hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png" ,    with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
        ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CvWRC5JznvFUzLEsNEGXnm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CvWRC5JznvFUzLEsNEGXnm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CvWRC5JznvFUzLEsNEGXnm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CvWRC5JznvFUzLEsNEGXnm:checked ~ #ipyplot-html-viewer-textarea-CvWRC5JznvFUzLEsNEGXnm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CvWRC5JznvFUzLEsNEGXnm:checked + #ipyplot-html-viewer-label-CvWRC5JznvFUzLEsNEGXnm:after {
# ...

# %%
with_reduced_non_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
# Out:
# 'idl_plots/plots_with_reduced/non_sort_map/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png'

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png",  non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png",
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png",  with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png",
    
non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
        , 
   
with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
     , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,      non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"  

     , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"

    ,      with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gY7Ejbrju8pXoWFAjAxRFo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gY7Ejbrju8pXoWFAjAxRFo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gY7Ejbrju8pXoWFAjAxRFo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gY7Ejbrju8pXoWFAjAxRFo:checked ~ #ipyplot-html-viewer-textarea-gY7Ejbrju8pXoWFAjAxRFo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gY7Ejbrju8pXoWFAjAxRFo:checked + #ipyplot-html-viewer-label-gY7Ejbrju8pXoWFAjAxRFo:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-98cDWmsWPCmNZsiNyERpBx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-98cDWmsWPCmNZsiNyERpBx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-98cDWmsWPCmNZsiNyERpBx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-98cDWmsWPCmNZsiNyERpBx:checked ~ #ipyplot-html-viewer-textarea-98cDWmsWPCmNZsiNyERpBx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-98cDWmsWPCmNZsiNyERpBx:checked + #ipyplot-html-viewer-label-98cDWmsWPCmNZsiNyERpBx:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
        , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2M7xJjAvcf4F2Gn7NwisJH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2M7xJjAvcf4F2Gn7NwisJH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2M7xJjAvcf4F2Gn7NwisJH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2M7xJjAvcf4F2Gn7NwisJH:checked ~ #ipyplot-html-viewer-textarea-2M7xJjAvcf4F2Gn7NwisJH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2M7xJjAvcf4F2Gn7NwisJH:checked + #ipyplot-html-viewer-label-2M7xJjAvcf4F2Gn7NwisJH:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"       , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
            ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 

    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Bj9MZVZw4ogKBvzE48ZhAT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Bj9MZVZw4ogKBvzE48ZhAT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Bj9MZVZw4ogKBvzE48ZhAT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Bj9MZVZw4ogKBvzE48ZhAT:checked ~ #ipyplot-html-viewer-textarea-Bj9MZVZw4ogKBvzE48ZhAT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Bj9MZVZw4ogKBvzE48ZhAT:checked + #ipyplot-html-viewer-label-Bj9MZVZw4ogKBvzE48ZhAT:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,     with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
  ]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jgWkj2t574pkiyjkHnUY9u {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jgWkj2t574pkiyjkHnUY9u {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jgWkj2t574pkiyjkHnUY9u {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jgWkj2t574pkiyjkHnUY9u:checked ~ #ipyplot-html-viewer-textarea-jgWkj2t574pkiyjkHnUY9u {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jgWkj2t574pkiyjkHnUY9u:checked + #ipyplot-html-viewer-label-jgWkj2t574pkiyjkHnUY9u:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-StxJfcCSy3pjUKxGBSRfWE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-StxJfcCSy3pjUKxGBSRfWE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-StxJfcCSy3pjUKxGBSRfWE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-StxJfcCSy3pjUKxGBSRfWE:checked ~ #ipyplot-html-viewer-textarea-StxJfcCSy3pjUKxGBSRfWE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-StxJfcCSy3pjUKxGBSRfWE:checked + #ipyplot-html-viewer-label-StxJfcCSy3pjUKxGBSRfWE:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Q8jvUCV8AEvu7nnaZMfjSc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Q8jvUCV8AEvu7nnaZMfjSc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Q8jvUCV8AEvu7nnaZMfjSc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Q8jvUCV8AEvu7nnaZMfjSc:checked ~ #ipyplot-html-viewer-textarea-Q8jvUCV8AEvu7nnaZMfjSc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Q8jvUCV8AEvu7nnaZMfjSc:checked + #ipyplot-html-viewer-label-Q8jvUCV8AEvu7nnaZMfjSc:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-H5oqUy27yazv3TASXYVspr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-H5oqUy27yazv3TASXYVspr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-H5oqUy27yazv3TASXYVspr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-H5oqUy27yazv3TASXYVspr:checked ~ #ipyplot-html-viewer-textarea-H5oqUy27yazv3TASXYVspr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-H5oqUy27yazv3TASXYVspr:checked + #ipyplot-html-viewer-label-H5oqUy27yazv3TASXYVspr:after {
# ...
