# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/output_5min_multi_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots_only_no_compression_ss27/"

start_time = '20160101'
end_time = '20201231'

non_sort_map_path = main_plot_path+"non_sort_map"
hemi_sort_map_path = main_plot_path+"hemi_sort_map"
kp_sort_map_path = main_plot_path+'kp_sort_map'
bx_sort_map_path = main_plot_path+'bx_sort_map'

grid_str = "grid_03"

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__median_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/any/energy/2d/any__minimum_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ePA7REZjJKHDggZiGRv5fe {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ePA7REZjJKHDggZiGRv5fe {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ePA7REZjJKHDggZiGRv5fe {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ePA7REZjJKHDggZiGRv5fe:checked ~ #ipyplot-html-viewer-textarea-ePA7REZjJKHDggZiGRv5fe {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ePA7REZjJKHDggZiGRv5fe:checked + #ipyplot-html-viewer-label-ePA7REZjJKHDggZiGRv5fe:after {
# ...

# %% [markdown]
# ## Sliced median enegy maps in different regions

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-juN25B6JhpWDowq8Gbt3Xo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-juN25B6JhpWDowq8Gbt3Xo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-juN25B6JhpWDowq8Gbt3Xo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-juN25B6JhpWDowq8Gbt3Xo:checked ~ #ipyplot-html-viewer-textarea-juN25B6JhpWDowq8Gbt3Xo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-juN25B6JhpWDowq8Gbt3Xo:checked + #ipyplot-html-viewer-label-juN25B6JhpWDowq8Gbt3Xo:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__median_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__median_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nytyVUdsnELg2mv2YvhijN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nytyVUdsnELg2mv2YvhijN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nytyVUdsnELg2mv2YvhijN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nytyVUdsnELg2mv2YvhijN:checked ~ #ipyplot-html-viewer-textarea-nytyVUdsnELg2mv2YvhijN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nytyVUdsnELg2mv2YvhijN:checked + #ipyplot-html-viewer-label-nytyVUdsnELg2mv2YvhijN:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_any/energy/2d/Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
       , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_any/energy/2d/BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_any/energy/2d/PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kaAxpWNc7bC97rNTK84wLV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kaAxpWNc7bC97rNTK84wLV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kaAxpWNc7bC97rNTK84wLV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kaAxpWNc7bC97rNTK84wLV:checked ~ #ipyplot-html-viewer-textarea-kaAxpWNc7bC97rNTK84wLV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kaAxpWNc7bC97rNTK84wLV:checked + #ipyplot-html-viewer-label-kaAxpWNc7bC97rNTK84wLV:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_any/energy/2d/north_BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_any/energy/2d/north_PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
  ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_any/energy/2d/south_BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_any/energy/2d/south_PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ng4is4uHNuUQ8mtzj6Bwrs {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ng4is4uHNuUQ8mtzj6Bwrs {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ng4is4uHNuUQ8mtzj6Bwrs {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ng4is4uHNuUQ8mtzj6Bwrs:checked ~ #ipyplot-html-viewer-textarea-Ng4is4uHNuUQ8mtzj6Bwrs {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ng4is4uHNuUQ8mtzj6Bwrs:checked + #ipyplot-html-viewer-label-Ng4is4uHNuUQ8mtzj6Bwrs:after {
# ...

# %%
images_array = [
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_any/energy/2d/north_BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_any/energy/2d/north_PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
  , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_any/energy/2d/south_BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_any/energy/2d/south_PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-eywJa8mSEkAC7CsLYCtCCx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eywJa8mSEkAC7CsLYCtCCx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eywJa8mSEkAC7CsLYCtCCx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eywJa8mSEkAC7CsLYCtCCx:checked ~ #ipyplot-html-viewer-textarea-eywJa8mSEkAC7CsLYCtCCx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eywJa8mSEkAC7CsLYCtCCx:checked + #ipyplot-html-viewer-label-eywJa8mSEkAC7CsLYCtCCx:after {
# ...

# %% [markdown]
# ## kp impacts on the convection maps

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,  kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,  kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,  kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-9RjtfuoR6SGXPXwh7ePF6U {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9RjtfuoR6SGXPXwh7ePF6U {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9RjtfuoR6SGXPXwh7ePF6U {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9RjtfuoR6SGXPXwh7ePF6U:checked ~ #ipyplot-html-viewer-textarea-9RjtfuoR6SGXPXwh7ePF6U {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9RjtfuoR6SGXPXwh7ePF6U:checked + #ipyplot-html-viewer-label-9RjtfuoR6SGXPXwh7ePF6U:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MxWj83SYvBGFPhGmXcfCcF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MxWj83SYvBGFPhGmXcfCcF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MxWj83SYvBGFPhGmXcfCcF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MxWj83SYvBGFPhGmXcfCcF:checked ~ #ipyplot-html-viewer-textarea-MxWj83SYvBGFPhGmXcfCcF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MxWj83SYvBGFPhGmXcfCcF:checked + #ipyplot-html-viewer-label-MxWj83SYvBGFPhGmXcfCcF:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gPesbwmauLcB54ArsHZQY8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gPesbwmauLcB54ArsHZQY8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gPesbwmauLcB54ArsHZQY8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gPesbwmauLcB54ArsHZQY8:checked ~ #ipyplot-html-viewer-textarea-gPesbwmauLcB54ArsHZQY8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gPesbwmauLcB54ArsHZQY8:checked + #ipyplot-html-viewer-label-gPesbwmauLcB54ArsHZQY8:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ev4VNhyYTAWyRFATSm5SPc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ev4VNhyYTAWyRFATSm5SPc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ev4VNhyYTAWyRFATSm5SPc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ev4VNhyYTAWyRFATSm5SPc:checked ~ #ipyplot-html-viewer-textarea-ev4VNhyYTAWyRFATSm5SPc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ev4VNhyYTAWyRFATSm5SPc:checked + #ipyplot-html-viewer-label-ev4VNhyYTAWyRFATSm5SPc:after {
# ...

# %% [markdown]
# ## Storm impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/nonstorm_time_any/energy/2d/nonstorm_time_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_any/energy/2d/storm_time_any__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/nonstorm_time_any/energy/2d/nonstorm_time_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_any/energy/2d/storm_time_any__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SjUQ8fP3DVsiqov3Z2bvbD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SjUQ8fP3DVsiqov3Z2bvbD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SjUQ8fP3DVsiqov3Z2bvbD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SjUQ8fP3DVsiqov3Z2bvbD:checked ~ #ipyplot-html-viewer-textarea-SjUQ8fP3DVsiqov3Z2bvbD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SjUQ8fP3DVsiqov3Z2bvbD:checked + #ipyplot-html-viewer-label-SjUQ8fP3DVsiqov3Z2bvbD:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swV_0_450_median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swV_450_900_median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swV_0_450_minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swV_450_900_minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400
                   )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jyPCKAVN7obSCh2wFAKXoS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jyPCKAVN7obSCh2wFAKXoS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jyPCKAVN7obSCh2wFAKXoS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jyPCKAVN7obSCh2wFAKXoS:checked ~ #ipyplot-html-viewer-textarea-jyPCKAVN7obSCh2wFAKXoS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jyPCKAVN7obSCh2wFAKXoS:checked + #ipyplot-html-viewer-label-jyPCKAVN7obSCh2wFAKXoS:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swP_0_2__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swP_2_20__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swP_0_2__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/any/energy/2d/any_swP_2_20__minimum_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8iYtWGku776RwLN2bhBHg9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8iYtWGku776RwLN2bhBHg9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8iYtWGku776RwLN2bhBHg9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8iYtWGku776RwLN2bhBHg9:checked ~ #ipyplot-html-viewer-textarea-8iYtWGku776RwLN2bhBHg9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8iYtWGku776RwLN2bhBHg9:checked + #ipyplot-html-viewer-label-8iYtWGku776RwLN2bhBHg9:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
### South / north in median energy different regions for positive and negative IMF By
images_array = [
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jmzmwn8uhkFBXawrk9NCUv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jmzmwn8uhkFBXawrk9NCUv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jmzmwn8uhkFBXawrk9NCUv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jmzmwn8uhkFBXawrk9NCUv:checked ~ #ipyplot-html-viewer-textarea-jmzmwn8uhkFBXawrk9NCUv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jmzmwn8uhkFBXawrk9NCUv:checked + #ipyplot-html-viewer-label-jmzmwn8uhkFBXawrk9NCUv:after {
# ...
