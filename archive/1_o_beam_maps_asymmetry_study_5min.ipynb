# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "5min_non_sort_map"

# %% [markdown]
# # Overall Maps
#
# Dawn asymmetry near Earth and dusk asymmetry further down

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7wgHGXWcK4UXeo3jFsiZPm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7wgHGXWcK4UXeo3jFsiZPm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7wgHGXWcK4UXeo3jFsiZPm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7wgHGXWcK4UXeo3jFsiZPm:checked ~ #ipyplot-html-viewer-textarea-7wgHGXWcK4UXeo3jFsiZPm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7wgHGXWcK4UXeo3jFsiZPm:checked + #ipyplot-html-viewer-label-7wgHGXWcK4UXeo3jFsiZPm:after {
# ...

# %% [markdown]
# ## Different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DaNY7pfQM7KT2KS8otEeFQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DaNY7pfQM7KT2KS8otEeFQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DaNY7pfQM7KT2KS8otEeFQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DaNY7pfQM7KT2KS8otEeFQ:checked ~ #ipyplot-html-viewer-textarea-DaNY7pfQM7KT2KS8otEeFQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DaNY7pfQM7KT2KS8otEeFQ:checked + #ipyplot-html-viewer-label-DaNY7pfQM7KT2KS8otEeFQ:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth. Dawnside asymmetry is observed

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
,      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-D7EojRyjRYptWCNcPuTYRM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-D7EojRyjRYptWCNcPuTYRM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-D7EojRyjRYptWCNcPuTYRM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-D7EojRyjRYptWCNcPuTYRM:checked ~ #ipyplot-html-viewer-textarea-D7EojRyjRYptWCNcPuTYRM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-D7EojRyjRYptWCNcPuTYRM:checked + #ipyplot-html-viewer-label-D7EojRyjRYptWCNcPuTYRM:after {
# ...

# %% [markdown]
# ### 100 - 1000 eV
# Most observed near the Earth. Dawnside asymmetry observed.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
 ,      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HBTBDX7VD73pGPSgmi7Dv5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HBTBDX7VD73pGPSgmi7Dv5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HBTBDX7VD73pGPSgmi7Dv5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HBTBDX7VD73pGPSgmi7Dv5:checked ~ #ipyplot-html-viewer-textarea-HBTBDX7VD73pGPSgmi7Dv5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HBTBDX7VD73pGPSgmi7Dv5:checked + #ipyplot-html-viewer-label-HBTBDX7VD73pGPSgmi7Dv5:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dCPqATqhS6dVzJ9E9LvzxZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dCPqATqhS6dVzJ9E9LvzxZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dCPqATqhS6dVzJ9E9LvzxZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dCPqATqhS6dVzJ9E9LvzxZ:checked ~ #ipyplot-html-viewer-textarea-dCPqATqhS6dVzJ9E9LvzxZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dCPqATqhS6dVzJ9E9LvzxZ:checked + #ipyplot-html-viewer-label-dCPqATqhS6dVzJ9E9LvzxZ:after {
# ...

# %% [markdown]
# ## Review the year with different energy ranges
# ### 2016 (X-Y GSM project, 1-100 eV, 100-1000eV, 1000-40000eV)
# Same energy divided asymmtry found

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BDTYHznueLSW2h6bMBAqtd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BDTYHznueLSW2h6bMBAqtd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BDTYHznueLSW2h6bMBAqtd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BDTYHznueLSW2h6bMBAqtd:checked ~ #ipyplot-html-viewer-textarea-BDTYHznueLSW2h6bMBAqtd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BDTYHznueLSW2h6bMBAqtd:checked + #ipyplot-html-viewer-label-BDTYHznueLSW2h6bMBAqtd:after {
# ...

# %% [markdown]
# ### 2017 (X-Y GSM project, 1-100 eV, 100-1000eV, 1000-40000eV)
# Same energy divided asymmtry found

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MZt32PYXzKh6hg5hz5Zuwo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MZt32PYXzKh6hg5hz5Zuwo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MZt32PYXzKh6hg5hz5Zuwo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MZt32PYXzKh6hg5hz5Zuwo:checked ~ #ipyplot-html-viewer-textarea-MZt32PYXzKh6hg5hz5Zuwo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MZt32PYXzKh6hg5hz5Zuwo:checked + #ipyplot-html-viewer-label-MZt32PYXzKh6hg5hz5Zuwo:after {
# ...

# %% [markdown]
# ## IMF By / Bz sorted maps

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KtLYjNiDy6NsdWNXSNWGJi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KtLYjNiDy6NsdWNXSNWGJi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KtLYjNiDy6NsdWNXSNWGJi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KtLYjNiDy6NsdWNXSNWGJi:checked ~ #ipyplot-html-viewer-textarea-KtLYjNiDy6NsdWNXSNWGJi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KtLYjNiDy6NsdWNXSNWGJi:checked + #ipyplot-html-viewer-label-KtLYjNiDy6NsdWNXSNWGJi:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted Lobe maps

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_Lobe_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_Lobe_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TUauTRX3EEwvtsr7yXP4Lx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TUauTRX3EEwvtsr7yXP4Lx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TUauTRX3EEwvtsr7yXP4Lx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TUauTRX3EEwvtsr7yXP4Lx:checked ~ #ipyplot-html-viewer-textarea-TUauTRX3EEwvtsr7yXP4Lx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TUauTRX3EEwvtsr7yXP4Lx:checked + #ipyplot-html-viewer-label-TUauTRX3EEwvtsr7yXP4Lx:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted BL maps

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_BL_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_BL_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3oCRV6aZWwxPHWUj4Hogm5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3oCRV6aZWwxPHWUj4Hogm5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3oCRV6aZWwxPHWUj4Hogm5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3oCRV6aZWwxPHWUj4Hogm5:checked ~ #ipyplot-html-viewer-textarea-3oCRV6aZWwxPHWUj4Hogm5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3oCRV6aZWwxPHWUj4Hogm5:checked + #ipyplot-html-viewer-label-3oCRV6aZWwxPHWUj4Hogm5:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted PS maps

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_PS_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_PS_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-YjdxdGxXr4YWzgfxFLV2KH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-YjdxdGxXr4YWzgfxFLV2KH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-YjdxdGxXr4YWzgfxFLV2KH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-YjdxdGxXr4YWzgfxFLV2KH:checked ~ #ipyplot-html-viewer-textarea-YjdxdGxXr4YWzgfxFLV2KH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-YjdxdGxXr4YWzgfxFLV2KH:checked + #ipyplot-html-viewer-label-YjdxdGxXr4YWzgfxFLV2KH:after {
# ...

# %% [markdown]
# ## By / Bz sorted maps with different energy ranges
# ### 1-100eV

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_100_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1_100_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
               
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Snb7dqe4vyuwZjJXKg3zNQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Snb7dqe4vyuwZjJXKg3zNQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Snb7dqe4vyuwZjJXKg3zNQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Snb7dqe4vyuwZjJXKg3zNQ:checked ~ #ipyplot-html-viewer-textarea-Snb7dqe4vyuwZjJXKg3zNQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Snb7dqe4vyuwZjJXKg3zNQ:checked + #ipyplot-html-viewer-label-Snb7dqe4vyuwZjJXKg3zNQ:after {
# ...

# %% [markdown]
# ### 100-1000eV

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_100_1000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_100_1000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
               
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RMK49VG6kadQKKEjxSHggH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RMK49VG6kadQKKEjxSHggH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RMK49VG6kadQKKEjxSHggH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RMK49VG6kadQKKEjxSHggH:checked ~ #ipyplot-html-viewer-textarea-RMK49VG6kadQKKEjxSHggH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RMK49VG6kadQKKEjxSHggH:checked + #ipyplot-html-viewer-label-RMK49VG6kadQKKEjxSHggH:after {
# ...

# %%
images_array = [ "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_0_20_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_0_20_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1000_40000_imfBz_-20_0_imfBy_0_25_swP_0_20/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"       
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JFHRJE8Jv7xg7eQxp7wM6s {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JFHRJE8Jv7xg7eQxp7wM6s {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JFHRJE8Jv7xg7eQxp7wM6s {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JFHRJE8Jv7xg7eQxp7wM6s:checked ~ #ipyplot-html-viewer-textarea-JFHRJE8Jv7xg7eQxp7wM6s {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JFHRJE8Jv7xg7eQxp7wM6s:checked + #ipyplot-html-viewer-label-JFHRJE8Jv7xg7eQxp7wM6s:after {
# ...

# %% [markdown]
# ### Possible solution:
# 1. bigger grid for different region
# 2. more years
