# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"

# %% [markdown]
# # Overall Maps
#
# Dawn asymmetry near Earth and dusk asymmetry further down

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UtmKjrguQJraLdX6FNrzwk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UtmKjrguQJraLdX6FNrzwk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UtmKjrguQJraLdX6FNrzwk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UtmKjrguQJraLdX6FNrzwk:checked ~ #ipyplot-html-viewer-textarea-UtmKjrguQJraLdX6FNrzwk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UtmKjrguQJraLdX6FNrzwk:checked + #ipyplot-html-viewer-label-UtmKjrguQJraLdX6FNrzwk:after {
# ...

# %% [markdown]
# ## Different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/non_sort_map/grid_02/all_all_All_any/vents/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ANvrRU6PTJPT8GmQXcjYG8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ANvrRU6PTJPT8GmQXcjYG8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ANvrRU6PTJPT8GmQXcjYG8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ANvrRU6PTJPT8GmQXcjYG8:checked ~ #ipyplot-html-viewer-textarea-ANvrRU6PTJPT8GmQXcjYG8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ANvrRU6PTJPT8GmQXcjYG8:checked + #ipyplot-html-viewer-label-ANvrRU6PTJPT8GmQXcjYG8:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth. Dawnside asymmetry is observed

# %%
images_array = [
    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
,      "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jCeTwMQc9QaF3FkkJmmXMx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jCeTwMQc9QaF3FkkJmmXMx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jCeTwMQc9QaF3FkkJmmXMx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jCeTwMQc9QaF3FkkJmmXMx:checked ~ #ipyplot-html-viewer-textarea-jCeTwMQc9QaF3FkkJmmXMx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jCeTwMQc9QaF3FkkJmmXMx:checked + #ipyplot-html-viewer-label-jCeTwMQc9QaF3FkkJmmXMx:after {
# ...

# %% [markdown]
# ### 100 - 1000 eV
# Most observed near the Earth. Dawnside asymmetry observed.

# %%
images_array = [
    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
 ,      "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4sMccojV9ZWjjXuj5XjT2a {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4sMccojV9ZWjjXuj5XjT2a {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4sMccojV9ZWjjXuj5XjT2a {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4sMccojV9ZWjjXuj5XjT2a:checked ~ #ipyplot-html-viewer-textarea-4sMccojV9ZWjjXuj5XjT2a {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4sMccojV9ZWjjXuj5XjT2a:checked + #ipyplot-html-viewer-label-4sMccojV9ZWjjXuj5XjT2a:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
  ,  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WnWqSXgrbmTyEvFzkWeXEQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WnWqSXgrbmTyEvFzkWeXEQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WnWqSXgrbmTyEvFzkWeXEQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WnWqSXgrbmTyEvFzkWeXEQ:checked ~ #ipyplot-html-viewer-textarea-WnWqSXgrbmTyEvFzkWeXEQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WnWqSXgrbmTyEvFzkWeXEQ:checked + #ipyplot-html-viewer-label-WnWqSXgrbmTyEvFzkWeXEQ:after {
# ...

# %% [markdown]
# ## Review the year with different energy ranges
# ### 2016 (X-Y GSM project, 1-100 eV, 100-1000eV, 1000-40000eV)
# Same energy divided asymmtry found

# %%
images_array = [
    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cxfYhi9gtoFaY3x7R9yAnM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cxfYhi9gtoFaY3x7R9yAnM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cxfYhi9gtoFaY3x7R9yAnM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cxfYhi9gtoFaY3x7R9yAnM:checked ~ #ipyplot-html-viewer-textarea-cxfYhi9gtoFaY3x7R9yAnM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cxfYhi9gtoFaY3x7R9yAnM:checked + #ipyplot-html-viewer-label-cxfYhi9gtoFaY3x7R9yAnM:after {
# ...

# %% [markdown]
# ### 2017 (X-Y GSM project, 1-100 eV, 100-1000eV, 1000-40000eV)
# Same energy divided asymmtry found

# %%
images_array = [
    "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-VbLjUjed2Wov3miiVbgByA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VbLjUjed2Wov3miiVbgByA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VbLjUjed2Wov3miiVbgByA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VbLjUjed2Wov3miiVbgByA:checked ~ #ipyplot-html-viewer-textarea-VbLjUjed2Wov3miiVbgByA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VbLjUjed2Wov3miiVbgByA:checked + #ipyplot-html-viewer-label-VbLjUjed2Wov3miiVbgByA:after {
# ...

# %% [markdown]
# ## IMF By / Bz sorted maps

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DTid4MjAAPJTqGp72X9Qb3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DTid4MjAAPJTqGp72X9Qb3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DTid4MjAAPJTqGp72X9Qb3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DTid4MjAAPJTqGp72X9Qb3:checked ~ #ipyplot-html-viewer-textarea-DTid4MjAAPJTqGp72X9Qb3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DTid4MjAAPJTqGp72X9Qb3:checked + #ipyplot-html-viewer-label-DTid4MjAAPJTqGp72X9Qb3:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted Lobe maps

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5UpWE5Sy7858TCd2RpFysN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5UpWE5Sy7858TCd2RpFysN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5UpWE5Sy7858TCd2RpFysN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5UpWE5Sy7858TCd2RpFysN:checked ~ #ipyplot-html-viewer-textarea-5UpWE5Sy7858TCd2RpFysN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5UpWE5Sy7858TCd2RpFysN:checked + #ipyplot-html-viewer-label-5UpWE5Sy7858TCd2RpFysN:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted BL maps

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iJGN9eU7wgFEQQvcz7DSbr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iJGN9eU7wgFEQQvcz7DSbr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iJGN9eU7wgFEQQvcz7DSbr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iJGN9eU7wgFEQQvcz7DSbr:checked ~ #ipyplot-html-viewer-textarea-iJGN9eU7wgFEQQvcz7DSbr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iJGN9eU7wgFEQQvcz7DSbr:checked + #ipyplot-html-viewer-label-iJGN9eU7wgFEQQvcz7DSbr:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted PS maps

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"        
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TxD6V3nvV8gAqckBpsN35o {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TxD6V3nvV8gAqckBpsN35o {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TxD6V3nvV8gAqckBpsN35o {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TxD6V3nvV8gAqckBpsN35o:checked ~ #ipyplot-html-viewer-textarea-TxD6V3nvV8gAqckBpsN35o {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TxD6V3nvV8gAqckBpsN35o:checked + #ipyplot-html-viewer-label-TxD6V3nvV8gAqckBpsN35o:after {
# ...

# %% [markdown]
# ## By / Bz sorted maps with different energy ranges
# ### 1-100eV

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
               
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ndLbpk4ugKjEncACLhkxgd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ndLbpk4ugKjEncACLhkxgd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ndLbpk4ugKjEncACLhkxgd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ndLbpk4ugKjEncACLhkxgd:checked ~ #ipyplot-html-viewer-textarea-ndLbpk4ugKjEncACLhkxgd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ndLbpk4ugKjEncACLhkxgd:checked + #ipyplot-html-viewer-label-ndLbpk4ugKjEncACLhkxgd:after {
# ...

# %% [markdown]
# ### 100-1000eV

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
               
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TsaFg2dFGuZe6eNqrXRksE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TsaFg2dFGuZe6eNqrXRksE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TsaFg2dFGuZe6eNqrXRksE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TsaFg2dFGuZe6eNqrXRksE:checked ~ #ipyplot-html-viewer-textarea-TsaFg2dFGuZe6eNqrXRksE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TsaFg2dFGuZe6eNqrXRksE:checked + #ipyplot-html-viewer-label-TsaFg2dFGuZe6eNqrXRksE:after {
# ...

# %%
images_array = [ "idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_0_20_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_0_20_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_0_imfBy_-25_0_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
                ,"idl_plots/non_sort_map/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_0_imfBy_0_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"       
               ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DiMLMNVDPb8VD4hCqiEoop {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DiMLMNVDPb8VD4hCqiEoop {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DiMLMNVDPb8VD4hCqiEoop {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DiMLMNVDPb8VD4hCqiEoop:checked ~ #ipyplot-html-viewer-textarea-DiMLMNVDPb8VD4hCqiEoop {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DiMLMNVDPb8VD4hCqiEoop:checked + #ipyplot-html-viewer-label-DiMLMNVDPb8VD4hCqiEoop:after {
# ...

# %% [markdown]
# ### Possible solution:
# 1. bigger grid for different region
# 2. more years
