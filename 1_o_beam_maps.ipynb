# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/output_sc1_sp3_300sec_multi_pa2_en2_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots/plots_ss27/"

non_sort_map_path = main_plot_path + 'non_sort_map'
hemi_sort_map_path = main_plot_path+"hemi_sort_map"
kp_sort_map_path = main_plot_path+'kp_sort_map'
bx_sort_map_path = main_plot_path+'bx_sort_map'

start_time = '20170101'
end_time = '20201231'
 
grid_str = "grid_02"
direction_str = "outflow"
correction_flag_str = 'corrected_'

ratio_type = "ratio_"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
#     , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EiPedkyh2c9VCycPbvKBZe {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EiPedkyh2c9VCycPbvKBZe {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EiPedkyh2c9VCycPbvKBZe {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EiPedkyh2c9VCycPbvKBZe:checked ~ #ipyplot-html-viewer-textarea-EiPedkyh2c9VCycPbvKBZe {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EiPedkyh2c9VCycPbvKBZe:checked + #ipyplot-html-viewer-label-EiPedkyh2c9VCycPbvKBZe:after {
# ...

# %% [markdown]
# ## Maps for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
, non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,
     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-VnMjeEwFnWxTx8mpU8whwt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VnMjeEwFnWxTx8mpU8whwt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VnMjeEwFnWxTx8mpU8whwt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VnMjeEwFnWxTx8mpU8whwt:checked ~ #ipyplot-html-viewer-textarea-VnMjeEwFnWxTx8mpU8whwt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VnMjeEwFnWxTx8mpU8whwt:checked + #ipyplot-html-viewer-label-VnMjeEwFnWxTx8mpU8whwt:after {
# ...

# %% [markdown]
# ## Beta dependence

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ltb9uVRMbeppUNdjxMYPT5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ltb9uVRMbeppUNdjxMYPT5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ltb9uVRMbeppUNdjxMYPT5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ltb9uVRMbeppUNdjxMYPT5:checked ~ #ipyplot-html-viewer-textarea-Ltb9uVRMbeppUNdjxMYPT5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ltb9uVRMbeppUNdjxMYPT5:checked + #ipyplot-html-viewer-label-Ltb9uVRMbeppUNdjxMYPT5:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XZgsm for dawn, center and dusk and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oLJKc4dRUdTLsRtmy5mMfK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oLJKc4dRUdTLsRtmy5mMfK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oLJKc4dRUdTLsRtmy5mMfK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oLJKc4dRUdTLsRtmy5mMfK:checked ~ #ipyplot-html-viewer-textarea-oLJKc4dRUdTLsRtmy5mMfK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oLJKc4dRUdTLsRtmy5mMfK:checked + #ipyplot-html-viewer-label-oLJKc4dRUdTLsRtmy5mMfK:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in YZgsm for Inner magnetosphere, tail and distant tail and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nx3Tsrus8iALj9QWeizTd8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nx3Tsrus8iALj9QWeizTd8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nx3Tsrus8iALj9QWeizTd8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nx3Tsrus8iALj9QWeizTd8:checked ~ #ipyplot-html-viewer-textarea-nx3Tsrus8iALj9QWeizTd8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nx3Tsrus8iALj9QWeizTd8:checked + #ipyplot-html-viewer-label-nx3Tsrus8iALj9QWeizTd8:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XYgsm for south and north and lobes, BL, PS
#
# * south/north hemisphere is defined with Bx, Zgsm and Xgsm

# %%
images_array = [
       hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png" 
    ,     
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
       ,    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mFgVGPMwN2uV8EPbiJKn2w {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mFgVGPMwN2uV8EPbiJKn2w {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mFgVGPMwN2uV8EPbiJKn2w {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mFgVGPMwN2uV8EPbiJKn2w:checked ~ #ipyplot-html-viewer-textarea-mFgVGPMwN2uV8EPbiJKn2w {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mFgVGPMwN2uV8EPbiJKn2w:checked + #ipyplot-html-viewer-label-mFgVGPMwN2uV8EPbiJKn2w:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ## IMF By sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
  ,      non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UpJUMP8ueV46ippPv9NsEq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UpJUMP8ueV46ippPv9NsEq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UpJUMP8ueV46ippPv9NsEq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UpJUMP8ueV46ippPv9NsEq:checked ~ #ipyplot-html-viewer-textarea-UpJUMP8ueV46ippPv9NsEq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UpJUMP8ueV46ippPv9NsEq:checked + #ipyplot-html-viewer-label-UpJUMP8ueV46ippPv9NsEq:after {
# ...

# %% [markdown]
# ## IMF By / Bz sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WWooYqwWwwPmEba8VAf9HA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WWooYqwWwwPmEba8VAf9HA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WWooYqwWwwPmEba8VAf9HA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WWooYqwWwwPmEba8VAf9HA:checked ~ #ipyplot-html-viewer-textarea-WWooYqwWwwPmEba8VAf9HA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WWooYqwWwwPmEba8VAf9HA:checked + #ipyplot-html-viewer-label-WWooYqwWwwPmEba8VAf9HA:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ktLiDaFUt4fKxTA9oT45QV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ktLiDaFUt4fKxTA9oT45QV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ktLiDaFUt4fKxTA9oT45QV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ktLiDaFUt4fKxTA9oT45QV:checked ~ #ipyplot-html-viewer-textarea-ktLiDaFUt4fKxTA9oT45QV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ktLiDaFUt4fKxTA9oT45QV:checked + #ipyplot-html-viewer-label-ktLiDaFUt4fKxTA9oT45QV:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   
            non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   
    non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   
    non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   
    non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   
    non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SDYqPsP7mnyPk525zHEpAm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SDYqPsP7mnyPk525zHEpAm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SDYqPsP7mnyPk525zHEpAm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SDYqPsP7mnyPk525zHEpAm:checked ~ #ipyplot-html-viewer-textarea-SDYqPsP7mnyPk525zHEpAm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SDYqPsP7mnyPk525zHEpAm:checked + #ipyplot-html-viewer-label-SDYqPsP7mnyPk525zHEpAm:after {
# ...

# %% [markdown]
# ### IMF By sorted hemi sphere maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7H8GHZ6rx9rxws6vA2WUUq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7H8GHZ6rx9rxws6vA2WUUq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7H8GHZ6rx9rxws6vA2WUUq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7H8GHZ6rx9rxws6vA2WUUq:checked ~ #ipyplot-html-viewer-textarea-7H8GHZ6rx9rxws6vA2WUUq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7H8GHZ6rx9rxws6vA2WUUq:checked + #ipyplot-html-viewer-label-7H8GHZ6rx9rxws6vA2WUUq:after {
# ...

# %% [markdown]
# ## Different events  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4yPLi62qMX7hrCx8SV8GCD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4yPLi62qMX7hrCx8SV8GCD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4yPLi62qMX7hrCx8SV8GCD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4yPLi62qMX7hrCx8SV8GCD:checked ~ #ipyplot-html-viewer-textarea-4yPLi62qMX7hrCx8SV8GCD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4yPLi62qMX7hrCx8SV8GCD:checked + #ipyplot-html-viewer-label-4yPLi62qMX7hrCx8SV8GCD:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ExhT2oyUWsgZj4N8RXvCU5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ExhT2oyUWsgZj4N8RXvCU5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ExhT2oyUWsgZj4N8RXvCU5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ExhT2oyUWsgZj4N8RXvCU5:checked ~ #ipyplot-html-viewer-textarea-ExhT2oyUWsgZj4N8RXvCU5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ExhT2oyUWsgZj4N8RXvCU5:checked + #ipyplot-html-viewer-label-ExhT2oyUWsgZj4N8RXvCU5:after {
# ...

# %% [markdown]
# ### 1000 - 3000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ET2hCcfoA4SDtoyBQy6ZAm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ET2hCcfoA4SDtoyBQy6ZAm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ET2hCcfoA4SDtoyBQy6ZAm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ET2hCcfoA4SDtoyBQy6ZAm:checked ~ #ipyplot-html-viewer-textarea-ET2hCcfoA4SDtoyBQy6ZAm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ET2hCcfoA4SDtoyBQy6ZAm:checked + #ipyplot-html-viewer-label-ET2hCcfoA4SDtoyBQy6ZAm:after {
# ...

# %% [markdown]
# ### 3000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+ratio_type+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-a3xB6D4e6HXbqXy8y9FpZ2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-a3xB6D4e6HXbqXy8y9FpZ2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-a3xB6D4e6HXbqXy8y9FpZ2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-a3xB6D4e6HXbqXy8y9FpZ2:checked ~ #ipyplot-html-viewer-textarea-a3xB6D4e6HXbqXy8y9FpZ2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-a3xB6D4e6HXbqXy8y9FpZ2:checked + #ipyplot-html-viewer-label-a3xB6D4e6HXbqXy8y9FpZ2:after {
# ...

# %% [markdown]
# ## kp impacts

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,      kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KBdnCTaXDYjabqwM6mEdhU {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KBdnCTaXDYjabqwM6mEdhU {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KBdnCTaXDYjabqwM6mEdhU {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KBdnCTaXDYjabqwM6mEdhU:checked ~ #ipyplot-html-viewer-textarea-KBdnCTaXDYjabqwM6mEdhU {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KBdnCTaXDYjabqwM6mEdhU:checked + #ipyplot-html-viewer-label-KBdnCTaXDYjabqwM6mEdhU:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_"+direction_str+"/events/2d/Kplt_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,  kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_"+direction_str+"/events/2d/Kplt_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_"+direction_str+"/events/2d/Kplt_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
, kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_"+direction_str+"/events/2d/Kpge_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_"+direction_str+"/events/2d/Kpge_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_"+direction_str+"/events/2d/Kpge_2_Lobe_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,
    
    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,  kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
, kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    
    ,
    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,  kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
, kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Wn73qUaucpH89P9X3QnnfW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Wn73qUaucpH89P9X3QnnfW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Wn73qUaucpH89P9X3QnnfW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Wn73qUaucpH89P9X3QnnfW:checked ~ #ipyplot-html-viewer-textarea-Wn73qUaucpH89P9X3QnnfW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Wn73qUaucpH89P9X3QnnfW:checked + #ipyplot-html-viewer-label-Wn73qUaucpH89P9X3QnnfW:after {
# ...

# %% [markdown]
# ## Storm impacts

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"   
    ,
     non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 , non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"

 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
      non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hyA2EsFpNwetSHNYVMH98g {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hyA2EsFpNwetSHNYVMH98g {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hyA2EsFpNwetSHNYVMH98g {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hyA2EsFpNwetSHNYVMH98g:checked ~ #ipyplot-html-viewer-textarea-hyA2EsFpNwetSHNYVMH98g {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hyA2EsFpNwetSHNYVMH98g:checked + #ipyplot-html-viewer-label-hyA2EsFpNwetSHNYVMH98g:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
, non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,  non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,  non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
        ,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300
                   )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-o9PxVn9fTtQtaEVzZMm6HC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-o9PxVn9fTtQtaEVzZMm6HC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-o9PxVn9fTtQtaEVzZMm6HC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-o9PxVn9fTtQtaEVzZMm6HC:checked ~ #ipyplot-html-viewer-textarea-o9PxVn9fTtQtaEVzZMm6HC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-o9PxVn9fTtQtaEVzZMm6HC:checked + #ipyplot-html-viewer-label-o9PxVn9fTtQtaEVzZMm6HC:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
, non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,
      non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,  non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__"+ correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QrRXtYoxsohetsSTSGeDM5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QrRXtYoxsohetsSTSGeDM5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QrRXtYoxsohetsSTSGeDM5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QrRXtYoxsohetsSTSGeDM5:checked ~ #ipyplot-html-viewer-textarea-QrRXtYoxsohetsSTSGeDM5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QrRXtYoxsohetsSTSGeDM5:checked + #ipyplot-html-viewer-label-QrRXtYoxsohetsSTSGeDM5:after {
# ...
