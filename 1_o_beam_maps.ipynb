# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/output_sc1_sp3_300sec_multi_pa2_en2_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots/plots_ss27/"

non_sort_map_path = main_plot_path + 'non_sort_map'
hemi_sort_map_path = main_plot_path+"hemi_sort_map"
kp_sort_map_path = main_plot_path+'kp_sort_map'
bx_sort_map_path = main_plot_path+'bx_sort_map'

start_time = '20170101'
end_time = '20201231'
 
grid_str = "grid_02"
direction_str = "outflow"
correction_flag_str = 'corrected_'

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
#     , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-eijBNNXC5PGpiqVSARZsMN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eijBNNXC5PGpiqVSARZsMN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eijBNNXC5PGpiqVSARZsMN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eijBNNXC5PGpiqVSARZsMN:checked ~ #ipyplot-html-viewer-textarea-eijBNNXC5PGpiqVSARZsMN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eijBNNXC5PGpiqVSARZsMN:checked + #ipyplot-html-viewer-label-eijBNNXC5PGpiqVSARZsMN:after {
# ...

# %% [markdown]
# ## Maps for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
, non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,
     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5Qhe49ospN7JbhtqBqwM8z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5Qhe49ospN7JbhtqBqwM8z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5Qhe49ospN7JbhtqBqwM8z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5Qhe49ospN7JbhtqBqwM8z:checked ~ #ipyplot-html-viewer-textarea-5Qhe49ospN7JbhtqBqwM8z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5Qhe49ospN7JbhtqBqwM8z:checked + #ipyplot-html-viewer-label-5Qhe49ospN7JbhtqBqwM8z:after {
# ...

# %% [markdown]
# ## Beta dependence

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NmJ9gSxczy7YhEQviJH9gi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NmJ9gSxczy7YhEQviJH9gi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NmJ9gSxczy7YhEQviJH9gi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NmJ9gSxczy7YhEQviJH9gi:checked ~ #ipyplot-html-viewer-textarea-NmJ9gSxczy7YhEQviJH9gi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NmJ9gSxczy7YhEQviJH9gi:checked + #ipyplot-html-viewer-label-NmJ9gSxczy7YhEQviJH9gi:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XZgsm for dawn, center and dusk and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-S344sDCJPULeB7MbC59e86 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-S344sDCJPULeB7MbC59e86 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-S344sDCJPULeB7MbC59e86 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-S344sDCJPULeB7MbC59e86:checked ~ #ipyplot-html-viewer-textarea-S344sDCJPULeB7MbC59e86 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-S344sDCJPULeB7MbC59e86:checked + #ipyplot-html-viewer-label-S344sDCJPULeB7MbC59e86:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in YZgsm for Inner magnetosphere, tail and distant tail and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-numQ3acyWht7QSh6pStQPA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-numQ3acyWht7QSh6pStQPA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-numQ3acyWht7QSh6pStQPA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-numQ3acyWht7QSh6pStQPA:checked ~ #ipyplot-html-viewer-textarea-numQ3acyWht7QSh6pStQPA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-numQ3acyWht7QSh6pStQPA:checked + #ipyplot-html-viewer-label-numQ3acyWht7QSh6pStQPA:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XYgsm for south and north and lobes, BL, PS
#
# * south/north hemisphere is defined with Bx, Zgsm and Xgsm

# %%
images_array = [
       hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png" 

    ,     
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
       ,    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MZ9Cgh9937vhUrti3VP3hF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MZ9Cgh9937vhUrti3VP3hF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MZ9Cgh9937vhUrti3VP3hF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MZ9Cgh9937vhUrti3VP3hF:checked ~ #ipyplot-html-viewer-textarea-MZ9Cgh9937vhUrti3VP3hF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MZ9Cgh9937vhUrti3VP3hF:checked + #ipyplot-html-viewer-label-MZ9Cgh9937vhUrti3VP3hF:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ## IMF By sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
  ,      non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8jmCUEMH7CPRWYxtvN7gzt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8jmCUEMH7CPRWYxtvN7gzt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8jmCUEMH7CPRWYxtvN7gzt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8jmCUEMH7CPRWYxtvN7gzt:checked ~ #ipyplot-html-viewer-textarea-8jmCUEMH7CPRWYxtvN7gzt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8jmCUEMH7CPRWYxtvN7gzt:checked + #ipyplot-html-viewer-label-8jmCUEMH7CPRWYxtvN7gzt:after {
# ...

# %% [markdown]
# ## IMF By / Bz sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PdyCvJvcGVckjvjRNcdetB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PdyCvJvcGVckjvjRNcdetB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PdyCvJvcGVckjvjRNcdetB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PdyCvJvcGVckjvjRNcdetB:checked ~ #ipyplot-html-viewer-textarea-PdyCvJvcGVckjvjRNcdetB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PdyCvJvcGVckjvjRNcdetB:checked + #ipyplot-html-viewer-label-PdyCvJvcGVckjvjRNcdetB:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hpjNz9tv9GiiuWDbpiyDAG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hpjNz9tv9GiiuWDbpiyDAG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hpjNz9tv9GiiuWDbpiyDAG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hpjNz9tv9GiiuWDbpiyDAG:checked ~ #ipyplot-html-viewer-textarea-hpjNz9tv9GiiuWDbpiyDAG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hpjNz9tv9GiiuWDbpiyDAG:checked + #ipyplot-html-viewer-label-hpjNz9tv9GiiuWDbpiyDAG:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-e6FmJZnRYWTCSP57PeG75p {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-e6FmJZnRYWTCSP57PeG75p {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-e6FmJZnRYWTCSP57PeG75p {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-e6FmJZnRYWTCSP57PeG75p:checked ~ #ipyplot-html-viewer-textarea-e6FmJZnRYWTCSP57PeG75p {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-e6FmJZnRYWTCSP57PeG75p:checked + #ipyplot-html-viewer-label-e6FmJZnRYWTCSP57PeG75p:after {
# ...

# %% [markdown]
# ### IMF By sorted hemi sphere maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HR6VSXun8SbaoVi66JTLtu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HR6VSXun8SbaoVi66JTLtu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HR6VSXun8SbaoVi66JTLtu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HR6VSXun8SbaoVi66JTLtu:checked ~ #ipyplot-html-viewer-textarea-HR6VSXun8SbaoVi66JTLtu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HR6VSXun8SbaoVi66JTLtu:checked + #ipyplot-html-viewer-label-HR6VSXun8SbaoVi66JTLtu:after {
# ...

# %% [markdown]
# ## Different events  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4TArmaLJhGoFGkGQgaEp5R {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4TArmaLJhGoFGkGQgaEp5R {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4TArmaLJhGoFGkGQgaEp5R {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4TArmaLJhGoFGkGQgaEp5R:checked ~ #ipyplot-html-viewer-textarea-4TArmaLJhGoFGkGQgaEp5R {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4TArmaLJhGoFGkGQgaEp5R:checked + #ipyplot-html-viewer-label-4TArmaLJhGoFGkGQgaEp5R:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-X3kWhyy2sG6QMUuXpuL7hp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-X3kWhyy2sG6QMUuXpuL7hp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-X3kWhyy2sG6QMUuXpuL7hp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-X3kWhyy2sG6QMUuXpuL7hp:checked ~ #ipyplot-html-viewer-textarea-X3kWhyy2sG6QMUuXpuL7hp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-X3kWhyy2sG6QMUuXpuL7hp:checked + #ipyplot-html-viewer-label-X3kWhyy2sG6QMUuXpuL7hp:after {
# ...

# %% [markdown]
# ### 1000 - 3000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PCXv3xpLjeDUR3vD4i6Ffy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PCXv3xpLjeDUR3vD4i6Ffy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PCXv3xpLjeDUR3vD4i6Ffy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PCXv3xpLjeDUR3vD4i6Ffy:checked ~ #ipyplot-html-viewer-textarea-PCXv3xpLjeDUR3vD4i6Ffy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PCXv3xpLjeDUR3vD4i6Ffy:checked + #ipyplot-html-viewer-label-PCXv3xpLjeDUR3vD4i6Ffy:after {
# ...

# %% [markdown]
# ### 3000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LTUiA5ESypUWDkBurLPdEZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LTUiA5ESypUWDkBurLPdEZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LTUiA5ESypUWDkBurLPdEZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LTUiA5ESypUWDkBurLPdEZ:checked ~ #ipyplot-html-viewer-textarea-LTUiA5ESypUWDkBurLPdEZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LTUiA5ESypUWDkBurLPdEZ:checked + #ipyplot-html-viewer-label-LTUiA5ESypUWDkBurLPdEZ:after {
# ...

# %% [markdown]
# ## kp impacts

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-f2VQaPsuiqkL5aDNGPYcfV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-f2VQaPsuiqkL5aDNGPYcfV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-f2VQaPsuiqkL5aDNGPYcfV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-f2VQaPsuiqkL5aDNGPYcfV:checked ~ #ipyplot-html-viewer-textarea-f2VQaPsuiqkL5aDNGPYcfV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-f2VQaPsuiqkL5aDNGPYcfV:checked + #ipyplot-html-viewer-label-f2VQaPsuiqkL5aDNGPYcfV:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-AkgMYDeLRarxmdLvM9WHTk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-AkgMYDeLRarxmdLvM9WHTk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-AkgMYDeLRarxmdLvM9WHTk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-AkgMYDeLRarxmdLvM9WHTk:checked ~ #ipyplot-html-viewer-textarea-AkgMYDeLRarxmdLvM9WHTk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-AkgMYDeLRarxmdLvM9WHTk:checked + #ipyplot-html-viewer-label-AkgMYDeLRarxmdLvM9WHTk:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6ZhcHLE3i3zCZu7SzWLmEo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6ZhcHLE3i3zCZu7SzWLmEo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6ZhcHLE3i3zCZu7SzWLmEo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6ZhcHLE3i3zCZu7SzWLmEo:checked ~ #ipyplot-html-viewer-textarea-6ZhcHLE3i3zCZu7SzWLmEo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6ZhcHLE3i3zCZu7SzWLmEo:checked + #ipyplot-html-viewer-label-6ZhcHLE3i3zCZu7SzWLmEo:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,    kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LpsLfSX3TLSK6EGL8nRFHg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LpsLfSX3TLSK6EGL8nRFHg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LpsLfSX3TLSK6EGL8nRFHg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LpsLfSX3TLSK6EGL8nRFHg:checked ~ #ipyplot-html-viewer-textarea-LpsLfSX3TLSK6EGL8nRFHg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LpsLfSX3TLSK6EGL8nRFHg:checked + #ipyplot-html-viewer-label-LpsLfSX3TLSK6EGL8nRFHg:after {
# ...

# %% [markdown]
# ## Storm impacts

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,
     non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
     non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DEA8sqBx2iKdiQLpowHB5Z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DEA8sqBx2iKdiQLpowHB5Z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DEA8sqBx2iKdiQLpowHB5Z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DEA8sqBx2iKdiQLpowHB5Z:checked ~ #ipyplot-html-viewer-textarea-DEA8sqBx2iKdiQLpowHB5Z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DEA8sqBx2iKdiQLpowHB5Z:checked + #ipyplot-html-viewer-label-DEA8sqBx2iKdiQLpowHB5Z:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
        , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400
                   )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-megk6KTn57jHncggeuiLas {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-megk6KTn57jHncggeuiLas {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-megk6KTn57jHncggeuiLas {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-megk6KTn57jHncggeuiLas:checked ~ #ipyplot-html-viewer-textarea-megk6KTn57jHncggeuiLas {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-megk6KTn57jHncggeuiLas:checked + #ipyplot-html-viewer-label-megk6KTn57jHncggeuiLas:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
,
     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__corrected_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__corrected_ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gWApXcbLL6iqk3tzUAE7ES {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gWApXcbLL6iqk3tzUAE7ES {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gWApXcbLL6iqk3tzUAE7ES {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gWApXcbLL6iqk3tzUAE7ES:checked ~ #ipyplot-html-viewer-textarea-gWApXcbLL6iqk3tzUAE7ES {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gWApXcbLL6iqk3tzUAE7ES:checked + #ipyplot-html-viewer-label-gWApXcbLL6iqk3tzUAE7ES:after {
# ...

# %% [markdown]
# ### South / north in median events different regions for positive and negative IMF By

# %%
### South / north in median events different regions for positive and negative IMF By
images_array = [
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_-25_0__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_0_25__"+correction_flag_str+"ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7DAzJno7YEF6irzH4Naxkv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7DAzJno7YEF6irzH4Naxkv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7DAzJno7YEF6irzH4Naxkv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7DAzJno7YEF6irzH4Naxkv:checked ~ #ipyplot-html-viewer-textarea-7DAzJno7YEF6irzH4Naxkv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7DAzJno7YEF6irzH4Naxkv:checked + #ipyplot-html-viewer-label-7DAzJno7YEF6irzH4Naxkv:after {
# ...
