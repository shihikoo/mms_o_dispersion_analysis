# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/output_5min_multi_subtraction_reduced_removebi_flux0.500.751.00_pap3.02.01.1/plots_ss27/"

non_sort_map_path = main_plot_path+"non_sort_map"
hemi_sort_map_path = main_plot_path+"hemi_sort_map"
kp_sort_map_path = main_plot_path+'kp_sort_map'
bx_sort_map_path = main_plot_path+'bx_sort_map'

start_time = '20170101'
end_time = '20201231'

grid_str = "grid_02"
direction_str = "outflow"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
#     , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7pbXqkETnh39Ds9uRVsXdC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7pbXqkETnh39Ds9uRVsXdC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7pbXqkETnh39Ds9uRVsXdC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7pbXqkETnh39Ds9uRVsXdC:checked ~ #ipyplot-html-viewer-textarea-7pbXqkETnh39Ds9uRVsXdC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7pbXqkETnh39Ds9uRVsXdC:checked + #ipyplot-html-viewer-label-7pbXqkETnh39Ds9uRVsXdC:after {
# ...

# %% [markdown]
# ## Maps for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
, non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,
     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EmiXWQthMvTgwUjb3Fqnd4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EmiXWQthMvTgwUjb3Fqnd4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EmiXWQthMvTgwUjb3Fqnd4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EmiXWQthMvTgwUjb3Fqnd4:checked ~ #ipyplot-html-viewer-textarea-EmiXWQthMvTgwUjb3Fqnd4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EmiXWQthMvTgwUjb3Fqnd4:checked + #ipyplot-html-viewer-label-EmiXWQthMvTgwUjb3Fqnd4:after {
# ...

# %% [markdown]
# ## Beta dependence

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/"+grid_str+"/Tail_"+direction_str+"/events/2d/Tail_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3UYuqnw74M98LPvxMDedFo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3UYuqnw74M98LPvxMDedFo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3UYuqnw74M98LPvxMDedFo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3UYuqnw74M98LPvxMDedFo:checked ~ #ipyplot-html-viewer-textarea-3UYuqnw74M98LPvxMDedFo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3UYuqnw74M98LPvxMDedFo:checked + #ipyplot-html-viewer-label-3UYuqnw74M98LPvxMDedFo:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XZgsm for dawn, center and dusk and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CqptJ7BCkSYn7yTLmK2F3k {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CqptJ7BCkSYn7yTLmK2F3k {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CqptJ7BCkSYn7yTLmK2F3k {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CqptJ7BCkSYn7yTLmK2F3k:checked ~ #ipyplot-html-viewer-textarea-CqptJ7BCkSYn7yTLmK2F3k {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CqptJ7BCkSYn7yTLmK2F3k:checked + #ipyplot-html-viewer-label-CqptJ7BCkSYn7yTLmK2F3k:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in YZgsm for Inner magnetosphere, tail and distant tail and lobes, BL, PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kaxCaAyBvoQKcHxYaHzXk7 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kaxCaAyBvoQKcHxYaHzXk7 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kaxCaAyBvoQKcHxYaHzXk7 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kaxCaAyBvoQKcHxYaHzXk7:checked ~ #ipyplot-html-viewer-textarea-kaxCaAyBvoQKcHxYaHzXk7 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kaxCaAyBvoQKcHxYaHzXk7:checked + #ipyplot-html-viewer-label-kaxCaAyBvoQKcHxYaHzXk7:after {
# ...

# %% [markdown]
# ## Occurrence frequency maps in XYgsm for south and north and lobes, BL, PS
#
# * south/north hemisphere is defined with Bx, Zgsm and Xgsm

# %%
images_array = [
       hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png" 

    ,     
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
       ,    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,
    hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ha9hSNmKyLPWspwd7mCts8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ha9hSNmKyLPWspwd7mCts8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ha9hSNmKyLPWspwd7mCts8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ha9hSNmKyLPWspwd7mCts8:checked ~ #ipyplot-html-viewer-textarea-ha9hSNmKyLPWspwd7mCts8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ha9hSNmKyLPWspwd7mCts8:checked + #ipyplot-html-viewer-label-ha9hSNmKyLPWspwd7mCts8:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ## IMF By sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
  ,      non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,     non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,    non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aNC8vtb7SJS9N4MKzYRUHA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aNC8vtb7SJS9N4MKzYRUHA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aNC8vtb7SJS9N4MKzYRUHA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aNC8vtb7SJS9N4MKzYRUHA:checked ~ #ipyplot-html-viewer-textarea-aNC8vtb7SJS9N4MKzYRUHA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aNC8vtb7SJS9N4MKzYRUHA:checked + #ipyplot-html-viewer-label-aNC8vtb7SJS9N4MKzYRUHA:after {
# ...

# %% [markdown]
# ## IMF By / Bz sorted maps in YZgsm for lobes, BL and PS

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UHxbnxxRScMT8TFJirRwWM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UHxbnxxRScMT8TFJirRwWM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UHxbnxxRScMT8TFJirRwWM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UHxbnxxRScMT8TFJirRwWM:checked ~ #ipyplot-html-viewer-textarea-UHxbnxxRScMT8TFJirRwWM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UHxbnxxRScMT8TFJirRwWM:checked + #ipyplot-html-viewer-label-UHxbnxxRScMT8TFJirRwWM:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_0_25_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBz_-25_0_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UMMeC3micfgfQKqNVxBF5d {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UMMeC3micfgfQKqNVxBF5d {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UMMeC3micfgfQKqNVxBF5d {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UMMeC3micfgfQKqNVxBF5d:checked ~ #ipyplot-html-viewer-textarea-UMMeC3micfgfQKqNVxBF5d {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UMMeC3micfgfQKqNVxBF5d:checked + #ipyplot-html-viewer-label-UMMeC3micfgfQKqNVxBF5d:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_15/Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/slice/slice_zgrid_10/Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_15/BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/slice/slice_zgrid_10/BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_15/PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/slice/slice_zgrid_10/PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cAxLEVrqZR9Vu8Svq5Qct8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cAxLEVrqZR9Vu8Svq5Qct8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cAxLEVrqZR9Vu8Svq5Qct8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cAxLEVrqZR9Vu8Svq5Qct8:checked ~ #ipyplot-html-viewer-textarea-cAxLEVrqZR9Vu8Svq5Qct8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cAxLEVrqZR9Vu8Svq5Qct8:checked + #ipyplot-html-viewer-label-cAxLEVrqZR9Vu8Svq5Qct8:after {
# ...

# %% [markdown]
# ### IMF By sorted hemi sphere maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UQmgxeB5sPGxAz95BdC8Bv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UQmgxeB5sPGxAz95BdC8Bv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UQmgxeB5sPGxAz95BdC8Bv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UQmgxeB5sPGxAz95BdC8Bv:checked ~ #ipyplot-html-viewer-textarea-UQmgxeB5sPGxAz95BdC8Bv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UQmgxeB5sPGxAz95BdC8Bv:checked + #ipyplot-html-viewer-label-UQmgxeB5sPGxAz95BdC8Bv:after {
# ...

# %% [markdown]
# ## Different events  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1_100__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MoWWzsKixwnsCTqSn37wif {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MoWWzsKixwnsCTqSn37wif {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MoWWzsKixwnsCTqSn37wif {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MoWWzsKixwnsCTqSn37wif:checked ~ #ipyplot-html-viewer-textarea-MoWWzsKixwnsCTqSn37wif {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MoWWzsKixwnsCTqSn37wif:checked + #ipyplot-html-viewer-label-MoWWzsKixwnsCTqSn37wif:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_100_1000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Sq3QTStUh9QdQBtFuc9PHT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Sq3QTStUh9QdQBtFuc9PHT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Sq3QTStUh9QdQBtFuc9PHT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Sq3QTStUh9QdQBtFuc9PHT:checked ~ #ipyplot-html-viewer-textarea-Sq3QTStUh9QdQBtFuc9PHT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Sq3QTStUh9QdQBtFuc9PHT:checked + #ipyplot-html-viewer-label-Sq3QTStUh9QdQBtFuc9PHT:after {
# ...

# %% [markdown]
# ### 1000 - 3000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_1000_3000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DMLXWTTWJACNxvFPoScghh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DMLXWTTWJACNxvFPoScghh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DMLXWTTWJACNxvFPoScghh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DMLXWTTWJACNxvFPoScghh:checked ~ #ipyplot-html-viewer-textarea-DMLXWTTWJACNxvFPoScghh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DMLXWTTWJACNxvFPoScghh:checked + #ipyplot-html-viewer-label-DMLXWTTWJACNxvFPoScghh:after {
# ...

# %% [markdown]
# ### 3000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
       ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/Lobe_"+direction_str+"/events/2d/Lobe_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
 ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
      ,   non_sort_map_path+"/"+grid_str+"/BL_"+direction_str+"/events/2d/BL_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/"+grid_str+"/PS_"+direction_str+"/events/2d/PS_"+direction_str+"_en_3000_40000__ratio_"+start_time+"_to_"+end_time+"_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5PKouwnoKbKnHLPQGKx5Pg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5PKouwnoKbKnHLPQGKx5Pg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5PKouwnoKbKnHLPQGKx5Pg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5PKouwnoKbKnHLPQGKx5Pg:checked ~ #ipyplot-html-viewer-textarea-5PKouwnoKbKnHLPQGKx5Pg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5PKouwnoKbKnHLPQGKx5Pg:checked + #ipyplot-html-viewer-label-5PKouwnoKbKnHLPQGKx5Pg:after {
# ...

# %% [markdown]
# ## kp impacts

# %%
images_array = [kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"__ratio_"   +start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"  
                ,  kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"__ratio_"   +start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"  
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PT2JsEUY6XLx3ti44AxWgG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PT2JsEUY6XLx3ti44AxWgG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PT2JsEUY6XLx3ti44AxWgG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PT2JsEUY6XLx3ti44AxWgG:checked ~ #ipyplot-html-viewer-textarea-PT2JsEUY6XLx3ti44AxWgG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PT2JsEUY6XLx3ti44AxWgG:checked + #ipyplot-html-viewer-label-PT2JsEUY6XLx3ti44AxWgG:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_Lobe_"+direction_str+"/events/2d/Kplt_2_Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_Lobe_"+direction_str+"/events/2d/Kpge_2_Lobe_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gUzJsibrE9pBpZ7jiyrzyD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gUzJsibrE9pBpZ7jiyrzyD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gUzJsibrE9pBpZ7jiyrzyD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gUzJsibrE9pBpZ7jiyrzyD:checked ~ #ipyplot-html-viewer-textarea-gUzJsibrE9pBpZ7jiyrzyD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gUzJsibrE9pBpZ7jiyrzyD:checked + #ipyplot-html-viewer-label-gUzJsibrE9pBpZ7jiyrzyD:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_BL_"+direction_str+"/events/2d/Kplt_2_BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_BL_"+direction_str+"/events/2d/Kpge_2_BL_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ioLaFpbrGStj7FkwFydsqu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ioLaFpbrGStj7FkwFydsqu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ioLaFpbrGStj7FkwFydsqu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ioLaFpbrGStj7FkwFydsqu:checked ~ #ipyplot-html-viewer-textarea-ioLaFpbrGStj7FkwFydsqu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ioLaFpbrGStj7FkwFydsqu:checked + #ipyplot-html-viewer-label-ioLaFpbrGStj7FkwFydsqu:after {
# ...

# %%
images_array = [
   kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_PS_"+direction_str+"/events/2d/Kplt_2_PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_PS_"+direction_str+"/events/2d/Kpge_2_PS_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ENonaoN79g3XYzVRiRTeCS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ENonaoN79g3XYzVRiRTeCS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ENonaoN79g3XYzVRiRTeCS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ENonaoN79g3XYzVRiRTeCS:checked ~ #ipyplot-html-viewer-textarea-ENonaoN79g3XYzVRiRTeCS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ENonaoN79g3XYzVRiRTeCS:checked + #ipyplot-html-viewer-label-ENonaoN79g3XYzVRiRTeCS:after {
# ...

# %% [markdown]
# ## Storm impacts

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/nonstorm_time_"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
 ,  non_sort_map_path+"/"+grid_str+"/storm_time_"+direction_str+"/events/2d/storm_time_"+direction_str+"__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SsiAFEzFLPJi4QKUAbUffZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SsiAFEzFLPJi4QKUAbUffZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SsiAFEzFLPJi4QKUAbUffZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SsiAFEzFLPJi4QKUAbUffZ:checked ~ #ipyplot-html-viewer-textarea-SsiAFEzFLPJi4QKUAbUffZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SsiAFEzFLPJi4QKUAbUffZ:checked + #ipyplot-html-viewer-label-SsiAFEzFLPJi4QKUAbUffZ:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_0_450_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swV_450_900_ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300
                   )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7gjrPJPDgjEStgkMAq2zrV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7gjrPJPDgjEStgkMAq2zrV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7gjrPJPDgjEStgkMAq2zrV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7gjrPJPDgjEStgkMAq2zrV:checked ~ #ipyplot-html-viewer-textarea-7gjrPJPDgjEStgkMAq2zrV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7gjrPJPDgjEStgkMAq2zrV:checked + #ipyplot-html-viewer-label-7gjrPJPDgjEStgkMAq2zrV:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_0_2__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
,   non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_swP_2_20__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-AufH88EDvDyAeckuHkeAXd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-AufH88EDvDyAeckuHkeAXd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-AufH88EDvDyAeckuHkeAXd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-AufH88EDvDyAeckuHkeAXd:checked ~ #ipyplot-html-viewer-textarea-AufH88EDvDyAeckuHkeAXd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-AufH88EDvDyAeckuHkeAXd:checked + #ipyplot-html-viewer-label-AufH88EDvDyAeckuHkeAXd:after {
# ...

# %% [markdown]
# ### South / north in median events different regions for positive and negative IMF By

# %%
### South / north in median events different regions for positive and negative IMF By
images_array = [
    hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_Lobe_"+direction_str+"/events/2d/north_Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_Lobe_"+direction_str+"/events/2d/south_Lobe_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_BL_"+direction_str+"/events/2d/north_BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_BL_"+direction_str+"/events/2d/south_BL_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_north/"+grid_str+"/north_PS_"+direction_str+"/events/2d/north_PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_-25_0__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"
   ,hemi_sort_map_path+"/hemi_south/"+grid_str+"/south_PS_"+direction_str+"/events/2d/south_PS_"+direction_str+"_imfBy_0_25__ratio_"+start_time+"_to_"+end_time+"_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-c9vrhZZfq5SzPfyZmMZTkF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-c9vrhZZfq5SzPfyZmMZTkF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-c9vrhZZfq5SzPfyZmMZTkF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-c9vrhZZfq5SzPfyZmMZTkF:checked ~ #ipyplot-html-viewer-textarea-c9vrhZZfq5SzPfyZmMZTkF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-c9vrhZZfq5SzPfyZmMZTkF:checked + #ipyplot-html-viewer-label-c9vrhZZfq5SzPfyZmMZTkF:after {
# ...
