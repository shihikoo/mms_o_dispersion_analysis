# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"

# %% [markdown]
# # All region maps in different projections
#
# Dawn asymmetry near Earth and dusk asymmetry further down

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Dr45zAX5fMp4MWq9umiAfo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Dr45zAX5fMp4MWq9umiAfo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Dr45zAX5fMp4MWq9umiAfo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Dr45zAX5fMp4MWq9umiAfo:checked ~ #ipyplot-html-viewer-textarea-Dr45zAX5fMp4MWq9umiAfo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Dr45zAX5fMp4MWq9umiAfo:checked + #ipyplot-html-viewer-label-Dr45zAX5fMp4MWq9umiAfo:after {
# ...

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-P5hCEXcTLoqcd4MBc2mi25 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-P5hCEXcTLoqcd4MBc2mi25 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-P5hCEXcTLoqcd4MBc2mi25 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-P5hCEXcTLoqcd4MBc2mi25:checked ~ #ipyplot-html-viewer-textarea-P5hCEXcTLoqcd4MBc2mi25 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-P5hCEXcTLoqcd4MBc2mi25:checked + #ipyplot-html-viewer-label-P5hCEXcTLoqcd4MBc2mi25:after {
# ...

# %% [markdown]
# ## Different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jtYxJZmefsuEviAaByoyWA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jtYxJZmefsuEviAaByoyWA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jtYxJZmefsuEviAaByoyWA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jtYxJZmefsuEviAaByoyWA:checked ~ #ipyplot-html-viewer-textarea-jtYxJZmefsuEviAaByoyWA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jtYxJZmefsuEviAaByoyWA:checked + #ipyplot-html-viewer-label-jtYxJZmefsuEviAaByoyWA:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TEpFKTQyVYYaB9DSVFV68A {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TEpFKTQyVYYaB9DSVFV68A {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TEpFKTQyVYYaB9DSVFV68A {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TEpFKTQyVYYaB9DSVFV68A:checked ~ #ipyplot-html-viewer-textarea-TEpFKTQyVYYaB9DSVFV68A {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TEpFKTQyVYYaB9DSVFV68A:checked + #ipyplot-html-viewer-label-TEpFKTQyVYYaB9DSVFV68A:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Energy maps in Lobe

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HaWzfbKg5TDoBFfgT3MEPN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HaWzfbKg5TDoBFfgT3MEPN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HaWzfbKg5TDoBFfgT3MEPN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HaWzfbKg5TDoBFfgT3MEPN:checked ~ #ipyplot-html-viewer-textarea-HaWzfbKg5TDoBFfgT3MEPN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HaWzfbKg5TDoBFfgT3MEPN:checked + #ipyplot-html-viewer-label-HaWzfbKg5TDoBFfgT3MEPN:after {
# ...

# %% [markdown]
# ### BL

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-L5WA4y8UMEixPtC8AVYkaL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-L5WA4y8UMEixPtC8AVYkaL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-L5WA4y8UMEixPtC8AVYkaL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-L5WA4y8UMEixPtC8AVYkaL:checked ~ #ipyplot-html-viewer-textarea-L5WA4y8UMEixPtC8AVYkaL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-L5WA4y8UMEixPtC8AVYkaL:checked + #ipyplot-html-viewer-label-L5WA4y8UMEixPtC8AVYkaL:after {
# ...

# %% [markdown]
# ### PS

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dDQo2TLFX7739mxRYMo3Jk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dDQo2TLFX7739mxRYMo3Jk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dDQo2TLFX7739mxRYMo3Jk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dDQo2TLFX7739mxRYMo3Jk:checked ~ #ipyplot-html-viewer-textarea-dDQo2TLFX7739mxRYMo3Jk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dDQo2TLFX7739mxRYMo3Jk:checked + #ipyplot-html-viewer-label-dDQo2TLFX7739mxRYMo3Jk:after {
# ...
