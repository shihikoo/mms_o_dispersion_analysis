# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
from collections import Counter
import math
import datetime as datetime
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import statistics
import glob
import ipyplot
import numpy as np
import random

# %%
reduced_folder = "idl_plots/plots_with_reduced/obeam_day/2019/*plasma_condition_short.png"
#subtraction_folder = "idl_plots//obeam_day_with_subtraction/*/*.png"
reduced_list = glob.glob(reduced_folder)
#subtraction_list = glob.glob(dispersion_fitting_png_folder)

# %%
len(reduced_list)
# Out:
# 672

# %%
reduced_list = sorted(reduced_list)

# %%
ipyplot.plot_images(list(reduced_list[0:30]), img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7PwsKMyvag2zT8ZR6E3Khf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7PwsKMyvag2zT8ZR6E3Khf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7PwsKMyvag2zT8ZR6E3Khf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7PwsKMyvag2zT8ZR6E3Khf:checked ~ #ipyplot-html-viewer-textarea-7PwsKMyvag2zT8ZR6E3Khf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7PwsKMyvag2zT8ZR6E3Khf:checked + #ipyplot-html-viewer-label-7PwsKMyvag2zT8ZR6E3Khf:after {
# ...
