# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
from collections import Counter
import math
import datetime as datetime
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import statistics
import glob
import ipyplot
import numpy as np
import random
# Out:
# /home/jliao/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/jliao/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
reduced_folder = "idl_plots/obeam_day_reduced/*/*.png"
subtraction_folder = "idl_plots/obeam_day_with_subtraction/*/*.png"
reduced_list = glob.glob(reduced_folder)
subtraction_list = glob.glob(dispersion_fitting_png_folder)

# %%
reduced_list = reduced_list.sort()

# %%
ipyplot.plot_images(list(reduced_list[0:30]), img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jdiRLLGMtrEwMHsGUGakLk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jdiRLLGMtrEwMHsGUGakLk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jdiRLLGMtrEwMHsGUGakLk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jdiRLLGMtrEwMHsGUGakLk:checked ~ #ipyplot-html-viewer-textarea-jdiRLLGMtrEwMHsGUGakLk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jdiRLLGMtrEwMHsGUGakLk:checked + #ipyplot-html-viewer-label-jdiRLLGMtrEwMHsGUGakLk:after {
# ...
