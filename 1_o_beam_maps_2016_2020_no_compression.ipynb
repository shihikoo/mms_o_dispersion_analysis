# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "plots_avoid_compression/non_sort_map"
hemi_sort_map_path = "plots_avoid_compression/hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
#     , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20201231_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-YxciGCy3uNcD4fNzBmEGpZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-YxciGCy3uNcD4fNzBmEGpZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-YxciGCy3uNcD4fNzBmEGpZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-YxciGCy3uNcD4fNzBmEGpZ:checked ~ #ipyplot-html-viewer-textarea-YxciGCy3uNcD4fNzBmEGpZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-YxciGCy3uNcD4fNzBmEGpZ:checked + #ipyplot-html-viewer-label-YxciGCy3uNcD4fNzBmEGpZ:after {
# ...

# %% [markdown]
# ### Lobe region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
#     , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Cv7xFcVaoYaXNKKHPfEuSQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Cv7xFcVaoYaXNKKHPfEuSQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Cv7xFcVaoYaXNKKHPfEuSQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Cv7xFcVaoYaXNKKHPfEuSQ:checked ~ #ipyplot-html-viewer-textarea-Cv7xFcVaoYaXNKKHPfEuSQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Cv7xFcVaoYaXNKKHPfEuSQ:checked + #ipyplot-html-viewer-label-Cv7xFcVaoYaXNKKHPfEuSQ:after {
# ...

# %% [markdown]
# ### BL region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
#     , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20201231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-D9eJKKsMx88uLBxhNc3qkh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-D9eJKKsMx88uLBxhNc3qkh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-D9eJKKsMx88uLBxhNc3qkh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-D9eJKKsMx88uLBxhNc3qkh:checked ~ #ipyplot-html-viewer-textarea-D9eJKKsMx88uLBxhNc3qkh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-D9eJKKsMx88uLBxhNc3qkh:checked + #ipyplot-html-viewer-label-D9eJKKsMx88uLBxhNc3qkh:after {
# ...

# %% [markdown]
# ### PS region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20201231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kyfzQAsbsETc5nMJGJcDAt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kyfzQAsbsETc5nMJGJcDAt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kyfzQAsbsETc5nMJGJcDAt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kyfzQAsbsETc5nMJGJcDAt:checked ~ #ipyplot-html-viewer-textarea-kyfzQAsbsETc5nMJGJcDAt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kyfzQAsbsETc5nMJGJcDAt:checked + #ipyplot-html-viewer-label-kyfzQAsbsETc5nMJGJcDAt:after {
# ...

# %% [markdown]
# ### All region Beta correlation

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_X_GSM_vs_Beta.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20201231_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8Gzbb5VHDqDtdVT2FwDr2H {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8Gzbb5VHDqDtdVT2FwDr2H {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8Gzbb5VHDqDtdVT2FwDr2H {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8Gzbb5VHDqDtdVT2FwDr2H:checked ~ #ipyplot-html-viewer-textarea-8Gzbb5VHDqDtdVT2FwDr2H {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8Gzbb5VHDqDtdVT2FwDr2H:checked + #ipyplot-html-viewer-label-8Gzbb5VHDqDtdVT2FwDr2H:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5KPJbeKEJBUabZy7tqNPsG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5KPJbeKEJBUabZy7tqNPsG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5KPJbeKEJBUabZy7tqNPsG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5KPJbeKEJBUabZy7tqNPsG:checked ~ #ipyplot-html-viewer-textarea-5KPJbeKEJBUabZy7tqNPsG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5KPJbeKEJBUabZy7tqNPsG:checked + #ipyplot-html-viewer-label-5KPJbeKEJBUabZy7tqNPsG:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mZvYeuxDQDCH7v8gLBpweS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mZvYeuxDQDCH7v8gLBpweS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mZvYeuxDQDCH7v8gLBpweS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mZvYeuxDQDCH7v8gLBpweS:checked ~ #ipyplot-html-viewer-textarea-mZvYeuxDQDCH7v8gLBpweS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mZvYeuxDQDCH7v8gLBpweS:checked + #ipyplot-html-viewer-label-mZvYeuxDQDCH7v8gLBpweS:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-GMbGzoiFwpwVQmXk6zitHR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-GMbGzoiFwpwVQmXk6zitHR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-GMbGzoiFwpwVQmXk6zitHR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-GMbGzoiFwpwVQmXk6zitHR:checked ~ #ipyplot-html-viewer-textarea-GMbGzoiFwpwVQmXk6zitHR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-GMbGzoiFwpwVQmXk6zitHR:checked + #ipyplot-html-viewer-label-GMbGzoiFwpwVQmXk6zitHR:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
             "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,    "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HXNbXUnK2W3Jq9thoQvJvT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HXNbXUnK2W3Jq9thoQvJvT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HXNbXUnK2W3Jq9thoQvJvT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HXNbXUnK2W3Jq9thoQvJvT:checked ~ #ipyplot-html-viewer-textarea-HXNbXUnK2W3Jq9thoQvJvT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HXNbXUnK2W3Jq9thoQvJvT:checked + #ipyplot-html-viewer-label-HXNbXUnK2W3Jq9thoQvJvT:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4NXgyit7K5szvfgQdxtXtE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4NXgyit7K5szvfgQdxtXtE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4NXgyit7K5szvfgQdxtXtE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4NXgyit7K5szvfgQdxtXtE:checked ~ #ipyplot-html-viewer-textarea-4NXgyit7K5szvfgQdxtXtE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4NXgyit7K5szvfgQdxtXtE:checked + #ipyplot-html-viewer-label-4NXgyit7K5szvfgQdxtXtE:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hDfarCMt8mzqZYjiHRDSVy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hDfarCMt8mzqZYjiHRDSVy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hDfarCMt8mzqZYjiHRDSVy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hDfarCMt8mzqZYjiHRDSVy:checked ~ #ipyplot-html-viewer-textarea-hDfarCMt8mzqZYjiHRDSVy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hDfarCMt8mzqZYjiHRDSVy:checked + #ipyplot-html-viewer-label-hDfarCMt8mzqZYjiHRDSVy:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4tVsW87pEFwN5Z7DBshEUW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4tVsW87pEFwN5Z7DBshEUW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4tVsW87pEFwN5Z7DBshEUW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4tVsW87pEFwN5Z7DBshEUW:checked ~ #ipyplot-html-viewer-textarea-4tVsW87pEFwN5Z7DBshEUW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4tVsW87pEFwN5Z7DBshEUW:checked + #ipyplot-html-viewer-label-4tVsW87pEFwN5Z7DBshEUW:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fghPQugMcL6HcQnKTkYrXX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fghPQugMcL6HcQnKTkYrXX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fghPQugMcL6HcQnKTkYrXX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fghPQugMcL6HcQnKTkYrXX:checked ~ #ipyplot-html-viewer-textarea-fghPQugMcL6HcQnKTkYrXX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fghPQugMcL6HcQnKTkYrXX:checked + #ipyplot-html-viewer-label-fghPQugMcL6HcQnKTkYrXX:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-R5YRpCYRCcx5RtXPL3HX2N {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-R5YRpCYRCcx5RtXPL3HX2N {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-R5YRpCYRCcx5RtXPL3HX2N {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-R5YRpCYRCcx5RtXPL3HX2N:checked ~ #ipyplot-html-viewer-textarea-R5YRpCYRCcx5RtXPL3HX2N {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-R5YRpCYRCcx5RtXPL3HX2N:checked + #ipyplot-html-viewer-label-R5YRpCYRCcx5RtXPL3HX2N:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PXo5Gu8JmdQKjZXn2RW2PZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PXo5Gu8JmdQKjZXn2RW2PZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PXo5Gu8JmdQKjZXn2RW2PZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PXo5Gu8JmdQKjZXn2RW2PZ:checked ~ #ipyplot-html-viewer-textarea-PXo5Gu8JmdQKjZXn2RW2PZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PXo5Gu8JmdQKjZXn2RW2PZ:checked + #ipyplot-html-viewer-label-PXo5Gu8JmdQKjZXn2RW2PZ:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
       ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
 ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20160101_to_20201231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-B2zUQ4ApnAoWMKZfprBD4i {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-B2zUQ4ApnAoWMKZfprBD4i {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-B2zUQ4ApnAoWMKZfprBD4i {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-B2zUQ4ApnAoWMKZfprBD4i:checked ~ #ipyplot-html-viewer-textarea-B2zUQ4ApnAoWMKZfprBD4i {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-B2zUQ4ApnAoWMKZfprBD4i:checked + #ipyplot-html-viewer-label-B2zUQ4ApnAoWMKZfprBD4i:after {
# ...
