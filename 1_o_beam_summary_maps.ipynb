# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"

# %% [markdown]
# # All region maps in different projections
#
# Dawn asymmetry near Earth and dusk asymmetry further down

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QZjz9Ku3BkP2m9bY8UXgS7 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QZjz9Ku3BkP2m9bY8UXgS7 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QZjz9Ku3BkP2m9bY8UXgS7 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QZjz9Ku3BkP2m9bY8UXgS7:checked ~ #ipyplot-html-viewer-textarea-QZjz9Ku3BkP2m9bY8UXgS7 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QZjz9Ku3BkP2m9bY8UXgS7:checked + #ipyplot-html-viewer-label-QZjz9Ku3BkP2m9bY8UXgS7:after {
# ...

# %% [markdown]
# ## Different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RR3Bhz9HNi2QuxXuytDov8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RR3Bhz9HNi2QuxXuytDov8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RR3Bhz9HNi2QuxXuytDov8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RR3Bhz9HNi2QuxXuytDov8:checked ~ #ipyplot-html-viewer-textarea-RR3Bhz9HNi2QuxXuytDov8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RR3Bhz9HNi2QuxXuytDov8:checked + #ipyplot-html-viewer-label-RR3Bhz9HNi2QuxXuytDov8:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth. Dawnside asymmetry is observed

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
,      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1_100_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dJmSbZ9Hkvd2KPFb5FrBXP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dJmSbZ9Hkvd2KPFb5FrBXP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dJmSbZ9Hkvd2KPFb5FrBXP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dJmSbZ9Hkvd2KPFb5FrBXP:checked ~ #ipyplot-html-viewer-textarea-dJmSbZ9Hkvd2KPFb5FrBXP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dJmSbZ9Hkvd2KPFb5FrBXP:checked + #ipyplot-html-viewer-label-dJmSbZ9Hkvd2KPFb5FrBXP:after {
# ...

# %% [markdown]
# ### 100 - 1000 eV
# Most observed near the Earth. Dawnside asymmetry observed.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
 ,      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_100_1000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-je8AchYRLKegip9mYyn9Em {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-je8AchYRLKegip9mYyn9Em {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-je8AchYRLKegip9mYyn9Em {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-je8AchYRLKegip9mYyn9Em:checked ~ #ipyplot-html-viewer-textarea-je8AchYRLKegip9mYyn9Em {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-je8AchYRLKegip9mYyn9Em:checked + #ipyplot-html-viewer-label-je8AchYRLKegip9mYyn9Em:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,  "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/events/2d/all_all_All_any_en_1000_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RjjkeCoqQMw2NKrVsDUSVd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RjjkeCoqQMw2NKrVsDUSVd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RjjkeCoqQMw2NKrVsDUSVd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RjjkeCoqQMw2NKrVsDUSVd:checked ~ #ipyplot-html-viewer-textarea-RjjkeCoqQMw2NKrVsDUSVd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RjjkeCoqQMw2NKrVsDUSVd:checked + #ipyplot-html-viewer-label-RjjkeCoqQMw2NKrVsDUSVd:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ## Lobe

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BJzLmbBeB6NBmMR6JtXPsh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BJzLmbBeB6NBmMR6JtXPsh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BJzLmbBeB6NBmMR6JtXPsh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BJzLmbBeB6NBmMR6JtXPsh:checked ~ #ipyplot-html-viewer-textarea-BJzLmbBeB6NBmMR6JtXPsh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BJzLmbBeB6NBmMR6JtXPsh:checked + #ipyplot-html-viewer-label-BJzLmbBeB6NBmMR6JtXPsh:after {
# ...

# %% [markdown]
# ### BL

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-VQdvZLx2ZzuzswjCGS9TJx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VQdvZLx2ZzuzswjCGS9TJx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VQdvZLx2ZzuzswjCGS9TJx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VQdvZLx2ZzuzswjCGS9TJx:checked ~ #ipyplot-html-viewer-textarea-VQdvZLx2ZzuzswjCGS9TJx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VQdvZLx2ZzuzswjCGS9TJx:checked + #ipyplot-html-viewer-label-VQdvZLx2ZzuzswjCGS9TJx:after {
# ...

# %% [markdown]
# ### PS

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-48TGUyFPxZjbUUtvf55a5N {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-48TGUyFPxZjbUUtvf55a5N {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-48TGUyFPxZjbUUtvf55a5N {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-48TGUyFPxZjbUUtvf55a5N:checked ~ #ipyplot-html-viewer-textarea-48TGUyFPxZjbUUtvf55a5N {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-48TGUyFPxZjbUUtvf55a5N:checked + #ipyplot-html-viewer-label-48TGUyFPxZjbUUtvf55a5N:after {
# ...
