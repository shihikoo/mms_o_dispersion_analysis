# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XZgsm plan for dawn, center and dusk in different regions

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_15/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_10/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_15/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_15/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_10/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_15/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_15/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_10/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_15/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-YESDbqS87BzDphBtYr9U95 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-YESDbqS87BzDphBtYr9U95 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-YESDbqS87BzDphBtYr9U95 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-YESDbqS87BzDphBtYr9U95:checked ~ #ipyplot-html-viewer-textarea-YESDbqS87BzDphBtYr9U95 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-YESDbqS87BzDphBtYr9U95:checked + #ipyplot-html-viewer-label-YESDbqS87BzDphBtYr9U95:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_15/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_10/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_10/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_15/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_10/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_10/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_15/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_10/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_10/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-G3Gbce8sRcxArrohc3ivh6 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-G3Gbce8sRcxArrohc3ivh6 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-G3Gbce8sRcxArrohc3ivh6 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-G3Gbce8sRcxArrohc3ivh6:checked ~ #ipyplot-html-viewer-textarea-G3Gbce8sRcxArrohc3ivh6 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-G3Gbce8sRcxArrohc3ivh6:checked + #ipyplot-html-viewer-label-G3Gbce8sRcxArrohc3ivh6:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XYgsm plan for south and north hemisphere

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_20/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/slice/slice_zgrid_20/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_20/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/slice/slice_zgrid_20/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-0.0_20.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_20/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/slice/slice_zgrid_20/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-m5AZUfuuetXDsYBEd3A5b7 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-m5AZUfuuetXDsYBEd3A5b7 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-m5AZUfuuetXDsYBEd3A5b7 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-m5AZUfuuetXDsYBEd3A5b7:checked ~ #ipyplot-html-viewer-textarea-m5AZUfuuetXDsYBEd3A5b7 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-m5AZUfuuetXDsYBEd3A5b7:checked + #ipyplot-html-viewer-label-m5AZUfuuetXDsYBEd3A5b7:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions 2016-2017 vs 2018-2019
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/events/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20180101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/events/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20180101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/events/2d/all_all__any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_ratio_20180101_to_20191231_X_GSM_vs_Z_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8EiaBECY5pYCGFFuN9E2mY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8EiaBECY5pYCGFFuN9E2mY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8EiaBECY5pYCGFFuN9E2mY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8EiaBECY5pYCGFFuN9E2mY:checked ~ #ipyplot-html-viewer-textarea-8EiaBECY5pYCGFFuN9E2mY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8EiaBECY5pYCGFFuN9E2mY:checked + #ipyplot-html-viewer-label-8EiaBECY5pYCGFFuN9E2mY:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth. Dawnside asymmetry is observed

# %% [markdown]
# ### 100 - 1000 eV
# Most observed near the Earth. Dawnside asymmetry observed.

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re
