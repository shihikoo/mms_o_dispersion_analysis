# %% [markdown]
# # Scripts to study the orbits impact
#
# limit the region to X [7,-20], Y = [-20,20], Z = [-4,4] to study
# 1. Is the asymmetry still observed
# 2. the different convection in different years
# 3. the south / north different convection patters

# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "limited_region/non_sort_map"
kp_sort_map_path = 'kp_sort_map'
hemi_sort_map_path = 'limited_region/hemi_sort_map'
bx_sort_map_path = 'bx_sort_map'

# %% [markdown]
# # south / north Median enegy and minimum energy maps for different years

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QdNAsca5Q7BNH3Eny7jCbP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QdNAsca5Q7BNH3Eny7jCbP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QdNAsca5Q7BNH3Eny7jCbP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QdNAsca5Q7BNH3Eny7jCbP:checked ~ #ipyplot-html-viewer-textarea-QdNAsca5Q7BNH3Eny7jCbP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QdNAsca5Q7BNH3Eny7jCbP:checked + #ipyplot-html-viewer-label-QdNAsca5Q7BNH3Eny7jCbP:after {
# ...

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-T9fopKJrfqjq73kmfVZsc8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-T9fopKJrfqjq73kmfVZsc8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-T9fopKJrfqjq73kmfVZsc8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-T9fopKJrfqjq73kmfVZsc8:checked ~ #ipyplot-html-viewer-textarea-T9fopKJrfqjq73kmfVZsc8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-T9fopKJrfqjq73kmfVZsc8:checked + #ipyplot-html-viewer-label-T9fopKJrfqjq73kmfVZsc8:after {
# ...

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cu4kjHizvdXU5Ucgsbe5zi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cu4kjHizvdXU5Ucgsbe5zi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cu4kjHizvdXU5Ucgsbe5zi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cu4kjHizvdXU5Ucgsbe5zi:checked ~ #ipyplot-html-viewer-textarea-cu4kjHizvdXU5Ucgsbe5zi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cu4kjHizvdXU5Ucgsbe5zi:checked + #ipyplot-html-viewer-label-cu4kjHizvdXU5Ucgsbe5zi:after {
# ...

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4okcTPa2ZYvTNu8RfV69gJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4okcTPa2ZYvTNu8RfV69gJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4okcTPa2ZYvTNu8RfV69gJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4okcTPa2ZYvTNu8RfV69gJ:checked ~ #ipyplot-html-viewer-textarea-4okcTPa2ZYvTNu8RfV69gJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4okcTPa2ZYvTNu8RfV69gJ:checked + #ipyplot-html-viewer-label-4okcTPa2ZYvTNu8RfV69gJ:after {
# ...

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-gcHnmCJ23wZSEvUVEXk9kx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gcHnmCJ23wZSEvUVEXk9kx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gcHnmCJ23wZSEvUVEXk9kx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gcHnmCJ23wZSEvUVEXk9kx:checked ~ #ipyplot-html-viewer-textarea-gcHnmCJ23wZSEvUVEXk9kx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gcHnmCJ23wZSEvUVEXk9kx:checked + #ipyplot-html-viewer-label-gcHnmCJ23wZSEvUVEXk9kx:after {
# ...

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nBqiuZxmsQxZ2RGa2HLNbn {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nBqiuZxmsQxZ2RGa2HLNbn {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nBqiuZxmsQxZ2RGa2HLNbn {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nBqiuZxmsQxZ2RGa2HLNbn:checked ~ #ipyplot-html-viewer-textarea-nBqiuZxmsQxZ2RGa2HLNbn {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nBqiuZxmsQxZ2RGa2HLNbn:checked + #ipyplot-html-viewer-label-nBqiuZxmsQxZ2RGa2HLNbn:after {
# ...

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4jZqd6piABGUsqj3MhGZTZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4jZqd6piABGUsqj3MhGZTZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4jZqd6piABGUsqj3MhGZTZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4jZqd6piABGUsqj3MhGZTZ:checked ~ #ipyplot-html-viewer-textarea-4jZqd6piABGUsqj3MhGZTZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4jZqd6piABGUsqj3MhGZTZ:checked + #ipyplot-html-viewer-label-4jZqd6piABGUsqj3MhGZTZ:after {
# ...

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TXZAcjjrmXqJwWMkNxuvP4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TXZAcjjrmXqJwWMkNxuvP4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TXZAcjjrmXqJwWMkNxuvP4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TXZAcjjrmXqJwWMkNxuvP4:checked ~ #ipyplot-html-viewer-textarea-TXZAcjjrmXqJwWMkNxuvP4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TXZAcjjrmXqJwWMkNxuvP4:checked + #ipyplot-html-viewer-label-TXZAcjjrmXqJwWMkNxuvP4:after {
# ...

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-eefEYejuhvb737BRztGGAY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eefEYejuhvb737BRztGGAY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eefEYejuhvb737BRztGGAY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eefEYejuhvb737BRztGGAY:checked ~ #ipyplot-html-viewer-textarea-eefEYejuhvb737BRztGGAY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eefEYejuhvb737BRztGGAY:checked + #ipyplot-html-viewer-label-eefEYejuhvb737BRztGGAY:after {
# ...

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-he9asM6akn6PGrhDBd2Dyh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-he9asM6akn6PGrhDBd2Dyh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-he9asM6akn6PGrhDBd2Dyh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-he9asM6akn6PGrhDBd2Dyh:checked ~ #ipyplot-html-viewer-textarea-he9asM6akn6PGrhDBd2Dyh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-he9asM6akn6PGrhDBd2Dyh:checked + #ipyplot-html-viewer-label-he9asM6akn6PGrhDBd2Dyh:after {
# ...

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dumxWDFHALYyTJvo8eRcXx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dumxWDFHALYyTJvo8eRcXx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dumxWDFHALYyTJvo8eRcXx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dumxWDFHALYyTJvo8eRcXx:checked ~ #ipyplot-html-viewer-textarea-dumxWDFHALYyTJvo8eRcXx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dumxWDFHALYyTJvo8eRcXx:checked + #ipyplot-html-viewer-label-dumxWDFHALYyTJvo8eRcXx:after {
# ...

# %% [markdown]
# # Orbits for different years

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
      , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20180101_to_20181231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20190101_to_20191231_X_GSM_vs_Z_GSM.png"

    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
      , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
     , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20180101_to_20181231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
 , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/footage/any__sampling_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NrVU3pVDBfEd8HPjyxKoQT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NrVU3pVDBfEd8HPjyxKoQT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NrVU3pVDBfEd8HPjyxKoQT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NrVU3pVDBfEd8HPjyxKoQT:checked ~ #ipyplot-html-viewer-textarea-NrVU3pVDBfEd8HPjyxKoQT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NrVU3pVDBfEd8HPjyxKoQT:checked + #ipyplot-html-viewer-label-NrVU3pVDBfEd8HPjyxKoQT:after {
# ...

# %% [markdown]
# # storm phase impact (different regions)

# %%
images_array = [
  "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_Lobe_any/energy/2d/nonstorm_time_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_BL_any/energy/2d/nonstorm_time_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_PS_any/energy/2d/nonstorm_time_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/storm_time_Lobe_any/energy/2d/storm_time_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/storm_time_BL_any/energy/2d/storm_time_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,"idl_plots/"+non_sort_map_path+"/grid_02/storm_time_PS_any/energy/2d/storm_time_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-g5ZivRtzqggm5mABXex8Cf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-g5ZivRtzqggm5mABXex8Cf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-g5ZivRtzqggm5mABXex8Cf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-g5ZivRtzqggm5mABXex8Cf:checked ~ #ipyplot-html-viewer-textarea-g5ZivRtzqggm5mABXex8Cf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-g5ZivRtzqggm5mABXex8Cf:checked + #ipyplot-html-viewer-label-g5ZivRtzqggm5mABXex8Cf:after {
# ...

# %% [markdown]
# # Kp impact

# %%
images_array = [
      "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JAyJYtyWTDQoL6jfGqUbKp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JAyJYtyWTDQoL6jfGqUbKp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JAyJYtyWTDQoL6jfGqUbKp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JAyJYtyWTDQoL6jfGqUbKp:checked ~ #ipyplot-html-viewer-textarea-JAyJYtyWTDQoL6jfGqUbKp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JAyJYtyWTDQoL6jfGqUbKp:checked + #ipyplot-html-viewer-label-JAyJYtyWTDQoL6jfGqUbKp:after {
# ...

# %% [markdown]
# ## Solar wind velocity sorted energy maps

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=225)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WaJTnNEYvP6YhGg3cmUFgX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WaJTnNEYvP6YhGg3cmUFgX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WaJTnNEYvP6YhGg3cmUFgX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WaJTnNEYvP6YhGg3cmUFgX:checked ~ #ipyplot-html-viewer-textarea-WaJTnNEYvP6YhGg3cmUFgX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WaJTnNEYvP6YhGg3cmUFgX:checked + #ipyplot-html-viewer-label-WaJTnNEYvP6YhGg3cmUFgX:after {
# ...

# %% [markdown]
# # Solar wind pressure sorted map

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
,        "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20190101_to_20191231_X_GSM_vs_Y_GSM.png"


]

ipyplot.plot_images(images_array, img_width=220)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-i6gEFrEqRb8cszNKYUxwHx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-i6gEFrEqRb8cszNKYUxwHx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-i6gEFrEqRb8cszNKYUxwHx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-i6gEFrEqRb8cszNKYUxwHx:checked ~ #ipyplot-html-viewer-textarea-i6gEFrEqRb8cszNKYUxwHx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-i6gEFrEqRb8cszNKYUxwHx:checked + #ipyplot-html-viewer-label-i6gEFrEqRb8cszNKYUxwHx:after {
# ...
