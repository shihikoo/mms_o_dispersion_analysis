# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"

with_reduced_non_sort_map_path = main_plot_path+ "plots_with_reduced/non_sort_map"
with_reduced_hemi_sort_map_path = main_plot_path+"plots_with_reduced/hemi_sort_map"

non_sort_map_path = main_plot_path+"plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
    non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-bAqCLf7ZE9dTewbhJSAiZ8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bAqCLf7ZE9dTewbhJSAiZ8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bAqCLf7ZE9dTewbhJSAiZ8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bAqCLf7ZE9dTewbhJSAiZ8:checked ~ #ipyplot-html-viewer-textarea-bAqCLf7ZE9dTewbhJSAiZ8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bAqCLf7ZE9dTewbhJSAiZ8:checked + #ipyplot-html-viewer-label-bAqCLf7ZE9dTewbhJSAiZ8:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-GcHBtsKKrZLzfEiMXKS6Vk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-GcHBtsKKrZLzfEiMXKS6Vk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-GcHBtsKKrZLzfEiMXKS6Vk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-GcHBtsKKrZLzfEiMXKS6Vk:checked ~ #ipyplot-html-viewer-textarea-GcHBtsKKrZLzfEiMXKS6Vk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-GcHBtsKKrZLzfEiMXKS6Vk:checked + #ipyplot-html-viewer-label-GcHBtsKKrZLzfEiMXKS6Vk:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5FBTcBiCXkttnMwVkiZHix {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5FBTcBiCXkttnMwVkiZHix {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5FBTcBiCXkttnMwVkiZHix {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5FBTcBiCXkttnMwVkiZHix:checked ~ #ipyplot-html-viewer-textarea-5FBTcBiCXkttnMwVkiZHix {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5FBTcBiCXkttnMwVkiZHix:checked + #ipyplot-html-viewer-label-5FBTcBiCXkttnMwVkiZHix:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cFR45FefXz5Wjh97PTu8fq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cFR45FefXz5Wjh97PTu8fq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cFR45FefXz5Wjh97PTu8fq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cFR45FefXz5Wjh97PTu8fq:checked ~ #ipyplot-html-viewer-textarea-cFR45FefXz5Wjh97PTu8fq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cFR45FefXz5Wjh97PTu8fq:checked + #ipyplot-html-viewer-label-cFR45FefXz5Wjh97PTu8fq:after {
# ...

# %%
images_array = [
    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_X_GSM_vs_Beta.png"
    , non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_DIST_vs_Beta.png"
    ,    with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_X_GSM_vs_Beta.png"
    , with_reduced_non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HZV2bW3eEMiDspmSWw4LVZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HZV2bW3eEMiDspmSWw4LVZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HZV2bW3eEMiDspmSWw4LVZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HZV2bW3eEMiDspmSWw4LVZ:checked ~ #ipyplot-html-viewer-textarea-HZV2bW3eEMiDspmSWw4LVZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HZV2bW3eEMiDspmSWw4LVZ:checked + #ipyplot-html-viewer-label-HZV2bW3eEMiDspmSWw4LVZ:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"   ,non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" ,with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"     
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"   
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ADftUGXMj6RBny4ppkPhf3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ADftUGXMj6RBny4ppkPhf3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ADftUGXMj6RBny4ppkPhf3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ADftUGXMj6RBny4ppkPhf3:checked ~ #ipyplot-html-viewer-textarea-ADftUGXMj6RBny4ppkPhf3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ADftUGXMj6RBny4ppkPhf3:checked + #ipyplot-html-viewer-label-ADftUGXMj6RBny4ppkPhf3:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"     ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CvyyxjYX958e2yji93Kam3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CvyyxjYX958e2yji93Kam3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CvyyxjYX958e2yji93Kam3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CvyyxjYX958e2yji93Kam3:checked ~ #ipyplot-html-viewer-textarea-CvyyxjYX958e2yji93Kam3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CvyyxjYX958e2yji93Kam3:checked + #ipyplot-html-viewer-label-CvyyxjYX958e2yji93Kam3:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
    hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png" ,    with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
        ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MrrHU7Jyc8nAqmgJWLVd2F {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MrrHU7Jyc8nAqmgJWLVd2F {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MrrHU7Jyc8nAqmgJWLVd2F {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MrrHU7Jyc8nAqmgJWLVd2F:checked ~ #ipyplot-html-viewer-textarea-MrrHU7Jyc8nAqmgJWLVd2F {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MrrHU7Jyc8nAqmgJWLVd2F:checked + #ipyplot-html-viewer-label-MrrHU7Jyc8nAqmgJWLVd2F:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
    non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png",  non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png",
     with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png",  with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png",
    
non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
  ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
        , 
   
with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
  ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
     , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,      non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"  

     , with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"

    ,      with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Fx9ezET9BUPUyCtTAvxefc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Fx9ezET9BUPUyCtTAvxefc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Fx9ezET9BUPUyCtTAvxefc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Fx9ezET9BUPUyCtTAvxefc:checked ~ #ipyplot-html-viewer-textarea-Fx9ezET9BUPUyCtTAvxefc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Fx9ezET9BUPUyCtTAvxefc:checked + #ipyplot-html-viewer-label-Fx9ezET9BUPUyCtTAvxefc:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6GDmZWT3yNeVkSJE2x6DGf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6GDmZWT3yNeVkSJE2x6DGf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6GDmZWT3yNeVkSJE2x6DGf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6GDmZWT3yNeVkSJE2x6DGf:checked ~ #ipyplot-html-viewer-textarea-6GDmZWT3yNeVkSJE2x6DGf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6GDmZWT3yNeVkSJE2x6DGf:checked + #ipyplot-html-viewer-label-6GDmZWT3yNeVkSJE2x6DGf:after {
# ...

# %%
with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
# Out:
# 'idl_plots/plots_with_reduced/non_sort_map/grid_02/PS_any/events/2d/PS_any_imfBz_-25_0imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png'

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
        , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
        ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_25_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-25_0_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    
]

ipyplot.plot_images(images_array, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZByGHyiTarTD9sNoXgvcP4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZByGHyiTarTD9sNoXgvcP4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZByGHyiTarTD9sNoXgvcP4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZByGHyiTarTD9sNoXgvcP4:checked ~ #ipyplot-html-viewer-textarea-ZByGHyiTarTD9sNoXgvcP4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZByGHyiTarTD9sNoXgvcP4:checked + #ipyplot-html-viewer-label-ZByGHyiTarTD9sNoXgvcP4:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"       , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
            ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 

    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-GTrN5eXkEvvNxd8b8rprMq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-GTrN5eXkEvvNxd8b8rprMq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-GTrN5eXkEvvNxd8b8rprMq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-GTrN5eXkEvvNxd8b8rprMq:checked ~ #ipyplot-html-viewer-textarea-GTrN5eXkEvvNxd8b8rprMq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-GTrN5eXkEvvNxd8b8rprMq:checked + #ipyplot-html-viewer-label-GTrN5eXkEvvNxd8b8rprMq:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,     with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    , with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
  ]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oKfVcXxZAYtPw3wdsM4VWq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oKfVcXxZAYtPw3wdsM4VWq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oKfVcXxZAYtPw3wdsM4VWq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oKfVcXxZAYtPw3wdsM4VWq:checked ~ #ipyplot-html-viewer-textarea-oKfVcXxZAYtPw3wdsM4VWq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oKfVcXxZAYtPw3wdsM4VWq:checked + #ipyplot-html-viewer-label-oKfVcXxZAYtPw3wdsM4VWq:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CtaNHCijeCZ5jLbwF9gN4L {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CtaNHCijeCZ5jLbwF9gN4L {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CtaNHCijeCZ5jLbwF9gN4L {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CtaNHCijeCZ5jLbwF9gN4L:checked ~ #ipyplot-html-viewer-textarea-CtaNHCijeCZ5jLbwF9gN4L {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CtaNHCijeCZ5jLbwF9gN4L:checked + #ipyplot-html-viewer-label-CtaNHCijeCZ5jLbwF9gN4L:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   
    

with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BqLjjZ6VNPJsYDFGdJ4TwP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BqLjjZ6VNPJsYDFGdJ4TwP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BqLjjZ6VNPJsYDFGdJ4TwP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BqLjjZ6VNPJsYDFGdJ4TwP:checked ~ #ipyplot-html-viewer-textarea-BqLjjZ6VNPJsYDFGdJ4TwP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BqLjjZ6VNPJsYDFGdJ4TwP:checked + #ipyplot-html-viewer-label-BqLjjZ6VNPJsYDFGdJ4TwP:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
         , with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
  
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
      ,   
    
with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   with_reduced_non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kUR7dLEFDuFHSBcVpXbbmm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kUR7dLEFDuFHSBcVpXbbmm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kUR7dLEFDuFHSBcVpXbbmm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kUR7dLEFDuFHSBcVpXbbmm:checked ~ #ipyplot-html-viewer-textarea-kUR7dLEFDuFHSBcVpXbbmm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kUR7dLEFDuFHSBcVpXbbmm:checked + #ipyplot-html-viewer-label-kUR7dLEFDuFHSBcVpXbbmm:after {
# ...
