# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "5min_non_sort_map"

# %% [markdown]
# # All region maps in different projections
#
# Dawn asymmetry near Earth and dusk asymmetry further down

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-FVcfKZri49w3YXHHHTDVA3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-FVcfKZri49w3YXHHHTDVA3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-FVcfKZri49w3YXHHHTDVA3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-FVcfKZri49w3YXHHHTDVA3:checked ~ #ipyplot-html-viewer-textarea-FVcfKZri49w3YXHHHTDVA3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-FVcfKZri49w3YXHHHTDVA3:checked + #ipyplot-html-viewer-label-FVcfKZri49w3YXHHHTDVA3:after {
# ...

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-m3fkCMRr4U8pbPHpMMu6UA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-m3fkCMRr4U8pbPHpMMu6UA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-m3fkCMRr4U8pbPHpMMu6UA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-m3fkCMRr4U8pbPHpMMu6UA:checked ~ #ipyplot-html-viewer-textarea-m3fkCMRr4U8pbPHpMMu6UA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-m3fkCMRr4U8pbPHpMMu6UA:checked + #ipyplot-html-viewer-label-m3fkCMRr4U8pbPHpMMu6UA:after {
# ...

# %% [markdown]
# ## Energy maps in different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PQesuYZA9cQYxYEvoWhgBT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PQesuYZA9cQYxYEvoWhgBT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PQesuYZA9cQYxYEvoWhgBT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PQesuYZA9cQYxYEvoWhgBT:checked ~ #ipyplot-html-viewer-textarea-PQesuYZA9cQYxYEvoWhgBT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PQesuYZA9cQYxYEvoWhgBT:checked + #ipyplot-html-viewer-label-PQesuYZA9cQYxYEvoWhgBT:after {
# ...

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_All_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_All_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-o75N4wPuAWiCuD77wSh368 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-o75N4wPuAWiCuD77wSh368 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-o75N4wPuAWiCuD77wSh368 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-o75N4wPuAWiCuD77wSh368:checked ~ #ipyplot-html-viewer-textarea-o75N4wPuAWiCuD77wSh368 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-o75N4wPuAWiCuD77wSh368:checked + #ipyplot-html-viewer-label-o75N4wPuAWiCuD77wSh368:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Energy maps in Lobe

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_Lobe_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_Lobe_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fGgehHTazmYYfjmbamo2o4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fGgehHTazmYYfjmbamo2o4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fGgehHTazmYYfjmbamo2o4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fGgehHTazmYYfjmbamo2o4:checked ~ #ipyplot-html-viewer-textarea-fGgehHTazmYYfjmbamo2o4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fGgehHTazmYYfjmbamo2o4:checked + #ipyplot-html-viewer-label-fGgehHTazmYYfjmbamo2o4:after {
# ...

# %% [markdown]
# ### Energy maps in BL

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_BL_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_BL_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-coMKUUmthrzDcxcX2G8rpj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-coMKUUmthrzDcxcX2G8rpj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-coMKUUmthrzDcxcX2G8rpj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-coMKUUmthrzDcxcX2G8rpj:checked ~ #ipyplot-html-viewer-textarea-coMKUUmthrzDcxcX2G8rpj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-coMKUUmthrzDcxcX2G8rpj:checked + #ipyplot-html-viewer-label-coMKUUmthrzDcxcX2G8rpj:after {
# ...

# %% [markdown]
# ### Energy maps in PS

# %%
#display(Image(url= "idl_plots/dispersion_day/o_beam20170406_180000_to_20170407_000000_dispersion.png", width = 450))
#display(Image(url= "idl_plots/dispersion_day/o_beam20170817_120000_to_20170817_180000_dispersion.png", width = 450))
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_median_energy__20160101_to_20171231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/all_all_PS_any/en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20/energy/2d/all_all_PS_any_en_1_40000_imfBz_-20_20_imfBy_-25_25_swP_0_20_minimum_energy__20160101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7VSroApquTbksYnk4NUWLZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7VSroApquTbksYnk4NUWLZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7VSroApquTbksYnk4NUWLZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7VSroApquTbksYnk4NUWLZ:checked ~ #ipyplot-html-viewer-textarea-7VSroApquTbksYnk4NUWLZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7VSroApquTbksYnk4NUWLZ:checked + #ipyplot-html-viewer-label-7VSroApquTbksYnk4NUWLZ:after {
# ...
