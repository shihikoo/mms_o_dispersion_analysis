# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_plots/"
non_sort_map_path = main_plot_path+ "plots_original/non_sort_map"
hemi_sort_map_path = main_plot_path+"plots_original/hemi_sort_map"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [
      non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20180101_to_20181231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20200101_to_20201231_X_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20180101_to_20181231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20200101_to_20201231_Y_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"  
    , non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ]

ipyplot.plot_images(images_array, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Tp2s9uu7nAdPnUcaZiNgDZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Tp2s9uu7nAdPnUcaZiNgDZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Tp2s9uu7nAdPnUcaZiNgDZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Tp2s9uu7nAdPnUcaZiNgDZ:checked ~ #ipyplot-html-viewer-textarea-Tp2s9uu7nAdPnUcaZiNgDZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Tp2s9uu7nAdPnUcaZiNgDZ:checked + #ipyplot-html-viewer-label-Tp2s9uu7nAdPnUcaZiNgDZ:after {
# ...

# %%
images_array = [
      non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20200101_to_20201231_X_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20180101_to_20181231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20200101_to_20201231_Y_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"  
    , non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ]

ipyplot.plot_images(images_array, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Lzn2N7kkThksM3RU8MKMD9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Lzn2N7kkThksM3RU8MKMD9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Lzn2N7kkThksM3RU8MKMD9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Lzn2N7kkThksM3RU8MKMD9:checked ~ #ipyplot-html-viewer-textarea-Lzn2N7kkThksM3RU8MKMD9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Lzn2N7kkThksM3RU8MKMD9:checked + #ipyplot-html-viewer-label-Lzn2N7kkThksM3RU8MKMD9:after {
# ...

# %%
images_array = [
      non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20180101_to_20181231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20200101_to_20201231_X_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20180101_to_20181231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20200101_to_20201231_Y_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"  
    , non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ]

ipyplot.plot_images(images_array, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-6xb4tSuSdcrQrHtUT3aQeb {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6xb4tSuSdcrQrHtUT3aQeb {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6xb4tSuSdcrQrHtUT3aQeb {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6xb4tSuSdcrQrHtUT3aQeb:checked ~ #ipyplot-html-viewer-textarea-6xb4tSuSdcrQrHtUT3aQeb {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6xb4tSuSdcrQrHtUT3aQeb:checked + #ipyplot-html-viewer-label-6xb4tSuSdcrQrHtUT3aQeb:after {
# ...

# %%
images_array = [
      non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20170101_to_20171231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20180101_to_20181231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20200101_to_20201231_X_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20180101_to_20181231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20200101_to_20201231_Y_GSM_vs_Z_GSM.png"

    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"  
    , non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ]

ipyplot.plot_images(images_array, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KnG9d5kEcZmU3j9jNhdkuq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KnG9d5kEcZmU3j9jNhdkuq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KnG9d5kEcZmU3j9jNhdkuq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KnG9d5kEcZmU3j9jNhdkuq:checked ~ #ipyplot-html-viewer-textarea-KnG9d5kEcZmU3j9jNhdkuq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KnG9d5kEcZmU3j9jNhdkuq:checked + #ipyplot-html-viewer-label-KnG9d5kEcZmU3j9jNhdkuq:after {
# ...

# %%
images_array = [
         non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20161231_X_GSM_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20170101_to_20171231_X_GSM_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20180101_to_20181231_X_GSM_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_X_GSM_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20200101_to_20201231_X_GSM_vs_Beta.png"
                 
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20160101_to_20161231_DIST_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20170101_to_20171231_DIST_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20180101_to_20181231_DIST_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20190101_to_20191231_DIST_vs_Beta.png"
    ,    non_sort_map_path+"/grid_02/Tail_any/events/2d/Tail_any__ratio_20200101_to_20201231_DIST_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ykduom7L3erm8QCANcjeSU {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ykduom7L3erm8QCANcjeSU {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ykduom7L3erm8QCANcjeSU {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ykduom7L3erm8QCANcjeSU:checked ~ #ipyplot-html-viewer-textarea-Ykduom7L3erm8QCANcjeSU {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ykduom7L3erm8QCANcjeSU:checked + #ipyplot-html-viewer-label-Ykduom7L3erm8QCANcjeSU:after {
# ...

# %%
images_array = [
        hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"  
        ,   hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"  
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
      ,   hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"    
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
        ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20180101_to_20181231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20200101_to_20201231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EVaQd4HTD7NrPLytoXxECN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EVaQd4HTD7NrPLytoXxECN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EVaQd4HTD7NrPLytoXxECN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EVaQd4HTD7NrPLytoXxECN:checked ~ #ipyplot-html-viewer-textarea-EVaQd4HTD7NrPLytoXxECN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EVaQd4HTD7NrPLytoXxECN:checked + #ipyplot-html-viewer-label-EVaQd4HTD7NrPLytoXxECN:after {
# ...
