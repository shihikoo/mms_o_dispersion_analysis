# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import datetime as datetime
import glob
import ipyplot
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_18401/2766333883.py in <module>
# ----> 1 import pandas as pd
#       2 import plotly.express as px
#       3 import plotly.io as pio
#       4 import datetime as datetime
#       5 import glob
#
# ModuleNotFoundError: No module named 'pandas'

# %%
filename = 'data/outflow_testset_toplot.csv'
to_plot = pd.read_csv(filename)
to_plot_list = list(to_plot["filepath"])

# %%
to_plot_list_ori = [sub.replace('idl_plots', 'idl_plots/plots_original') for sub in to_plot_list] 
to_plot_list_sub = [sub.replace('idl_plots', 'idl_plots/output_2min_subtraction') for sub in to_plot_list] 
to_plot_list_flux = [sub.replace('idl_plots', 'idl_plots/output_2min_flux0.100.150.20') for sub in to_plot_list] 
to_plot_list_pap = [sub.replace('idl_plots', 'idl_plots/output_2min_pap3.02.01.1') for sub in to_plot_list] 
to_plot_list_sub_flux_pap = [sub.replace('idl_plots', 'idl_plots/output_2min_subtraction_flux0.100.150.20_pap1.71.41.1') for sub in to_plot_list]
to_plot_list_sub_flux_pap_high = [sub.replace('idl_plots', 'idl_plots/output_2min_subtraction_flux0.100.150.20_pap3.02.01.1') for sub in to_plot_list] 
to_plot_list_sub_flux_pap_higher = [sub.replace('idl_plots', 'idl_plots/output_2min_subtraction_flux0.500.751.00_pap3.02.01.1') for sub in to_plot_list] 
to_plot_list_5min = [sub.replace('idl_plots', 'idl_plots/output_5min') for sub in to_plot_list] 
to_plot_list_5min_sub_flux_pap_high = [sub.replace('idl_plots', 'idl_plots/output_5min_subtraction_flux0.100.150.20_pap3.02.01.1') for sub in to_plot_list] 
to_plot_list_2min_sub_flux_pap_high_multi = [sub.replace('idl_plots', 'idl_plots/output_2min_multi_subtraction_flux0.100.150.20_pap3.02.01.1') for sub in to_plot_list] 


len(to_plot_list_ori)
# Out:
# 104

# %%
for i in range(4):
    ipyplot.plot_images([to_plot_list_sub_flux_pap[i],to_plot_list_sub_flux_pap_higher[i]] , img_width=440)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8Gd3gqMPQwNX8QnLnKXi8g {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8Gd3gqMPQwNX8QnLnKXi8g {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8Gd3gqMPQwNX8QnLnKXi8g {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8Gd3gqMPQwNX8QnLnKXi8g:checked ~ #ipyplot-html-viewer-textarea-8Gd3gqMPQwNX8QnLnKXi8g {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8Gd3gqMPQwNX8QnLnKXi8g:checked + #ipyplot-html-viewer-label-8Gd3gqMPQwNX8QnLnKXi8g:after {
# ...

# %%
for i in range(4):
    ipyplot.plot_images([to_plot_list_sub_flux_pap[i],to_plot_list_5min_sub_flux_pap[i]] , img_width=440)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8f514fe62641> in <module>
#       1 for i in range(4):
# ----> 2     ipyplot.plot_images([to_plot_list_sub_flux_pap[i],to_plot_list_5min_sub_flux_pap[i]] , img_width=440)
#
# NameError: name 'to_plot_list_5min_sub_flux_pap' is not defined
