# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "plots_only_reduced/non_sort_map"
hemi_sort_map_path = "plots_only_reduced/hemi_sort_map"

# %% [markdown]
# # "Corrected" maps for compression dates

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
#     , "idl_plots/"+non_sort_map_path+"/grid_02/any/events/2d/any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XcqjDEAERme2NGVxafetoJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XcqjDEAERme2NGVxafetoJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XcqjDEAERme2NGVxafetoJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XcqjDEAERme2NGVxafetoJ:checked ~ #ipyplot-html-viewer-textarea-XcqjDEAERme2NGVxafetoJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XcqjDEAERme2NGVxafetoJ:checked + #ipyplot-html-viewer-label-XcqjDEAERme2NGVxafetoJ:after {
# ...

# %% [markdown]
# ### Lobe region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ktDoRDocbrM99uruobkJhx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ktDoRDocbrM99uruobkJhx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ktDoRDocbrM99uruobkJhx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ktDoRDocbrM99uruobkJhx:checked ~ #ipyplot-html-viewer-textarea-ktDoRDocbrM99uruobkJhx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ktDoRDocbrM99uruobkJhx:checked + #ipyplot-html-viewer-label-ktDoRDocbrM99uruobkJhx:after {
# ...

# %% [markdown]
# ### BL region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SYMH4eK7FAMzXURAuPKZyr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SYMH4eK7FAMzXURAuPKZyr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SYMH4eK7FAMzXURAuPKZyr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SYMH4eK7FAMzXURAuPKZyr:checked ~ #ipyplot-html-viewer-textarea-SYMH4eK7FAMzXURAuPKZyr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SYMH4eK7FAMzXURAuPKZyr:checked + #ipyplot-html-viewer-label-SYMH4eK7FAMzXURAuPKZyr:after {
# ...

# %% [markdown]
# ### PS region

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Beta.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4mb2ZizNkr77PKTchf7Mxt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4mb2ZizNkr77PKTchf7Mxt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4mb2ZizNkr77PKTchf7Mxt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4mb2ZizNkr77PKTchf7Mxt:checked ~ #ipyplot-html-viewer-textarea-4mb2ZizNkr77PKTchf7Mxt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4mb2ZizNkr77PKTchf7Mxt:checked + #ipyplot-html-viewer-label-4mb2ZizNkr77PKTchf7Mxt:after {
# ...

# %% [markdown]
# # Occurrence frequency maps in XZgsm plan for dawn, center and dusk in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-H3T6N7nNXqQPFh4KMSSwm3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-H3T6N7nNXqQPFh4KMSSwm3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-H3T6N7nNXqQPFh4KMSSwm3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-H3T6N7nNXqQPFh4KMSSwm3:checked ~ #ipyplot-html-viewer-textarea-H3T6N7nNXqQPFh4KMSSwm3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-H3T6N7nNXqQPFh4KMSSwm3:checked + #ipyplot-html-viewer-label-H3T6N7nNXqQPFh4KMSSwm3:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in YZgsm plan for Inner magnetosphere, tail and distant tail in different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nvF5ZNMutSAPy4ShsYGSzG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nvF5ZNMutSAPy4ShsYGSzG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nvF5ZNMutSAPy4ShsYGSzG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nvF5ZNMutSAPy4ShsYGSzG:checked ~ #ipyplot-html-viewer-textarea-nvF5ZNMutSAPy4ShsYGSzG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nvF5ZNMutSAPy4ShsYGSzG:checked + #ipyplot-html-viewer-label-nvF5ZNMutSAPy4ShsYGSzG:after {
# ...

# %% [markdown]
# # Occurrence frequency maps 2016-2019 in XYgsm plan for south and north hemisphere (defined with Bx, Zgsm and Xgsm)

# %%
images_array = [
        "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hvaULaTm7kbZ2wM2UA6Udo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hvaULaTm7kbZ2wM2UA6Udo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hvaULaTm7kbZ2wM2UA6Udo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hvaULaTm7kbZ2wM2UA6Udo:checked ~ #ipyplot-html-viewer-textarea-hvaULaTm7kbZ2wM2UA6Udo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hvaULaTm7kbZ2wM2UA6Udo:checked + #ipyplot-html-viewer-label-hvaULaTm7kbZ2wM2UA6Udo:after {
# ...

# %% [markdown]
# # IMF By correlation with asymmetry

# %% [markdown]
# ### IMF By sorted maps in YZgsm for different regions

# %%
images_array = [
             "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,    "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
,    "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Q59LViAZvLjB4wLjNrLZLf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Q59LViAZvLjB4wLjNrLZLf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Q59LViAZvLjB4wLjNrLZLf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Q59LViAZvLjB4wLjNrLZLf:checked ~ #ipyplot-html-viewer-textarea-Q59LViAZvLjB4wLjNrLZLf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Q59LViAZvLjB4wLjNrLZLf:checked + #ipyplot-html-viewer-label-Q59LViAZvLjB4wLjNrLZLf:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=250)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-3dv7ygKo74LhvPP6CyV8Ey {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3dv7ygKo74LhvPP6CyV8Ey {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3dv7ygKo74LhvPP6CyV8Ey {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3dv7ygKo74LhvPP6CyV8Ey:checked ~ #ipyplot-html-viewer-textarea-3dv7ygKo74LhvPP6CyV8Ey {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3dv7ygKo74LhvPP6CyV8Ey:checked + #ipyplot-html-viewer-label-3dv7ygKo74LhvPP6CyV8Ey:after {
# ...

# %% [markdown]
# ### IMF By / Bz sorted sliced maps in YZgsm for lobe

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_0_20_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBz_-20_0_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HvvJaHuhyPm3jyuTEbAH97 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HvvJaHuhyPm3jyuTEbAH97 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HvvJaHuhyPm3jyuTEbAH97 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HvvJaHuhyPm3jyuTEbAH97:checked ~ #ipyplot-html-viewer-textarea-HvvJaHuhyPm3jyuTEbAH97 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HvvJaHuhyPm3jyuTEbAH97:checked + #ipyplot-html-viewer-label-HvvJaHuhyPm3jyuTEbAH97:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in YZgsm for different regions

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_15/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/slice/slice_zgrid_10/Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_15/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/slice/slice_zgrid_10/BL_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png" 
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_0_25__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_15/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-30.0_-15.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-15.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/slice/slice_zgrid_10/PS_any_imfBy_-25_0__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM_at_X_GSM_-5.0_5.0.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-msHonVcugZAfvefLREBchr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-msHonVcugZAfvefLREBchr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-msHonVcugZAfvefLREBchr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-msHonVcugZAfvefLREBchr:checked ~ #ipyplot-html-viewer-textarea-msHonVcugZAfvefLREBchr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-msHonVcugZAfvefLREBchr:checked + #ipyplot-html-viewer-label-msHonVcugZAfvefLREBchr:after {
# ...

# %% [markdown]
# ### IMF By sorted sliced maps in XYgsm for different regions

# %%
images_array = [
      "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/events/2d/north_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/events/2d/south_Lobe_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/events/2d/north_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/events/2d/south_BL_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"

    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/events/2d/north_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_-25_0__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/events/2d/south_PS_any_imfBy_0_25__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"

    
  ]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KgyXJw9PxKY5q4BMcBh5GJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KgyXJw9PxKY5q4BMcBh5GJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KgyXJw9PxKY5q4BMcBh5GJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KgyXJw9PxKY5q4BMcBh5GJ:checked ~ #ipyplot-html-viewer-textarea-KgyXJw9PxKY5q4BMcBh5GJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KgyXJw9PxKY5q4BMcBh5GJ:checked + #ipyplot-html-viewer-label-KgyXJw9PxKY5q4BMcBh5GJ:after {
# ...

# %% [markdown]
# ## Different energy  ranges
#
# ### 1- 100 eV
# Data are trapped near Earth.

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1_100__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fZKv8RFXaaUsaTxh89saaF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fZKv8RFXaaUsaTxh89saaF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fZKv8RFXaaUsaTxh89saaF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fZKv8RFXaaUsaTxh89saaF:checked ~ #ipyplot-html-viewer-textarea-fZKv8RFXaaUsaTxh89saaF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fZKv8RFXaaUsaTxh89saaF:checked + #ipyplot-html-viewer-label-fZKv8RFXaaUsaTxh89saaF:after {
# ...

# %% [markdown]
# ### 100 eV ~ 1 keV

# %%
images_array = [
          "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_100_1000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
   ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jWFDB7F36QMDhyErD8TvMJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jWFDB7F36QMDhyErD8TvMJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jWFDB7F36QMDhyErD8TvMJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jWFDB7F36QMDhyErD8TvMJ:checked ~ #ipyplot-html-viewer-textarea-jWFDB7F36QMDhyErD8TvMJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jWFDB7F36QMDhyErD8TvMJ:checked + #ipyplot-html-viewer-label-jWFDB7F36QMDhyErD8TvMJ:after {
# ...

# %% [markdown]
# ### 1000 - 40000 eV
# Dusk asymmetry observed for -10Re to -20Re

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
       ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/events/2d/Lobe_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
 ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
      ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/events/2d/BL_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Z_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/events/2d/PS_any_en_1000_40000__ratio_20190417_to_20190817_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-E89o6PXjdkizqcxNd6Rfeg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-E89o6PXjdkizqcxNd6Rfeg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-E89o6PXjdkizqcxNd6Rfeg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-E89o6PXjdkizqcxNd6Rfeg:checked ~ #ipyplot-html-viewer-textarea-E89o6PXjdkizqcxNd6Rfeg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-E89o6PXjdkizqcxNd6Rfeg:checked + #ipyplot-html-viewer-label-E89o6PXjdkizqcxNd6Rfeg:after {
# ...
