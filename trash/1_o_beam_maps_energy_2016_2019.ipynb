# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
non_sort_map_path = "non_sort_map"
kp_sort_map_path = 'kp_sort_map'
hemi_sort_map_path = 'hemi_sort_map'
bx_sort_map_path = 'bx_sort_map'

# %% [markdown]
# # Median enegy and minimum energy maps in different projections

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MDq2xjeHBqdEKmCE6tJ9uj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MDq2xjeHBqdEKmCE6tJ9uj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MDq2xjeHBqdEKmCE6tJ9uj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MDq2xjeHBqdEKmCE6tJ9uj:checked ~ #ipyplot-html-viewer-textarea-MDq2xjeHBqdEKmCE6tJ9uj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MDq2xjeHBqdEKmCE6tJ9uj:checked + #ipyplot-html-viewer-label-MDq2xjeHBqdEKmCE6tJ9uj:after {
# ...

# %% [markdown]
# # Median energy map 2016-2017 vs 2018-2019

# %%
images_array = [
       "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
   ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
 ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
  ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CiJndGErpuG653ABTAULMK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CiJndGErpuG653ABTAULMK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CiJndGErpuG653ABTAULMK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CiJndGErpuG653ABTAULMK:checked ~ #ipyplot-html-viewer-textarea-CiJndGErpuG653ABTAULMK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CiJndGErpuG653ABTAULMK:checked + #ipyplot-html-viewer-label-CiJndGErpuG653ABTAULMK:after {
# ...

# %% [markdown]
# # Minimum energy map 2016-2017 vs 2018-2019

# %%
images_array = [
       "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
     ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
   ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20171231_X_GSM_vs_Y_GSM.png"
 ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20180101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8P6SYki4Ex9SmuTwJfjnQD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8P6SYki4Ex9SmuTwJfjnQD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8P6SYki4Ex9SmuTwJfjnQD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8P6SYki4Ex9SmuTwJfjnQD:checked ~ #ipyplot-html-viewer-textarea-8P6SYki4Ex9SmuTwJfjnQD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8P6SYki4Ex9SmuTwJfjnQD:checked + #ipyplot-html-viewer-label-8P6SYki4Ex9SmuTwJfjnQD:after {
# ...

# %% [markdown]
# # Median energy map south/north 2016-2017 vs 2018-2019

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_20/Lobe_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_20/Lobe_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_20/Lobe_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_20/Lobe_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_20/BL_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_20/BL_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_20/BL_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_20/BL_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_20/PS_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_20/PS_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_0.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_20/PS_any__median_energy__20160101_to_20171231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_20/PS_any__median_energy__20180101_to_20191231_X_GSM_vs_Y_GSM_at_Z_GSM_-20.0_0.0.png"
    
]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SxKP6d5Grycz2MxSdWjvGq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SxKP6d5Grycz2MxSdWjvGq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SxKP6d5Grycz2MxSdWjvGq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SxKP6d5Grycz2MxSdWjvGq:checked ~ #ipyplot-html-viewer-textarea-SxKP6d5Grycz2MxSdWjvGq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SxKP6d5Grycz2MxSdWjvGq:checked + #ipyplot-html-viewer-label-SxKP6d5Grycz2MxSdWjvGq:after {
# ...

# %%
images_array = [
        "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_10/Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/slice/slice_zgrid_15/Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_10/BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/slice/slice_zgrid_15/BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-20.0_-5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_10/PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_-5.0_5.0.png"
    ,   "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/slice/slice_zgrid_15/PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM_at_Y_GSM_5.0_20.0.png"
  ]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-YTbKr88RJm8yp9KSeVjxrd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-YTbKr88RJm8yp9KSeVjxrd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-YTbKr88RJm8yp9KSeVjxrd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-YTbKr88RJm8yp9KSeVjxrd:checked ~ #ipyplot-html-viewer-textarea-YTbKr88RJm8yp9KSeVjxrd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-YTbKr88RJm8yp9KSeVjxrd:checked + #ipyplot-html-viewer-label-YTbKr88RJm8yp9KSeVjxrd:after {
# ...

# %% [markdown]
# ## Different years ( 2016 VS 2017)
#
# Asymmetry can be seen in both year
# 2016: south hemisphere observation only. Clear asymmtry -5 Re to 5 Re. Symmetric -10 to -5Re
# 2017: both hemisperes data. same asymmetry as observed for all data.
#
# ### Meidan energy

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20160101_to_20161231_MLT_vs_L.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
      , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
  , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__median_energy__20170101_to_20171231_MLT_vs_L.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Az2BdtaauWAYs9Nj9UMcym {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Az2BdtaauWAYs9Nj9UMcym {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Az2BdtaauWAYs9Nj9UMcym {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Az2BdtaauWAYs9Nj9UMcym:checked ~ #ipyplot-html-viewer-textarea-Az2BdtaauWAYs9Nj9UMcym {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Az2BdtaauWAYs9Nj9UMcym:checked + #ipyplot-html-viewer-label-Az2BdtaauWAYs9Nj9UMcym:after {
# ...

# %% [markdown]
# ### Minimum energy

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20161231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20161231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20161231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20160101_to_20161231_MLT_vs_L.png"
      , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20170101_to_20171231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20170101_to_20171231_X_GSM_vs_Z_GSM.png"
     , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20170101_to_20171231_Y_GSM_vs_Z_GSM.png"
 , "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any__minimum_energy__20170101_to_20171231_MLT_vs_L.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-frb2v8GVUfmEbkDJr36cxq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-frb2v8GVUfmEbkDJr36cxq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-frb2v8GVUfmEbkDJr36cxq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-frb2v8GVUfmEbkDJr36cxq:checked ~ #ipyplot-html-viewer-textarea-frb2v8GVUfmEbkDJr36cxq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-frb2v8GVUfmEbkDJr36cxq:checked + #ipyplot-html-viewer-label-frb2v8GVUfmEbkDJr36cxq:after {
# ...

# %% [markdown]
# ## Review Different Regions [Lobe, BL, PS]

# %% [markdown]
# ### Median Energy maps in Lobe, BL, PS

# %%
images_array = [
      "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__median_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__median_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    ,"idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__median_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7MCMruvpmz747JHZX9XoKv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7MCMruvpmz747JHZX9XoKv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7MCMruvpmz747JHZX9XoKv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7MCMruvpmz747JHZX9XoKv:checked ~ #ipyplot-html-viewer-textarea-7MCMruvpmz747JHZX9XoKv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7MCMruvpmz747JHZX9XoKv:checked + #ipyplot-html-viewer-label-7MCMruvpmz747JHZX9XoKv:after {
# ...

# %% [markdown]
# ### Minimum Energy maps in Lobe, BL, PS

# %%
images_array = [
     "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/Lobe_any/energy/2d/Lobe_any__minimum_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
       , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/BL_any/energy/2d/BL_any__minimum_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Z_GSM.png"
    , "idl_plots/"+non_sort_map_path+"/grid_02/PS_any/energy/2d/PS_any__minimum_energy__20160101_to_20191231_Y_GSM_vs_Z_GSM.png"
]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PSC33a2U5rxM9UJQRni4Hi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PSC33a2U5rxM9UJQRni4Hi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PSC33a2U5rxM9UJQRni4Hi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PSC33a2U5rxM9UJQRni4Hi:checked ~ #ipyplot-html-viewer-textarea-PSC33a2U5rxM9UJQRni4Hi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PSC33a2U5rxM9UJQRni4Hi:checked + #ipyplot-html-viewer-label-PSC33a2U5rxM9UJQRni4Hi:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mGKbFMroaoFMWnAbEuTisu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mGKbFMroaoFMWnAbEuTisu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mGKbFMroaoFMWnAbEuTisu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mGKbFMroaoFMWnAbEuTisu:checked ~ #ipyplot-html-viewer-textarea-mGKbFMroaoFMWnAbEuTisu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mGKbFMroaoFMWnAbEuTisu:checked + #ipyplot-html-viewer-label-mGKbFMroaoFMWnAbEuTisu:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
    ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
  ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SoKpNvi2wGvxYK4G4iwdS6 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SoKpNvi2wGvxYK4G4iwdS6 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SoKpNvi2wGvxYK4G4iwdS6 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SoKpNvi2wGvxYK4G4iwdS6:checked ~ #ipyplot-html-viewer-textarea-SoKpNvi2wGvxYK4G4iwdS6 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SoKpNvi2wGvxYK4G4iwdS6:checked + #ipyplot-html-viewer-label-SoKpNvi2wGvxYK4G4iwdS6:after {
# ...

# %% [markdown]
# ### South / north in median energy different regions for positive and negative IMF By

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_-25_0__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_imfBy_0_25__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4sjBSWTEyUwG3JaymskE5N {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4sjBSWTEyUwG3JaymskE5N {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4sjBSWTEyUwG3JaymskE5N {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4sjBSWTEyUwG3JaymskE5N:checked ~ #ipyplot-html-viewer-textarea-4sjBSWTEyUwG3JaymskE5N {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4sjBSWTEyUwG3JaymskE5N:checked + #ipyplot-html-viewer-label-4sjBSWTEyUwG3JaymskE5N:after {
# ...

# %% [markdown]
# ## kp impacts on the convection maps

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_any/energy/2d/Kplt_2_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,  "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_any/energy/2d/Kpge_2_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PrYXdL6DVTZKBPZFN8M86F {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PrYXdL6DVTZKBPZFN8M86F {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PrYXdL6DVTZKBPZFN8M86F {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PrYXdL6DVTZKBPZFN8M86F:checked ~ #ipyplot-html-viewer-textarea-PrYXdL6DVTZKBPZFN8M86F {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PrYXdL6DVTZKBPZFN8M86F:checked + #ipyplot-html-viewer-label-PrYXdL6DVTZKBPZFN8M86F:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_Lobe_any/energy/2d/Kplt_2_Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_Lobe_any/energy/2d/Kpge_2_Lobe_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RMYGv597jdAc8KkT9PiCNw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RMYGv597jdAc8KkT9PiCNw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RMYGv597jdAc8KkT9PiCNw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RMYGv597jdAc8KkT9PiCNw:checked ~ #ipyplot-html-viewer-textarea-RMYGv597jdAc8KkT9PiCNw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RMYGv597jdAc8KkT9PiCNw:checked + #ipyplot-html-viewer-label-RMYGv597jdAc8KkT9PiCNw:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_BL_any/energy/2d/Kplt_2_BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_BL_any/energy/2d/Kpge_2_BL_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ULVjDacLiten4gFa93KY9E {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ULVjDacLiten4gFa93KY9E {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ULVjDacLiten4gFa93KY9E {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ULVjDacLiten4gFa93KY9E:checked ~ #ipyplot-html-viewer-textarea-ULVjDacLiten4gFa93KY9E {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ULVjDacLiten4gFa93KY9E:checked + #ipyplot-html-viewer-label-ULVjDacLiten4gFa93KY9E:after {
# ...

# %%
images_array = [
   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_lt_2/grid_02/Kplt_2_PS_any/energy/2d/Kplt_2_PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+kp_sort_map_path+"/kp_ge_2/grid_02/Kpge_2_PS_any/energy/2d/Kpge_2_PS_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-beiZoYUsvDQouKAe49LLfF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-beiZoYUsvDQouKAe49LLfF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-beiZoYUsvDQouKAe49LLfF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-beiZoYUsvDQouKAe49LLfF:checked ~ #ipyplot-html-viewer-textarea-beiZoYUsvDQouKAe49LLfF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-beiZoYUsvDQouKAe49LLfF:checked + #ipyplot-html-viewer-label-beiZoYUsvDQouKAe49LLfF:after {
# ...

# %% [markdown]
# ## Storm impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/nonstorm_time_any/energy/2d/nonstorm_time_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
 ,  "idl_plots/"+non_sort_map_path+"/grid_02/storm_time_any/energy/2d/storm_time_any__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-MSQ9wpCfBCxmTKEbGpDz9T {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MSQ9wpCfBCxmTKEbGpDz9T {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MSQ9wpCfBCxmTKEbGpDz9T {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MSQ9wpCfBCxmTKEbGpDz9T:checked ~ #ipyplot-html-viewer-textarea-MSQ9wpCfBCxmTKEbGpDz9T {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MSQ9wpCfBCxmTKEbGpDz9T:checked + #ipyplot-html-viewer-label-MSQ9wpCfBCxmTKEbGpDz9T:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_0_450_minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swV_450_900_minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fGieRspVsAG9QDpJxC4LwJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fGieRspVsAG9QDpJxC4LwJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fGieRspVsAG9QDpJxC4LwJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fGieRspVsAG9QDpJxC4LwJ:checked ~ #ipyplot-html-viewer-textarea-fGieRspVsAG9QDpJxC4LwJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fGieRspVsAG9QDpJxC4LwJ:checked + #ipyplot-html-viewer-label-fGieRspVsAG9QDpJxC4LwJ:after {
# ...

# %%
images_array = [
    "idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_Lobe_any/energy/2d/north_Lobe_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_Lobe_any/energy/2d/south_Lobe_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_BL_any/energy/2d/north_BL_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_BL_any/energy/2d/south_BL_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_north/grid_02/north_PS_any/energy/2d/north_PS_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_0_450_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
   ,"idl_plots/"+hemi_sort_map_path+"/hemi_south/grid_02/south_PS_any/energy/2d/south_PS_any_swV_450_900_median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RNxGm4o64j7J8Mwf6dEC3S {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RNxGm4o64j7J8Mwf6dEC3S {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RNxGm4o64j7J8Mwf6dEC3S {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RNxGm4o64j7J8Mwf6dEC3S:checked ~ #ipyplot-html-viewer-textarea-RNxGm4o64j7J8Mwf6dEC3S {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RNxGm4o64j7J8Mwf6dEC3S:checked + #ipyplot-html-viewer-label-RNxGm4o64j7J8Mwf6dEC3S:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [
    "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__median_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_0_2__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"
,   "idl_plots/"+non_sort_map_path+"/grid_02/any/energy/2d/any_swP_2_20__minimum_energy__20160101_to_20191231_X_GSM_vs_Y_GSM.png"

]

ipyplot.plot_images(images_array, img_width=228)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oXFpYtFk9Ykgr5L2X2RaYN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oXFpYtFk9Ykgr5L2X2RaYN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oXFpYtFk9Ykgr5L2X2RaYN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oXFpYtFk9Ykgr5L2X2RaYN:checked ~ #ipyplot-html-viewer-textarea-oXFpYtFk9Ykgr5L2X2RaYN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oXFpYtFk9Ykgr5L2X2RaYN:checked + #ipyplot-html-viewer-label-oXFpYtFk9Ykgr5L2X2RaYN:after {
# ...
